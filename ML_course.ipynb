# %%
# !gdown https://drive.google.com/uc?id=1UvHAQn7Ypzj4KonaSZJNewO1Zl_U-aHl
# Out:
# Downloading...
# From: https://drive.google.com/uc?id=1UvHAQn7Ypzj4KonaSZJNewO1Zl_U-aHl
# To: /content/INT3405-projects.zip
# 100% 105M/105M [00:01<00:00, 88.9MB/s]

# %%
# !unzip INT3405-projects.zip
# !cp -r 'INT3405E Final project' project
# %cd project
# !unzip ml1m.zip
# Out:
# Archive:  INT3405-projects.zip
#   inflating: INT3405E Final project/README.md
#   inflating: INT3405E Final project/load_data_example.py
#   inflating: INT3405E Final project/ml1m.zip
# /content/project
# Archive:  ml1m.zip
#    creating: content/dataset/
#   inflating: content/dataset/movies_test.dat
#   inflating: content/dataset/users.dat
#   inflating: content/dataset/genres.txt
#   inflating: content/dataset/ratings.dat
#   inflating: content/dataset/movies_train.dat
#    creating: content/dataset/ml1m-images/
#   inflating: content/dataset/ml1m-images/2816.jpg
#   inflating: content/dataset/ml1m-images/1043.jpg
#   inflating: content/dataset/ml1m-images/941.jpg
#   inflating: content/dataset/ml1m-images/2.jpg
#   inflating: content/dataset/ml1m-images/160.jpg
#   inflating: content/dataset/ml1m-images/1201.jpg
#   inflating: content/dataset/ml1m-images/276.jpg
#   inflating: content/dataset/ml1m-images/2119.jpg
#   inflating: content/dataset/ml1m-images/599.jpg
#   inflating: content/dataset/ml1m-images/2829.jpg
#   inflating: content/dataset/ml1m-images/3628.jpg
#   inflating: content/dataset/ml1m-images/1867.jpg
#   inflating: content/dataset/ml1m-images/924.jpg
#   inflating: content/dataset/ml1m-images/2380.jpg
#   inflating: content/dataset/ml1m-images/1458.jpg
#   inflating: content/dataset/ml1m-images/3169.jpg
#   inflating: content/dataset/ml1m-images/168.jpg
#   inflating: content/dataset/ml1m-images/1083.jpg
#   inflating: content/dataset/ml1m-images/2637.jpg
#   inflating: content/dataset/ml1m-images/3070.jpg
#   inflating: content/dataset/ml1m-images/2514.jpg
#   inflating: content/dataset/ml1m-images/1962.jpg
#   inflating: content/dataset/ml1m-images/2792.jpg
#   inflating: content/dataset/ml1m-images/2558.jpg
#   inflating: content/dataset/ml1m-images/3786.jpg
#   inflating: content/dataset/ml1m-images/1055.jpg
#   inflating: content/dataset/ml1m-images/1834.jpg
#   inflating: content/dataset/ml1m-images/3343.jpg
#   inflating: content/dataset/ml1m-images/2974.jpg
#   inflating: content/dataset/ml1m-images/1066.jpg
#   inflating: content/dataset/ml1m-images/3796.jpg
#   inflating: content/dataset/ml1m-images/1332.jpg
#   inflating: content/dataset/ml1m-images/3360.jpg
#   inflating: content/dataset/ml1m-images/1221.jpg
#   inflating: content/dataset/ml1m-images/1970.jpg
#   inflating: content/dataset/ml1m-images/2706.jpg
#   inflating: content/dataset/ml1m-images/1341.jpg
#   inflating: content/dataset/ml1m-images/1817.jpg
#   inflating: content/dataset/ml1m-images/265.jpg
#   inflating: content/dataset/ml1m-images/2325.jpg
#   inflating: content/dataset/ml1m-images/1821.jpg
#   inflating: content/dataset/ml1m-images/2639.jpg
#   inflating: content/dataset/ml1m-images/3807.jpg
#   inflating: content/dataset/ml1m-images/1346.jpg
#   inflating: content/dataset/ml1m-images/2083.jpg
#   inflating: content/dataset/ml1m-images/113.jpg
#   inflating: content/dataset/ml1m-images/2868.jpg
#   inflating: content/dataset/ml1m-images/3617.jpg
#   inflating: content/dataset/ml1m-images/2904.jpg
#   inflating: content/dataset/ml1m-images/73.jpg
#   inflating: content/dataset/ml1m-images/3950.jpg
#   inflating: content/dataset/ml1m-images/3587.jpg
#   inflating: content/dataset/ml1m-images/2005.jpg
#   inflating: content/dataset/ml1m-images/1044.jpg
#   inflating: content/dataset/ml1m-images/1385.jpg
#   inflating: content/dataset/ml1m-images/26.jpg
#   inflating: content/dataset/ml1m-images/1449.jpg
#   inflating: content/dataset/ml1m-images/3213.jpg
#   inflating: content/dataset/ml1m-images/2988.jpg
#   inflating: content/dataset/ml1m-images/82.jpg
#   inflating: content/dataset/ml1m-images/2667.jpg
#   inflating: content/dataset/ml1m-images/2451.jpg
#   inflating: content/dataset/ml1m-images/2985.jpg
#   inflating: content/dataset/ml1m-images/252.jpg
#   inflating: content/dataset/ml1m-images/333.jpg
#   inflating: content/dataset/ml1m-images/1565.jpg
#   inflating: content/dataset/ml1m-images/850.jpg
#   inflating: content/dataset/ml1m-images/2147.jpg
#   inflating: content/dataset/ml1m-images/1020.jpg
#   inflating: content/dataset/ml1m-images/2649.jpg
#   inflating: content/dataset/ml1m-images/3915.jpg
#   inflating: content/dataset/ml1m-images/571.jpg
#   inflating: content/dataset/ml1m-images/463.jpg
#   inflating: content/dataset/ml1m-images/1383.jpg
#   inflating: content/dataset/ml1m-images/1014.jpg
#   inflating: content/dataset/ml1m-images/939.jpg
#   inflating: content/dataset/ml1m-images/22.jpg
#   inflating: content/dataset/ml1m-images/307.jpg
#   inflating: content/dataset/ml1m-images/2010.jpg
#   inflating: content/dataset/ml1m-images/3688.jpg
#   inflating: content/dataset/ml1m-images/1722.jpg
#   inflating: content/dataset/ml1m-images/2482.jpg
#   inflating: content/dataset/ml1m-images/2827.jpg
#   inflating: content/dataset/ml1m-images/3368.jpg
#   inflating: content/dataset/ml1m-images/2535.jpg
#   inflating: content/dataset/ml1m-images/961.jpg
#   inflating: content/dataset/ml1m-images/2677.jpg
#   inflating: content/dataset/ml1m-images/2628.jpg
#   inflating: content/dataset/ml1m-images/1387.jpg
#   inflating: content/dataset/ml1m-images/824.jpg
#   inflating: content/dataset/ml1m-images/2365.jpg
#   inflating: content/dataset/ml1m-images/3614.jpg
#   inflating: content/dataset/ml1m-images/3882.jpg
#   inflating: content/dataset/ml1m-images/2728.jpg
#   inflating: content/dataset/ml1m-images/2625.jpg
#   inflating: content/dataset/ml1m-images/1374.jpg
#   inflating: content/dataset/ml1m-images/1285.jpg
#   inflating: content/dataset/ml1m-images/193.jpg
#   inflating: content/dataset/ml1m-images/3518.jpg
#   inflating: content/dataset/ml1m-images/3045.jpg
#   inflating: content/dataset/ml1m-images/498.jpg
#   inflating: content/dataset/ml1m-images/16.jpg
#   inflating: content/dataset/ml1m-images/2491.jpg
#   inflating: content/dataset/ml1m-images/3643.jpg
#   inflating: content/dataset/ml1m-images/2407.jpg
#   inflating: content/dataset/ml1m-images/2773.jpg
#   inflating: content/dataset/ml1m-images/3923.jpg
#   inflating: content/dataset/ml1m-images/3335.jpg
#   inflating: content/dataset/ml1m-images/2732.jpg
#   inflating: content/dataset/ml1m-images/378.jpg
#   inflating: content/dataset/ml1m-images/196.jpg
#   inflating: content/dataset/ml1m-images/1269.jpg
#   inflating: content/dataset/ml1m-images/1608.jpg
#   inflating: content/dataset/ml1m-images/2411.jpg
#   inflating: content/dataset/ml1m-images/3387.jpg
#   inflating: content/dataset/ml1m-images/2807.jpg
#   inflating: content/dataset/ml1m-images/2171.jpg
#   inflating: content/dataset/ml1m-images/2403.jpg
#   inflating: content/dataset/ml1m-images/1758.jpg
#   inflating: content/dataset/ml1m-images/2735.jpg
#   inflating: content/dataset/ml1m-images/2290.jpg
#   inflating: content/dataset/ml1m-images/2740.jpg
#   inflating: content/dataset/ml1m-images/2316.jpg
#   inflating: content/dataset/ml1m-images/719.jpg
#   inflating: content/dataset/ml1m-images/3052.jpg
#   inflating: content/dataset/ml1m-images/3505.jpg
#   inflating: content/dataset/ml1m-images/2573.jpg
#   inflating: content/dataset/ml1m-images/2241.jpg
#   inflating: content/dataset/ml1m-images/1017.jpg
#   inflating: content/dataset/ml1m-images/413.jpg
#   inflating: content/dataset/ml1m-images/3499.jpg
#   inflating: content/dataset/ml1m-images/955.jpg
#   inflating: content/dataset/ml1m-images/2919.jpg
#   inflating: content/dataset/ml1m-images/2476.jpg
#   inflating: content/dataset/ml1m-images/1351.jpg
#   inflating: content/dataset/ml1m-images/596.jpg
#   inflating: content/dataset/ml1m-images/2101.jpg
#   inflating: content/dataset/ml1m-images/3949.jpg
#   inflating: content/dataset/ml1m-images/2166.jpg
#   inflating: content/dataset/ml1m-images/2428.jpg
#   inflating: content/dataset/ml1m-images/10.jpg
#   inflating: content/dataset/ml1m-images/2080.jpg
#   inflating: content/dataset/ml1m-images/3112.jpg
#   inflating: content/dataset/ml1m-images/3176.jpg
#   inflating: content/dataset/ml1m-images/480.jpg
#   inflating: content/dataset/ml1m-images/3283.jpg
#   inflating: content/dataset/ml1m-images/3878.jpg
#   inflating: content/dataset/ml1m-images/2165.jpg
#   inflating: content/dataset/ml1m-images/617.jpg
#   inflating: content/dataset/ml1m-images/1767.jpg
#   inflating: content/dataset/ml1m-images/2624.jpg
#   inflating: content/dataset/ml1m-images/1880.jpg
#   inflating: content/dataset/ml1m-images/473.jpg
#   inflating: content/dataset/ml1m-images/769.jpg
#   inflating: content/dataset/ml1m-images/2757.jpg
#   inflating: content/dataset/ml1m-images/1857.jpg
#   inflating: content/dataset/ml1m-images/2826.jpg
#   inflating: content/dataset/ml1m-images/3270.jpg
#   inflating: content/dataset/ml1m-images/2164.jpg
#   inflating: content/dataset/ml1m-images/3032.jpg
#   inflating: content/dataset/ml1m-images/3525.jpg
#   inflating: content/dataset/ml1m-images/2712.jpg
#   inflating: content/dataset/ml1m-images/1997.jpg
#   inflating: content/dataset/ml1m-images/2979.jpg
#   inflating: content/dataset/ml1m-images/2856.jpg
#   inflating: content/dataset/ml1m-images/3910.jpg
#   inflating: content/dataset/ml1m-images/2609.jpg
#   inflating: content/dataset/ml1m-images/1227.jpg
#   inflating: content/dataset/ml1m-images/2973.jpg
#   inflating: content/dataset/ml1m-images/2442.jpg
#   inflating: content/dataset/ml1m-images/370.jpg
#   inflating: content/dataset/ml1m-images/1615.jpg
#   inflating: content/dataset/ml1m-images/3760.jpg
#   inflating: content/dataset/ml1m-images/808.jpg
#   inflating: content/dataset/ml1m-images/1457.jpg
#   inflating: content/dataset/ml1m-images/1504.jpg
#   inflating: content/dataset/ml1m-images/3514.jpg
#   inflating: content/dataset/ml1m-images/3802.jpg
#   inflating: content/dataset/ml1m-images/1405.jpg
#   inflating: content/dataset/ml1m-images/3316.jpg
#   inflating: content/dataset/ml1m-images/3659.jpg
#   inflating: content/dataset/ml1m-images/804.jpg
#   inflating: content/dataset/ml1m-images/1162.jpg
#   inflating: content/dataset/ml1m-images/2381.jpg
#   inflating: content/dataset/ml1m-images/2055.jpg
#   inflating: content/dataset/ml1m-images/964.jpg
#   inflating: content/dataset/ml1m-images/1667.jpg
#   inflating: content/dataset/ml1m-images/1896.jpg
#   inflating: content/dataset/ml1m-images/3862.jpg
#   inflating: content/dataset/ml1m-images/3911.jpg
#   inflating: content/dataset/ml1m-images/736.jpg
#   inflating: content/dataset/ml1m-images/1217.jpg
#   inflating: content/dataset/ml1m-images/1759.jpg
#   inflating: content/dataset/ml1m-images/1629.jpg
#   inflating: content/dataset/ml1m-images/3319.jpg
#   inflating: content/dataset/ml1m-images/2024.jpg
#   inflating: content/dataset/ml1m-images/3160.jpg
#   inflating: content/dataset/ml1m-images/2866.jpg
#   inflating: content/dataset/ml1m-images/952.jpg
#   inflating: content/dataset/ml1m-images/2545.jpg
#   inflating: content/dataset/ml1m-images/2550.jpg
#   inflating: content/dataset/ml1m-images/248.jpg
#   inflating: content/dataset/ml1m-images/910.jpg
#   inflating: content/dataset/ml1m-images/1252.jpg
#   inflating: content/dataset/ml1m-images/1348.jpg
#   inflating: content/dataset/ml1m-images/1955.jpg
#   inflating: content/dataset/ml1m-images/2894.jpg
#   inflating: content/dataset/ml1m-images/3941.jpg
#   inflating: content/dataset/ml1m-images/659.jpg
#   inflating: content/dataset/ml1m-images/3469.jpg
#   inflating: content/dataset/ml1m-images/3813.jpg
#   inflating: content/dataset/ml1m-images/555.jpg
#   inflating: content/dataset/ml1m-images/3819.jpg
#   inflating: content/dataset/ml1m-images/2057.jpg
#   inflating: content/dataset/ml1m-images/1754.jpg
#   inflating: content/dataset/ml1m-images/1663.jpg
#   inflating: content/dataset/ml1m-images/294.jpg
#   inflating: content/dataset/ml1m-images/1484.jpg
#   inflating: content/dataset/ml1m-images/3372.jpg
#   inflating: content/dataset/ml1m-images/1668.jpg
#   inflating: content/dataset/ml1m-images/3177.jpg
#   inflating: content/dataset/ml1m-images/2134.jpg
#   inflating: content/dataset/ml1m-images/23.jpg
#   inflating: content/dataset/ml1m-images/1965.jpg
#   inflating: content/dataset/ml1m-images/829.jpg
#   inflating: content/dataset/ml1m-images/3929.jpg
#   inflating: content/dataset/ml1m-images/1355.jpg
#   inflating: content/dataset/ml1m-images/304.jpg
#   inflating: content/dataset/ml1m-images/282.jpg
#   inflating: content/dataset/ml1m-images/3731.jpg
#   inflating: content/dataset/ml1m-images/2399.jpg
#   inflating: content/dataset/ml1m-images/2098.jpg
#   inflating: content/dataset/ml1m-images/390.jpg
#   inflating: content/dataset/ml1m-images/2632.jpg
#   inflating: content/dataset/ml1m-images/3804.jpg
#   inflating: content/dataset/ml1m-images/3161.jpg
#   inflating: content/dataset/ml1m-images/240.jpg
#   inflating: content/dataset/ml1m-images/788.jpg
#   inflating: content/dataset/ml1m-images/223.jpg
#   inflating: content/dataset/ml1m-images/3673.jpg
#   inflating: content/dataset/ml1m-images/3751.jpg
#   inflating: content/dataset/ml1m-images/1619.jpg
#   inflating: content/dataset/ml1m-images/2611.jpg
#   inflating: content/dataset/ml1m-images/3580.jpg
#   inflating: content/dataset/ml1m-images/1473.jpg
#   inflating: content/dataset/ml1m-images/2704.jpg
#   inflating: content/dataset/ml1m-images/358.jpg
#   inflating: content/dataset/ml1m-images/2035.jpg
#   inflating: content/dataset/ml1m-images/1520.jpg
#   inflating: content/dataset/ml1m-images/2457.jpg
#   inflating: content/dataset/ml1m-images/2725.jpg
#   inflating: content/dataset/ml1m-images/771.jpg
#   inflating: content/dataset/ml1m-images/251.jpg
#   inflating: content/dataset/ml1m-images/602.jpg
#   inflating: content/dataset/ml1m-images/1170.jpg
#   inflating: content/dataset/ml1m-images/3568.jpg
#   inflating: content/dataset/ml1m-images/181.jpg
#   inflating: content/dataset/ml1m-images/3130.jpg
#   inflating: content/dataset/ml1m-images/2694.jpg
#   inflating: content/dataset/ml1m-images/3230.jpg
#   inflating: content/dataset/ml1m-images/313.jpg
#   inflating: content/dataset/ml1m-images/99.jpg
#   inflating: content/dataset/ml1m-images/2936.jpg
#   inflating: content/dataset/ml1m-images/714.jpg
#   inflating: content/dataset/ml1m-images/3854.jpg
#   inflating: content/dataset/ml1m-images/2395.jpg
#   inflating: content/dataset/ml1m-images/2927.jpg
#   inflating: content/dataset/ml1m-images/944.jpg
#   inflating: content/dataset/ml1m-images/2969.jpg
#   inflating: content/dataset/ml1m-images/2351.jpg
#   inflating: content/dataset/ml1m-images/1853.jpg
#   inflating: content/dataset/ml1m-images/3263.jpg
#   inflating: content/dataset/ml1m-images/1948.jpg
#   inflating: content/dataset/ml1m-images/1126.jpg
#   inflating: content/dataset/ml1m-images/2614.jpg
#   inflating: content/dataset/ml1m-images/117.jpg
#   inflating: content/dataset/ml1m-images/2435.jpg
#   inflating: content/dataset/ml1m-images/303.jpg
#   inflating: content/dataset/ml1m-images/897.jpg
#   inflating: content/dataset/ml1m-images/1099.jpg
#   inflating: content/dataset/ml1m-images/1924.jpg
#   inflating: content/dataset/ml1m-images/3928.jpg
#   inflating: content/dataset/ml1m-images/2104.jpg
#   inflating: content/dataset/ml1m-images/2666.jpg
#   inflating: content/dataset/ml1m-images/229.jpg
#   inflating: content/dataset/ml1m-images/2501.jpg
#   inflating: content/dataset/ml1m-images/2681.jpg
#   inflating: content/dataset/ml1m-images/1230.jpg
#   inflating: content/dataset/ml1m-images/1255.jpg
#   inflating: content/dataset/ml1m-images/992.jpg
#   inflating: content/dataset/ml1m-images/1972.jpg
#   inflating: content/dataset/ml1m-images/3820.jpg
#   inflating: content/dataset/ml1m-images/2802.jpg
#   inflating: content/dataset/ml1m-images/2964.jpg
#   inflating: content/dataset/ml1m-images/3007.jpg
#   inflating: content/dataset/ml1m-images/1978.jpg
#   inflating: content/dataset/ml1m-images/3667.jpg
#   inflating: content/dataset/ml1m-images/1097.jpg
#   inflating: content/dataset/ml1m-images/3185.jpg
#   inflating: content/dataset/ml1m-images/50.jpg
#   inflating: content/dataset/ml1m-images/326.jpg
#   inflating: content/dataset/ml1m-images/2983.jpg
#   inflating: content/dataset/ml1m-images/3497.jpg
#   inflating: content/dataset/ml1m-images/2384.jpg
#   inflating: content/dataset/ml1m-images/951.jpg
#   inflating: content/dataset/ml1m-images/550.jpg
#   inflating: content/dataset/ml1m-images/1654.jpg
#   inflating: content/dataset/ml1m-images/627.jpg
#   inflating: content/dataset/ml1m-images/342.jpg
#   inflating: content/dataset/ml1m-images/565.jpg
#   inflating: content/dataset/ml1m-images/556.jpg
#   inflating: content/dataset/ml1m-images/3728.jpg
#   inflating: content/dataset/ml1m-images/241.jpg
#   inflating: content/dataset/ml1m-images/1681.jpg
#   inflating: content/dataset/ml1m-images/2396.jpg
#   inflating: content/dataset/ml1m-images/1060.jpg
#   inflating: content/dataset/ml1m-images/3490.jpg
#   inflating: content/dataset/ml1m-images/3805.jpg
#   inflating: content/dataset/ml1m-images/3186.jpg
#   inflating: content/dataset/ml1m-images/3798.jpg
#   inflating: content/dataset/ml1m-images/3438.jpg
#   inflating: content/dataset/ml1m-images/513.jpg
#   inflating: content/dataset/ml1m-images/3695.jpg
#   inflating: content/dataset/ml1m-images/297.jpg
#   inflating: content/dataset/ml1m-images/1616.jpg
#   inflating: content/dataset/ml1m-images/1036.jpg
#   inflating: content/dataset/ml1m-images/671.jpg
#   inflating: content/dataset/ml1m-images/1191.jpg
#   inflating: content/dataset/ml1m-images/1337.jpg
#   inflating: content/dataset/ml1m-images/417.jpg
#   inflating: content/dataset/ml1m-images/1397.jpg
#   inflating: content/dataset/ml1m-images/1342.jpg
#   inflating: content/dataset/ml1m-images/2294.jpg
#   inflating: content/dataset/ml1m-images/3710.jpg
#   inflating: content/dataset/ml1m-images/2710.jpg
#   inflating: content/dataset/ml1m-images/1247.jpg
#   inflating: content/dataset/ml1m-images/1086.jpg
#   inflating: content/dataset/ml1m-images/394.jpg
#   inflating: content/dataset/ml1m-images/931.jpg
#   inflating: content/dataset/ml1m-images/1592.jpg
#   inflating: content/dataset/ml1m-images/3616.jpg
#   inflating: content/dataset/ml1m-images/3475.jpg
#   inflating: content/dataset/ml1m-images/3770.jpg
#   inflating: content/dataset/ml1m-images/268.jpg
#   inflating: content/dataset/ml1m-images/1804.jpg
#   inflating: content/dataset/ml1m-images/3309.jpg
#   inflating: content/dataset/ml1m-images/3554.jpg
#   inflating: content/dataset/ml1m-images/1809.jpg
#   inflating: content/dataset/ml1m-images/7.jpg
#   inflating: content/dataset/ml1m-images/3513.jpg
#   inflating: content/dataset/ml1m-images/3689.jpg
#   inflating: content/dataset/ml1m-images/1925.jpg
#   inflating: content/dataset/ml1m-images/380.jpg
#   inflating: content/dataset/ml1m-images/2286.jpg
#   inflating: content/dataset/ml1m-images/2871.jpg
#   inflating: content/dataset/ml1m-images/3116.jpg
#   inflating: content/dataset/ml1m-images/2799.jpg
#   inflating: content/dataset/ml1m-images/2383.jpg
#   inflating: content/dataset/ml1m-images/3266.jpg
#   inflating: content/dataset/ml1m-images/2652.jpg
#   inflating: content/dataset/ml1m-images/2862.jpg
#   inflating: content/dataset/ml1m-images/2589.jpg
#   inflating: content/dataset/ml1m-images/1409.jpg
#   inflating: content/dataset/ml1m-images/668.jpg
#   inflating: content/dataset/ml1m-images/2137.jpg
#   inflating: content/dataset/ml1m-images/1717.jpg
#   inflating: content/dataset/ml1m-images/908.jpg
#   inflating: content/dataset/ml1m-images/3189.jpg
#   inflating: content/dataset/ml1m-images/1517.jpg
#   inflating: content/dataset/ml1m-images/3495.jpg
#   inflating: content/dataset/ml1m-images/3078.jpg
#   inflating: content/dataset/ml1m-images/1563.jpg
#   inflating: content/dataset/ml1m-images/3694.jpg
#   inflating: content/dataset/ml1m-images/2012.jpg
#   inflating: content/dataset/ml1m-images/3908.jpg
#   inflating: content/dataset/ml1m-images/2300.jpg
#   inflating: content/dataset/ml1m-images/609.jpg
#   inflating: content/dataset/ml1m-images/3457.jpg
#   inflating: content/dataset/ml1m-images/2956.jpg
#   inflating: content/dataset/ml1m-images/3716.jpg
#   inflating: content/dataset/ml1m-images/892.jpg
#   inflating: content/dataset/ml1m-images/1673.jpg
#   inflating: content/dataset/ml1m-images/470.jpg
#   inflating: content/dataset/ml1m-images/1483.jpg
#   inflating: content/dataset/ml1m-images/431.jpg
#   inflating: content/dataset/ml1m-images/83.jpg
#   inflating: content/dataset/ml1m-images/1783.jpg
#   inflating: content/dataset/ml1m-images/93.jpg
#   inflating: content/dataset/ml1m-images/12.jpg
#   inflating: content/dataset/ml1m-images/218.jpg
#   inflating: content/dataset/ml1m-images/1205.jpg
#   inflating: content/dataset/ml1m-images/216.jpg
#   inflating: content/dataset/ml1m-images/2506.jpg
#   inflating: content/dataset/ml1m-images/810.jpg
#   inflating: content/dataset/ml1m-images/3117.jpg
#   inflating: content/dataset/ml1m-images/722.jpg
#   inflating: content/dataset/ml1m-images/1185.jpg
#   inflating: content/dataset/ml1m-images/1264.jpg
#   inflating: content/dataset/ml1m-images/1966.jpg
#   inflating: content/dataset/ml1m-images/125.jpg
#   inflating: content/dataset/ml1m-images/184.jpg
#   inflating: content/dataset/ml1m-images/3724.jpg
#   inflating: content/dataset/ml1m-images/3224.jpg
#   inflating: content/dataset/ml1m-images/2950.jpg
#   inflating: content/dataset/ml1m-images/3060.jpg
#   inflating: content/dataset/ml1m-images/3165.jpg
#   inflating: content/dataset/ml1m-images/1292.jpg
#   inflating: content/dataset/ml1m-images/2193.jpg
#   inflating: content/dataset/ml1m-images/536.jpg
#   inflating: content/dataset/ml1m-images/3705.jpg
#   inflating: content/dataset/ml1m-images/3604.jpg
#   inflating: content/dataset/ml1m-images/3082.jpg
#   inflating: content/dataset/ml1m-images/3663.jpg
#   inflating: content/dataset/ml1m-images/962.jpg
#   inflating: content/dataset/ml1m-images/510.jpg
#   inflating: content/dataset/ml1m-images/1675.jpg
#   inflating: content/dataset/ml1m-images/3282.jpg
#   inflating: content/dataset/ml1m-images/3743.jpg
#   inflating: content/dataset/ml1m-images/3511.jpg
#   inflating: content/dataset/ml1m-images/1679.jpg
#   inflating: content/dataset/ml1m-images/2076.jpg
#   inflating: content/dataset/ml1m-images/2803.jpg
#   inflating: content/dataset/ml1m-images/1317.jpg
#   inflating: content/dataset/ml1m-images/455.jpg
#   inflating: content/dataset/ml1m-images/3516.jpg
#   inflating: content/dataset/ml1m-images/3675.jpg
#   inflating: content/dataset/ml1m-images/2929.jpg
#   inflating: content/dataset/ml1m-images/704.jpg
#   inflating: content/dataset/ml1m-images/3442.jpg
#   inflating: content/dataset/ml1m-images/2796.jpg
#   inflating: content/dataset/ml1m-images/1228.jpg
#   inflating: content/dataset/ml1m-images/2370.jpg
#   inflating: content/dataset/ml1m-images/3259.jpg
#   inflating: content/dataset/ml1m-images/1456.jpg
#   inflating: content/dataset/ml1m-images/1999.jpg
#   inflating: content/dataset/ml1m-images/1204.jpg
#   inflating: content/dataset/ml1m-images/1343.jpg
#   inflating: content/dataset/ml1m-images/3428.jpg
#   inflating: content/dataset/ml1m-images/318.jpg
#   inflating: content/dataset/ml1m-images/2339.jpg
#   inflating: content/dataset/ml1m-images/2981.jpg
#   inflating: content/dataset/ml1m-images/3135.jpg
#   inflating: content/dataset/ml1m-images/2729.jpg
#   inflating: content/dataset/ml1m-images/1330.jpg
#   inflating: content/dataset/ml1m-images/3665.jpg
#   inflating: content/dataset/ml1m-images/3468.jpg
#   inflating: content/dataset/ml1m-images/1421.jpg
#   inflating: content/dataset/ml1m-images/3747.jpg
#   inflating: content/dataset/ml1m-images/1546.jpg
#   inflating: content/dataset/ml1m-images/3445.jpg
#   inflating: content/dataset/ml1m-images/207.jpg
#   inflating: content/dataset/ml1m-images/377.jpg
#   inflating: content/dataset/ml1m-images/524.jpg
#   inflating: content/dataset/ml1m-images/3672.jpg
#   inflating: content/dataset/ml1m-images/893.jpg
#   inflating: content/dataset/ml1m-images/1372.jpg
#   inflating: content/dataset/ml1m-images/2398.jpg
#   inflating: content/dataset/ml1m-images/502.jpg
#   inflating: content/dataset/ml1m-images/2414.jpg
#   inflating: content/dataset/ml1m-images/3661.jpg
#   inflating: content/dataset/ml1m-images/1123.jpg
#   inflating: content/dataset/ml1m-images/2582.jpg
#   inflating: content/dataset/ml1m-images/479.jpg
#   inflating: content/dataset/ml1m-images/2853.jpg
#   inflating: content/dataset/ml1m-images/451.jpg
#   inflating: content/dataset/ml1m-images/309.jpg
#   inflating: content/dataset/ml1m-images/1858.jpg
#   inflating: content/dataset/ml1m-images/613.jpg
#   inflating: content/dataset/ml1m-images/1244.jpg
#   inflating: content/dataset/ml1m-images/589.jpg
#   inflating: content/dataset/ml1m-images/3017.jpg
#   inflating: content/dataset/ml1m-images/2488.jpg
#   inflating: content/dataset/ml1m-images/876.jpg
#   inflating: content/dataset/ml1m-images/331.jpg
#   inflating: content/dataset/ml1m-images/929.jpg
#   inflating: content/dataset/ml1m-images/653.jpg
#   inflating: content/dataset/ml1m-images/2749.jpg
#   inflating: content/dataset/ml1m-images/2599.jpg
#   inflating: content/dataset/ml1m-images/2702.jpg
#   inflating: content/dataset/ml1m-images/2736.jpg
#   inflating: content/dataset/ml1m-images/934.jpg
#   inflating: content/dataset/ml1m-images/2139.jpg
#   inflating: content/dataset/ml1m-images/1104.jpg
#   inflating: content/dataset/ml1m-images/2994.jpg
#   inflating: content/dataset/ml1m-images/2586.jpg
#   inflating: content/dataset/ml1m-images/3706.jpg
#   inflating: content/dataset/ml1m-images/3683.jpg
#   inflating: content/dataset/ml1m-images/3524.jpg
#   inflating: content/dataset/ml1m-images/1907.jpg
#   inflating: content/dataset/ml1m-images/215.jpg
#   inflating: content/dataset/ml1m-images/1214.jpg
#   inflating: content/dataset/ml1m-images/1294.jpg
#   inflating: content/dataset/ml1m-images/1068.jpg
#   inflating: content/dataset/ml1m-images/3142.jpg
#   inflating: content/dataset/ml1m-images/3415.jpg
#   inflating: content/dataset/ml1m-images/1610.jpg
#   inflating: content/dataset/ml1m-images/2328.jpg
#   inflating: content/dataset/ml1m-images/1093.jpg
#   inflating: content/dataset/ml1m-images/680.jpg
#   inflating: content/dataset/ml1m-images/2092.jpg
#   inflating: content/dataset/ml1m-images/538.jpg
#   inflating: content/dataset/ml1m-images/484.jpg
#   inflating: content/dataset/ml1m-images/2967.jpg
#   inflating: content/dataset/ml1m-images/3487.jpg
#   inflating: content/dataset/ml1m-images/2262.jpg
#   inflating: content/dataset/ml1m-images/360.jpg
#   inflating: content/dataset/ml1m-images/1362.jpg
#   inflating: content/dataset/ml1m-images/1863.jpg
#   inflating: content/dataset/ml1m-images/3090.jpg
#   inflating: content/dataset/ml1m-images/74.jpg
#   inflating: content/dataset/ml1m-images/495.jpg
#   inflating: content/dataset/ml1m-images/2902.jpg
#   inflating: content/dataset/ml1m-images/3265.jpg
#   inflating: content/dataset/ml1m-images/1985.jpg
#   inflating: content/dataset/ml1m-images/2555.jpg
#   inflating: content/dataset/ml1m-images/875.jpg
#   inflating: content/dataset/ml1m-images/156.jpg
#   inflating: content/dataset/ml1m-images/1570.jpg
#   inflating: content/dataset/ml1m-images/3902.jpg
#   inflating: content/dataset/ml1m-images/1872.jpg
#   inflating: content/dataset/ml1m-images/2953.jpg
#   inflating: content/dataset/ml1m-images/1290.jpg
#   inflating: content/dataset/ml1m-images/1535.jpg
#   inflating: content/dataset/ml1m-images/2572.jpg
#   inflating: content/dataset/ml1m-images/292.jpg
#   inflating: content/dataset/ml1m-images/1016.jpg
#   inflating: content/dataset/ml1m-images/3846.jpg
#   inflating: content/dataset/ml1m-images/2634.jpg
#   inflating: content/dataset/ml1m-images/1596.jpg
#   inflating: content/dataset/ml1m-images/1495.jpg
#   inflating: content/dataset/ml1m-images/2851.jpg
#   inflating: content/dataset/ml1m-images/2865.jpg
#   inflating: content/dataset/ml1m-images/2392.jpg
#   inflating: content/dataset/ml1m-images/3433.jpg
#   inflating: content/dataset/ml1m-images/1662.jpg
#   inflating: content/dataset/ml1m-images/1854.jpg
#   inflating: content/dataset/ml1m-images/3364.jpg
#   inflating: content/dataset/ml1m-images/92.jpg
#   inflating: content/dataset/ml1m-images/3808.jpg
#   inflating: content/dataset/ml1m-images/316.jpg
#   inflating: content/dataset/ml1m-images/3633.jpg
#   inflating: content/dataset/ml1m-images/2416.jpg
#   inflating: content/dataset/ml1m-images/1670.jpg
#   inflating: content/dataset/ml1m-images/1180.jpg
#   inflating: content/dataset/ml1m-images/746.jpg
#   inflating: content/dataset/ml1m-images/2109.jpg
#   inflating: content/dataset/ml1m-images/2496.jpg
#   inflating: content/dataset/ml1m-images/1407.jpg
#   inflating: content/dataset/ml1m-images/3914.jpg
#   inflating: content/dataset/ml1m-images/161.jpg
#   inflating: content/dataset/ml1m-images/1030.jpg
#   inflating: content/dataset/ml1m-images/583.jpg
#   inflating: content/dataset/ml1m-images/1366.jpg
#   inflating: content/dataset/ml1m-images/281.jpg
#   inflating: content/dataset/ml1m-images/3024.jpg
#   inflating: content/dataset/ml1m-images/2793.jpg
#   inflating: content/dataset/ml1m-images/456.jpg
#   inflating: content/dataset/ml1m-images/1450.jpg
#   inflating: content/dataset/ml1m-images/2132.jpg
#   inflating: content/dataset/ml1m-images/3289.jpg
#   inflating: content/dataset/ml1m-images/1945.jpg
#   inflating: content/dataset/ml1m-images/2989.jpg
#   inflating: content/dataset/ml1m-images/3952.jpg
#   inflating: content/dataset/ml1m-images/1245.jpg
#   inflating: content/dataset/ml1m-images/3034.jpg
#   inflating: content/dataset/ml1m-images/1502.jpg
#   inflating: content/dataset/ml1m-images/2747.jpg
#   inflating: content/dataset/ml1m-images/499.jpg
#   inflating: content/dataset/ml1m-images/49.jpg
#   inflating: content/dataset/ml1m-images/2790.jpg
#   inflating: content/dataset/ml1m-images/3287.jpg
#   inflating: content/dataset/ml1m-images/697.jpg
#   inflating: content/dataset/ml1m-images/3452.jpg
#   inflating: content/dataset/ml1m-images/3101.jpg
#   inflating: content/dataset/ml1m-images/1307.jpg
#   inflating: content/dataset/ml1m-images/1569.jpg
#   inflating: content/dataset/ml1m-images/2860.jpg
#   inflating: content/dataset/ml1m-images/3909.jpg
#   inflating: content/dataset/ml1m-images/3076.jpg
#   inflating: content/dataset/ml1m-images/832.jpg
#   inflating: content/dataset/ml1m-images/3746.jpg
#   inflating: content/dataset/ml1m-images/483.jpg
#   inflating: content/dataset/ml1m-images/3134.jpg
#   inflating: content/dataset/ml1m-images/3111.jpg
#   inflating: content/dataset/ml1m-images/592.jpg
#   inflating: content/dataset/ml1m-images/3108.jpg
#   inflating: content/dataset/ml1m-images/551.jpg
#   inflating: content/dataset/ml1m-images/3548.jpg
#   inflating: content/dataset/ml1m-images/1811.jpg
#   inflating: content/dataset/ml1m-images/3268.jpg
#   inflating: content/dataset/ml1m-images/1621.jpg
#   inflating: content/dataset/ml1m-images/2345.jpg
#   inflating: content/dataset/ml1m-images/474.jpg
#   inflating: content/dataset/ml1m-images/3528.jpg
#   inflating: content/dataset/ml1m-images/485.jpg
#   inflating: content/dataset/ml1m-images/2696.jpg
#   inflating: content/dataset/ml1m-images/3649.jpg
#   inflating: content/dataset/ml1m-images/3512.jpg
#   inflating: content/dataset/ml1m-images/967.jpg
#   inflating: content/dataset/ml1m-images/1041.jpg
#   inflating: content/dataset/ml1m-images/449.jpg
#   inflating: content/dataset/ml1m-images/3669.jpg
#   inflating: content/dataset/ml1m-images/1531.jpg
#   inflating: content/dataset/ml1m-images/2245.jpg
#   inflating: content/dataset/ml1m-images/3670.jpg
#   inflating: content/dataset/ml1m-images/339.jpg
#   inflating: content/dataset/ml1m-images/147.jpg
#   inflating: content/dataset/ml1m-images/1595.jpg
#   inflating: content/dataset/ml1m-images/3624.jpg
#   inflating: content/dataset/ml1m-images/2683.jpg
#   inflating: content/dataset/ml1m-images/2301.jpg
#   inflating: content/dataset/ml1m-images/1725.jpg
#   inflating: content/dataset/ml1m-images/415.jpg
#   inflating: content/dataset/ml1m-images/1206.jpg
#   inflating: content/dataset/ml1m-images/3826.jpg
#   inflating: content/dataset/ml1m-images/2390.jpg
#   inflating: content/dataset/ml1m-images/2187.jpg
#   inflating: content/dataset/ml1m-images/3711.jpg
#   inflating: content/dataset/ml1m-images/1253.jpg
#   inflating: content/dataset/ml1m-images/1747.jpg
#   inflating: content/dataset/ml1m-images/1611.jpg
#   inflating: content/dataset/ml1m-images/1922.jpg
#   inflating: content/dataset/ml1m-images/2108.jpg
#   inflating: content/dataset/ml1m-images/1518.jpg
#   inflating: content/dataset/ml1m-images/956.jpg
#   inflating: content/dataset/ml1m-images/2530.jpg
#   inflating: content/dataset/ml1m-images/525.jpg
#   inflating: content/dataset/ml1m-images/3780.jpg
#   inflating: content/dataset/ml1m-images/1682.jpg
#   inflating: content/dataset/ml1m-images/1025.jpg
#   inflating: content/dataset/ml1m-images/214.jpg
#   inflating: content/dataset/ml1m-images/2648.jpg
#   inflating: content/dataset/ml1m-images/3152.jpg
#   inflating: content/dataset/ml1m-images/1460.jpg
#   inflating: content/dataset/ml1m-images/3634.jpg
#   inflating: content/dataset/ml1m-images/2421.jpg
#   inflating: content/dataset/ml1m-images/2342.jpg
#   inflating: content/dataset/ml1m-images/2650.jpg
#   inflating: content/dataset/ml1m-images/2835.jpg
#   inflating: content/dataset/ml1m-images/532.jpg
#   inflating: content/dataset/ml1m-images/2376.jpg
#   inflating: content/dataset/ml1m-images/3702.jpg
#   inflating: content/dataset/ml1m-images/1749.jpg
#   inflating: content/dataset/ml1m-images/1671.jpg
#   inflating: content/dataset/ml1m-images/2257.jpg
#   inflating: content/dataset/ml1m-images/2113.jpg
#   inflating: content/dataset/ml1m-images/1482.jpg
#   inflating: content/dataset/ml1m-images/2434.jpg
#   inflating: content/dataset/ml1m-images/999.jpg
#   inflating: content/dataset/ml1m-images/3690.jpg
#   inflating: content/dataset/ml1m-images/2993.jpg
#   inflating: content/dataset/ml1m-images/1632.jpg
#   inflating: content/dataset/ml1m-images/44.jpg
#   inflating: content/dataset/ml1m-images/2612.jpg
#   inflating: content/dataset/ml1m-images/2123.jpg
#   inflating: content/dataset/ml1m-images/2520.jpg
#   inflating: content/dataset/ml1m-images/3404.jpg
#   inflating: content/dataset/ml1m-images/2112.jpg
#   inflating: content/dataset/ml1m-images/2494.jpg
#   inflating: content/dataset/ml1m-images/3635.jpg
#   inflating: content/dataset/ml1m-images/1356.jpg
#   inflating: content/dataset/ml1m-images/75.jpg
#   inflating: content/dataset/ml1m-images/1177.jpg
#   inflating: content/dataset/ml1m-images/1693.jpg
#   inflating: content/dataset/ml1m-images/1617.jpg
#   inflating: content/dataset/ml1m-images/3498.jpg
#   inflating: content/dataset/ml1m-images/1694.jpg
#   inflating: content/dataset/ml1m-images/669.jpg
#   inflating: content/dataset/ml1m-images/830.jpg
#   inflating: content/dataset/ml1m-images/103.jpg
#   inflating: content/dataset/ml1m-images/346.jpg
#   inflating: content/dataset/ml1m-images/2518.jpg
#   inflating: content/dataset/ml1m-images/1354.jpg
#   inflating: content/dataset/ml1m-images/2311.jpg
#   inflating: content/dataset/ml1m-images/2022.jpg
#   inflating: content/dataset/ml1m-images/187.jpg
#   inflating: content/dataset/ml1m-images/2605.jpg
#   inflating: content/dataset/ml1m-images/2279.jpg
#   inflating: content/dataset/ml1m-images/1426.jpg
#   inflating: content/dataset/ml1m-images/1864.jpg
#   inflating: content/dataset/ml1m-images/2121.jpg
#   inflating: content/dataset/ml1m-images/145.jpg
#   inflating: content/dataset/ml1m-images/1769.jpg
#   inflating: content/dataset/ml1m-images/3501.jpg
#   inflating: content/dataset/ml1m-images/78.jpg
#   inflating: content/dataset/ml1m-images/1168.jpg
#   inflating: content/dataset/ml1m-images/465.jpg
#   inflating: content/dataset/ml1m-images/3104.jpg
#   inflating: content/dataset/ml1m-images/3936.jpg
#   inflating: content/dataset/ml1m-images/942.jpg
#   inflating: content/dataset/ml1m-images/3089.jpg
#   inflating: content/dataset/ml1m-images/2937.jpg
#   inflating: content/dataset/ml1m-images/1643.jpg
#   inflating: content/dataset/ml1m-images/224.jpg
#   inflating: content/dataset/ml1m-images/2959.jpg
#   inflating: content/dataset/ml1m-images/1937.jpg
#   inflating: content/dataset/ml1m-images/1878.jpg
#   inflating: content/dataset/ml1m-images/2837.jpg
#   inflating: content/dataset/ml1m-images/1378.jpg
#   inflating: content/dataset/ml1m-images/2847.jpg
#   inflating: content/dataset/ml1m-images/1197.jpg
#   inflating: content/dataset/ml1m-images/3204.jpg
#   inflating: content/dataset/ml1m-images/87.jpg
#   inflating: content/dataset/ml1m-images/3389.jpg
#   inflating: content/dataset/ml1m-images/1943.jpg
#   inflating: content/dataset/ml1m-images/301.jpg
#   inflating: content/dataset/ml1m-images/3182.jpg
#   inflating: content/dataset/ml1m-images/1477.jpg
#   inflating: content/dataset/ml1m-images/1635.jpg
#   inflating: content/dataset/ml1m-images/2750.jpg
#   inflating: content/dataset/ml1m-images/2382.jpg
#   inflating: content/dataset/ml1m-images/376.jpg
#   inflating: content/dataset/ml1m-images/3897.jpg
#   inflating: content/dataset/ml1m-images/317.jpg
#   inflating: content/dataset/ml1m-images/2256.jpg
#   inflating: content/dataset/ml1m-images/1131.jpg
#   inflating: content/dataset/ml1m-images/542.jpg
#   inflating: content/dataset/ml1m-images/1646.jpg
#   inflating: content/dataset/ml1m-images/1541.jpg
#   inflating: content/dataset/ml1m-images/3810.jpg
#   inflating: content/dataset/ml1m-images/102.jpg
#   inflating: content/dataset/ml1m-images/2122.jpg
#   inflating: content/dataset/ml1m-images/3726.jpg
#   inflating: content/dataset/ml1m-images/1939.jpg
#   inflating: content/dataset/ml1m-images/2635.jpg
#   inflating: content/dataset/ml1m-images/1551.jpg
#   inflating: content/dataset/ml1m-images/408.jpg
#   inflating: content/dataset/ml1m-images/851.jpg
#   inflating: content/dataset/ml1m-images/1734.jpg
#   inflating: content/dataset/ml1m-images/1932.jpg
#   inflating: content/dataset/ml1m-images/432.jpg
#   inflating: content/dataset/ml1m-images/1032.jpg
#   inflating: content/dataset/ml1m-images/2548.jpg
#   inflating: content/dataset/ml1m-images/3302.jpg
#   inflating: content/dataset/ml1m-images/2815.jpg
#   inflating: content/dataset/ml1m-images/1379.jpg
#   inflating: content/dataset/ml1m-images/373.jpg
#   inflating: content/dataset/ml1m-images/3354.jpg
#   inflating: content/dataset/ml1m-images/3075.jpg
#   inflating: content/dataset/ml1m-images/3708.jpg
#   inflating: content/dataset/ml1m-images/239.jpg
#   inflating: content/dataset/ml1m-images/1942.jpg
#   inflating: content/dataset/ml1m-images/2493.jpg
#   inflating: content/dataset/ml1m-images/2021.jpg
#   inflating: content/dataset/ml1m-images/1417.jpg
#   inflating: content/dataset/ml1m-images/3529.jpg
#   inflating: content/dataset/ml1m-images/3841.jpg
#   inflating: content/dataset/ml1m-images/45.jpg
#   inflating: content/dataset/ml1m-images/3391.jpg
#   inflating: content/dataset/ml1m-images/1393.jpg
#   inflating: content/dataset/ml1m-images/1899.jpg
#   inflating: content/dataset/ml1m-images/573.jpg
#   inflating: content/dataset/ml1m-images/2714.jpg
#   inflating: content/dataset/ml1m-images/3740.jpg
#   inflating: content/dataset/ml1m-images/1547.jpg
#   inflating: content/dataset/ml1m-images/1389.jpg
#   inflating: content/dataset/ml1m-images/2314.jpg
#   inflating: content/dataset/ml1m-images/3871.jpg
#   inflating: content/dataset/ml1m-images/2034.jpg
#   inflating: content/dataset/ml1m-images/863.jpg
#   inflating: content/dataset/ml1m-images/2368.jpg
#   inflating: content/dataset/ml1m-images/352.jpg
#   inflating: content/dataset/ml1m-images/1416.jpg
#   inflating: content/dataset/ml1m-images/2154.jpg
#   inflating: content/dataset/ml1m-images/3494.jpg
#   inflating: content/dataset/ml1m-images/3585.jpg
#   inflating: content/dataset/ml1m-images/2015.jpg
#   inflating: content/dataset/ml1m-images/2088.jpg
#   inflating: content/dataset/ml1m-images/1213.jpg
#   inflating: content/dataset/ml1m-images/3707.jpg
#   inflating: content/dataset/ml1m-images/2820.jpg
#   inflating: content/dataset/ml1m-images/3547.jpg
#   inflating: content/dataset/ml1m-images/34.jpg
#   inflating: content/dataset/ml1m-images/991.jpg
#   inflating: content/dataset/ml1m-images/1408.jpg
#   inflating: content/dataset/ml1m-images/3357.jpg
#   inflating: content/dataset/ml1m-images/1949.jpg
#   inflating: content/dataset/ml1m-images/1446.jpg
#   inflating: content/dataset/ml1m-images/3681.jpg
#   inflating: content/dataset/ml1m-images/2575.jpg
#   inflating: content/dataset/ml1m-images/2186.jpg
#   inflating: content/dataset/ml1m-images/3622.jpg
#   inflating: content/dataset/ml1m-images/1542.jpg
#   inflating: content/dataset/ml1m-images/1523.jpg
#   inflating: content/dataset/ml1m-images/759.jpg
#   inflating: content/dataset/ml1m-images/1422.jpg
#   inflating: content/dataset/ml1m-images/3593.jpg
#   inflating: content/dataset/ml1m-images/3143.jpg
#   inflating: content/dataset/ml1m-images/6.jpg
#   inflating: content/dataset/ml1m-images/527.jpg
#   inflating: content/dataset/ml1m-images/541.jpg
#   inflating: content/dataset/ml1m-images/52.jpg
#   inflating: content/dataset/ml1m-images/180.jpg
#   inflating: content/dataset/ml1m-images/299.jpg
#   inflating: content/dataset/ml1m-images/257.jpg
#   inflating: content/dataset/ml1m-images/2306.jpg
#   inflating: content/dataset/ml1m-images/2499.jpg
#   inflating: content/dataset/ml1m-images/2349.jpg
#   inflating: content/dataset/ml1m-images/2400.jpg
#   inflating: content/dataset/ml1m-images/3644.jpg
#   inflating: content/dataset/ml1m-images/1485.jpg
#   inflating: content/dataset/ml1m-images/3791.jpg
#   inflating: content/dataset/ml1m-images/1732.jpg
#   inflating: content/dataset/ml1m-images/943.jpg
#   inflating: content/dataset/ml1m-images/3809.jpg
#   inflating: content/dataset/ml1m-images/1058.jpg
#   inflating: content/dataset/ml1m-images/3840.jpg
#   inflating: content/dataset/ml1m-images/2546.jpg
#   inflating: content/dataset/ml1m-images/179.jpg
#   inflating: content/dataset/ml1m-images/3120.jpg
#   inflating: content/dataset/ml1m-images/1952.jpg
#   inflating: content/dataset/ml1m-images/425.jpg
#   inflating: content/dataset/ml1m-images/3225.jpg
#   inflating: content/dataset/ml1m-images/2182.jpg
#   inflating: content/dataset/ml1m-images/3030.jpg
#   inflating: content/dataset/ml1m-images/3000.jpg
#   inflating: content/dataset/ml1m-images/2653.jpg
#   inflating: content/dataset/ml1m-images/1359.jpg
#   inflating: content/dataset/ml1m-images/3757.jpg
#   inflating: content/dataset/ml1m-images/1193.jpg
#   inflating: content/dataset/ml1m-images/1135.jpg
#   inflating: content/dataset/ml1m-images/3831.jpg
#   inflating: content/dataset/ml1m-images/1273.jpg
#   inflating: content/dataset/ml1m-images/903.jpg
#   inflating: content/dataset/ml1m-images/3251.jpg
#   inflating: content/dataset/ml1m-images/2720.jpg
#   inflating: content/dataset/ml1m-images/329.jpg
#   inflating: content/dataset/ml1m-images/762.jpg
#   inflating: content/dataset/ml1m-images/1873.jpg
#   inflating: content/dataset/ml1m-images/1427.jpg
#   inflating: content/dataset/ml1m-images/1125.jpg
#   inflating: content/dataset/ml1m-images/3545.jpg
#   inflating: content/dataset/ml1m-images/3.jpg
#   inflating: content/dataset/ml1m-images/2065.jpg
#   inflating: content/dataset/ml1m-images/3073.jpg
#   inflating: content/dataset/ml1m-images/3947.jpg
#   inflating: content/dataset/ml1m-images/2511.jpg
#   inflating: content/dataset/ml1m-images/3325.jpg
#   inflating: content/dataset/ml1m-images/1466.jpg
#   inflating: content/dataset/ml1m-images/3138.jpg
#   inflating: content/dataset/ml1m-images/2458.jpg
#   inflating: content/dataset/ml1m-images/2886.jpg
#   inflating: content/dataset/ml1m-images/1836.jpg
#   inflating: content/dataset/ml1m-images/3304.jpg
#   inflating: content/dataset/ml1m-images/1913.jpg
#   inflating: content/dataset/ml1m-images/1904.jpg
#   inflating: content/dataset/ml1m-images/3658.jpg
#   inflating: content/dataset/ml1m-images/3709.jpg
#   inflating: content/dataset/ml1m-images/231.jpg
#   inflating: content/dataset/ml1m-images/2266.jpg
#   inflating: content/dataset/ml1m-images/1305.jpg
#   inflating: content/dataset/ml1m-images/3313.jpg
#   inflating: content/dataset/ml1m-images/1779.jpg
#   inflating: content/dataset/ml1m-images/1951.jpg
#   inflating: content/dataset/ml1m-images/3103.jpg
#   inflating: content/dataset/ml1m-images/1153.jpg
#   inflating: content/dataset/ml1m-images/3094.jpg
#   inflating: content/dataset/ml1m-images/47.jpg
#   inflating: content/dataset/ml1m-images/2071.jpg
#   inflating: content/dataset/ml1m-images/1009.jpg
#   inflating: content/dataset/ml1m-images/3008.jpg
#   inflating: content/dataset/ml1m-images/418.jpg
#   inflating: content/dataset/ml1m-images/302.jpg
#   inflating: content/dataset/ml1m-images/55.jpg
#   inflating: content/dataset/ml1m-images/2753.jpg
#   inflating: content/dataset/ml1m-images/1094.jpg
#   inflating: content/dataset/ml1m-images/1958.jpg
#   inflating: content/dataset/ml1m-images/464.jpg
#   inflating: content/dataset/ml1m-images/263.jpg
#   inflating: content/dataset/ml1m-images/2449.jpg
#   inflating: content/dataset/ml1m-images/2691.jpg
#   inflating: content/dataset/ml1m-images/95.jpg
#   inflating: content/dataset/ml1m-images/2867.jpg
#   inflating: content/dataset/ml1m-images/2855.jpg
#   inflating: content/dataset/ml1m-images/835.jpg
#   inflating: content/dataset/ml1m-images/1640.jpg
#   inflating: content/dataset/ml1m-images/901.jpg
#   inflating: content/dataset/ml1m-images/2255.jpg
#   inflating: content/dataset/ml1m-images/84.jpg
#   inflating: content/dataset/ml1m-images/2155.jpg
#   inflating: content/dataset/ml1m-images/3180.jpg
#   inflating: content/dataset/ml1m-images/2759.jpg
#   inflating: content/dataset/ml1m-images/124.jpg
#   inflating: content/dataset/ml1m-images/626.jpg
#   inflating: content/dataset/ml1m-images/1261.jpg
#   inflating: content/dataset/ml1m-images/243.jpg
#   inflating: content/dataset/ml1m-images/3874.jpg
#   inflating: content/dataset/ml1m-images/1161.jpg
#   inflating: content/dataset/ml1m-images/1614.jpg
#   inflating: content/dataset/ml1m-images/2791.jpg
#   inflating: content/dataset/ml1m-images/2180.jpg
#   inflating: content/dataset/ml1m-images/2160.jpg
#   inflating: content/dataset/ml1m-images/3424.jpg
#   inflating: content/dataset/ml1m-images/2287.jpg
#   inflating: content/dataset/ml1m-images/1279.jpg
#   inflating: content/dataset/ml1m-images/2185.jpg
#   inflating: content/dataset/ml1m-images/1475.jpg
#   inflating: content/dataset/ml1m-images/674.jpg
#   inflating: content/dataset/ml1m-images/580.jpg
#   inflating: content/dataset/ml1m-images/3392.jpg
#   inflating: content/dataset/ml1m-images/914.jpg
#   inflating: content/dataset/ml1m-images/3900.jpg
#   inflating: content/dataset/ml1m-images/379.jpg
#   inflating: content/dataset/ml1m-images/3901.jpg
#   inflating: content/dataset/ml1m-images/19.jpg
#   inflating: content/dataset/ml1m-images/412.jpg
#   inflating: content/dataset/ml1m-images/1929.jpg
#   inflating: content/dataset/ml1m-images/2531.jpg
#   inflating: content/dataset/ml1m-images/3926.jpg
#   inflating: content/dataset/ml1m-images/2379.jpg
#   inflating: content/dataset/ml1m-images/2700.jpg
#   inflating: content/dataset/ml1m-images/58.jpg
#   inflating: content/dataset/ml1m-images/2532.jpg
#   inflating: content/dataset/ml1m-images/414.jpg
#   inflating: content/dataset/ml1m-images/63.jpg
#   inflating: content/dataset/ml1m-images/2110.jpg
#   inflating: content/dataset/ml1m-images/805.jpg
#   inflating: content/dataset/ml1m-images/1235.jpg
# ...
#   inflating: content/dataset/ml1m-images/3113.jpg
#   inflating: content/dataset/ml1m-images/982.jpg
#   inflating: content/dataset/ml1m-images/2935.jpg
#   inflating: content/dataset/ml1m-images/3338.jpg
#   inflating: content/dataset/ml1m-images/2059.jpg
#   inflating: content/dataset/ml1m-images/1210.jpg
#   inflating: content/dataset/ml1m-images/1699.jpg
#   inflating: content/dataset/ml1m-images/700.jpg
#   inflating: content/dataset/ml1m-images/1277.jpg
#   inflating: content/dataset/ml1m-images/269.jpg
#   inflating: content/dataset/ml1m-images/1688.jpg
#   inflating: content/dataset/ml1m-images/154.jpg
#   inflating: content/dataset/ml1m-images/3591.jpg
#   inflating: content/dataset/ml1m-images/3626.jpg
#   inflating: content/dataset/ml1m-images/2812.jpg
#   inflating: content/dataset/ml1m-images/3853.jpg
#   inflating: content/dataset/ml1m-images/3912.jpg
#   inflating: content/dataset/ml1m-images/3196.jpg
#   inflating: content/dataset/ml1m-images/2115.jpg
#   inflating: content/dataset/ml1m-images/1208.jpg
#   inflating: content/dataset/ml1m-images/1258.jpg
#   inflating: content/dataset/ml1m-images/3339.jpg
#   inflating: content/dataset/ml1m-images/3471.jpg
#   inflating: content/dataset/ml1m-images/2881.jpg
#   inflating: content/dataset/ml1m-images/1933.jpg
#   inflating: content/dataset/ml1m-images/1856.jpg
#   inflating: content/dataset/ml1m-images/798.jpg
#   inflating: content/dataset/ml1m-images/3099.jpg
#   inflating: content/dataset/ml1m-images/1254.jpg
#   inflating: content/dataset/ml1m-images/1411.jpg
#   inflating: content/dataset/ml1m-images/945.jpg
#   inflating: content/dataset/ml1m-images/543.jpg
#   inflating: content/dataset/ml1m-images/1006.jpg
#   inflating: content/dataset/ml1m-images/2471.jpg
#   inflating: content/dataset/ml1m-images/3642.jpg
#   inflating: content/dataset/ml1m-images/3945.jpg
#   inflating: content/dataset/ml1m-images/552.jpg
#   inflating: content/dataset/ml1m-images/1233.jpg
#   inflating: content/dataset/ml1m-images/2116.jpg
#   inflating: content/dataset/ml1m-images/2143.jpg
#   inflating: content/dataset/ml1m-images/1702.jpg
#   inflating: content/dataset/ml1m-images/2125.jpg
#   inflating: content/dataset/ml1m-images/2000.jpg
#   inflating: content/dataset/ml1m-images/1181.jpg
#   inflating: content/dataset/ml1m-images/3823.jpg
#   inflating: content/dataset/ml1m-images/122.jpg
#   inflating: content/dataset/ml1m-images/111.jpg
#   inflating: content/dataset/ml1m-images/2892.jpg
#   inflating: content/dataset/ml1m-images/440.jpg
#   inflating: content/dataset/ml1m-images/2655.jpg
#   inflating: content/dataset/ml1m-images/927.jpg
#   inflating: content/dataset/ml1m-images/2194.jpg
#   inflating: content/dataset/ml1m-images/227.jpg
#   inflating: content/dataset/ml1m-images/3713.jpg
#   inflating: content/dataset/ml1m-images/1912.jpg
#   inflating: content/dataset/ml1m-images/1683.jpg
#   inflating: content/dataset/ml1m-images/3596.jpg
#   inflating: content/dataset/ml1m-images/162.jpg
#   inflating: content/dataset/ml1m-images/3261.jpg
#   inflating: content/dataset/ml1m-images/105.jpg
#   inflating: content/dataset/ml1m-images/2670.jpg
#   inflating: content/dataset/ml1m-images/2013.jpg
#   inflating: content/dataset/ml1m-images/3872.jpg
#   inflating: content/dataset/ml1m-images/3610.jpg
#   inflating: content/dataset/ml1m-images/2312.jpg
#   inflating: content/dataset/ml1m-images/3320.jpg
#   inflating: content/dataset/ml1m-images/3218.jpg
#   inflating: content/dataset/ml1m-images/116.jpg
#   inflating: content/dataset/ml1m-images/841.jpg
#   inflating: content/dataset/ml1m-images/2893.jpg
#   inflating: content/dataset/ml1m-images/3526.jpg
#   inflating: content/dataset/ml1m-images/2424.jpg
#   inflating: content/dataset/ml1m-images/3880.jpg
#   inflating: content/dataset/ml1m-images/1240.jpg
#   inflating: content/dataset/ml1m-images/846.jpg
#   inflating: content/dataset/ml1m-images/1029.jpg
#   inflating: content/dataset/ml1m-images/3925.jpg
#   inflating: content/dataset/ml1m-images/65.jpg
#   inflating: content/dataset/ml1m-images/2060.jpg
#   inflating: content/dataset/ml1m-images/1335.jpg
#   inflating: content/dataset/ml1m-images/2903.jpg
#   inflating: content/dataset/ml1m-images/1188.jpg
#   inflating: content/dataset/ml1m-images/1762.jpg
#   inflating: content/dataset/ml1m-images/3837.jpg
#   inflating: content/dataset/ml1m-images/491.jpg
#   inflating: content/dataset/ml1m-images/2583.jpg
#   inflating: content/dataset/ml1m-images/166.jpg
#   inflating: content/dataset/ml1m-images/1270.jpg
#   inflating: content/dataset/ml1m-images/3943.jpg
#   inflating: content/dataset/ml1m-images/1625.jpg
#   inflating: content/dataset/ml1m-images/2947.jpg
#   inflating: content/dataset/ml1m-images/1562.jpg
#   inflating: content/dataset/ml1m-images/3053.jpg
#   inflating: content/dataset/ml1m-images/900.jpg
#   inflating: content/dataset/ml1m-images/2036.jpg
#   inflating: content/dataset/ml1m-images/1980.jpg
#   inflating: content/dataset/ml1m-images/2888.jpg
#   inflating: content/dataset/ml1m-images/1136.jpg
#   inflating: content/dataset/ml1m-images/2350.jpg
#   inflating: content/dataset/ml1m-images/1198.jpg
#   inflating: content/dataset/ml1m-images/423.jpg
#   inflating: content/dataset/ml1m-images/2051.jpg
#   inflating: content/dataset/ml1m-images/2107.jpg
#   inflating: content/dataset/ml1m-images/1840.jpg
#   inflating: content/dataset/ml1m-images/261.jpg
#   inflating: content/dataset/ml1m-images/1508.jpg
#   inflating: content/dataset/ml1m-images/349.jpg
#   inflating: content/dataset/ml1m-images/1493.jpg
#   inflating: content/dataset/ml1m-images/149.jpg
#   inflating: content/dataset/ml1m-images/2385.jpg
#   inflating: content/dataset/ml1m-images/372.jpg
#   inflating: content/dataset/ml1m-images/1916.jpg
#   inflating: content/dataset/ml1m-images/1581.jpg
#   inflating: content/dataset/ml1m-images/2152.jpg
#   inflating: content/dataset/ml1m-images/2046.jpg
#   inflating: content/dataset/ml1m-images/1218.jpg
#   inflating: content/dataset/ml1m-images/2726.jpg
#   inflating: content/dataset/ml1m-images/1620.jpg
#   inflating: content/dataset/ml1m-images/2931.jpg
#   inflating: content/dataset/ml1m-images/3029.jpg
#   inflating: content/dataset/ml1m-images/1996.jpg
#   inflating: content/dataset/ml1m-images/1648.jpg
#   inflating: content/dataset/ml1m-images/2038.jpg
#   inflating: content/dataset/ml1m-images/1826.jpg
#   inflating: content/dataset/ml1m-images/2118.jpg
#   inflating: content/dataset/ml1m-images/291.jpg
#   inflating: content/dataset/ml1m-images/2642.jpg
#   inflating: content/dataset/ml1m-images/973.jpg
#   inflating: content/dataset/ml1m-images/1119.jpg
#   inflating: content/dataset/ml1m-images/3153.jpg
#   inflating: content/dataset/ml1m-images/3817.jpg
#   inflating: content/dataset/ml1m-images/3329.jpg
#   inflating: content/dataset/ml1m-images/3638.jpg
#   inflating: content/dataset/ml1m-images/3774.jpg
#   inflating: content/dataset/ml1m-images/923.jpg
#   inflating: content/dataset/ml1m-images/1246.jpg
#   inflating: content/dataset/ml1m-images/1898.jpg
#   inflating: content/dataset/ml1m-images/3096.jpg
#   inflating: content/dataset/ml1m-images/2463.jpg
#   inflating: content/dataset/ml1m-images/2965.jpg
#   inflating: content/dataset/ml1m-images/1.jpg
#   inflating: content/dataset/ml1m-images/3214.jpg
#   inflating: content/dataset/ml1m-images/3639.jpg
#   inflating: content/dataset/ml1m-images/182.jpg
#   inflating: content/dataset/ml1m-images/1669.jpg
#   inflating: content/dataset/ml1m-images/3704.jpg
#   inflating: content/dataset/ml1m-images/708.jpg
#   inflating: content/dataset/ml1m-images/2106.jpg
#   inflating: content/dataset/ml1m-images/123.jpg
#   inflating: content/dataset/ml1m-images/3447.jpg
#   inflating: content/dataset/ml1m-images/848.jpg
#   inflating: content/dataset/ml1m-images/2303.jpg
#   inflating: content/dataset/ml1m-images/2766.jpg
#   inflating: content/dataset/ml1m-images/2232.jpg
#   inflating: content/dataset/ml1m-images/1091.jpg
#   inflating: content/dataset/ml1m-images/1609.jpg
#   inflating: content/dataset/ml1m-images/2780.jpg
#   inflating: content/dataset/ml1m-images/2321.jpg
#   inflating: content/dataset/ml1m-images/767.jpg
#   inflating: content/dataset/ml1m-images/3534.jpg
#   inflating: content/dataset/ml1m-images/344.jpg
#   inflating: content/dataset/ml1m-images/1500.jpg
#   inflating: content/dataset/ml1m-images/3845.jpg
#   inflating: content/dataset/ml1m-images/2521.jpg
#   inflating: content/dataset/ml1m-images/3018.jpg
#   inflating: content/dataset/ml1m-images/507.jpg
#   inflating: content/dataset/ml1m-images/3269.jpg
#   inflating: content/dataset/ml1m-images/3741.jpg
#   inflating: content/dataset/ml1m-images/335.jpg
#   inflating: content/dataset/ml1m-images/1022.jpg
#   inflating: content/dataset/ml1m-images/519.jpg
#   inflating: content/dataset/ml1m-images/3793.jpg
#   inflating: content/dataset/ml1m-images/842.jpg
#   inflating: content/dataset/ml1m-images/1879.jpg
#   inflating: content/dataset/ml1m-images/2288.jpg
#   inflating: content/dataset/ml1m-images/1203.jpg
#   inflating: content/dataset/ml1m-images/1013.jpg
#   inflating: content/dataset/ml1m-images/325.jpg
#   inflating: content/dataset/ml1m-images/2598.jpg
#   inflating: content/dataset/ml1m-images/2883.jpg
#   inflating: content/dataset/ml1m-images/3317.jpg
#   inflating: content/dataset/ml1m-images/1586.jpg
#   inflating: content/dataset/ml1m-images/765.jpg
#   inflating: content/dataset/ml1m-images/1690.jpg
#   inflating: content/dataset/ml1m-images/2877.jpg
#   inflating: content/dataset/ml1m-images/2243.jpg
#   inflating: content/dataset/ml1m-images/1095.jpg
#   inflating: content/dataset/ml1m-images/3698.jpg
#   inflating: content/dataset/ml1m-images/2291.jpg
#   inflating: content/dataset/ml1m-images/1917.jpg
#   inflating: content/dataset/ml1m-images/1298.jpg
#   inflating: content/dataset/ml1m-images/3660.jpg
#   inflating: content/dataset/ml1m-images/2082.jpg
#   inflating: content/dataset/ml1m-images/1552.jpg
#   inflating: content/dataset/ml1m-images/1353.jpg
#   inflating: content/dataset/ml1m-images/177.jpg
#   inflating: content/dataset/ml1m-images/1324.jpg
#   inflating: content/dataset/ml1m-images/1046.jpg
#   inflating: content/dataset/ml1m-images/490.jpg
#   inflating: content/dataset/ml1m-images/1008.jpg
#   inflating: content/dataset/ml1m-images/1431.jpg
#   inflating: content/dataset/ml1m-images/3235.jpg
#   inflating: content/dataset/ml1m-images/581.jpg
#   inflating: content/dataset/ml1m-images/2087.jpg
#   inflating: content/dataset/ml1m-images/548.jpg
#   inflating: content/dataset/ml1m-images/616.jpg
#   inflating: content/dataset/ml1m-images/2456.jpg
#   inflating: content/dataset/ml1m-images/1382.jpg
#   inflating: content/dataset/ml1m-images/866.jpg
#   inflating: content/dataset/ml1m-images/3725.jpg
#   inflating: content/dataset/ml1m-images/225.jpg
#   inflating: content/dataset/ml1m-images/1876.jpg
#   inflating: content/dataset/ml1m-images/1549.jpg
#   inflating: content/dataset/ml1m-images/1865.jpg
#   inflating: content/dataset/ml1m-images/2150.jpg
#   inflating: content/dataset/ml1m-images/600.jpg
#   inflating: content/dataset/ml1m-images/2928.jpg
#   inflating: content/dataset/ml1m-images/2523.jpg
#   inflating: content/dataset/ml1m-images/3091.jpg
#   inflating: content/dataset/ml1m-images/206.jpg
#   inflating: content/dataset/ml1m-images/1837.jpg
#   inflating: content/dataset/ml1m-images/3021.jpg
#   inflating: content/dataset/ml1m-images/2870.jpg
#   inflating: content/dataset/ml1m-images/14.jpg
#   inflating: content/dataset/ml1m-images/121.jpg
#   inflating: content/dataset/ml1m-images/219.jpg
#   inflating: content/dataset/ml1m-images/2094.jpg
#   inflating: content/dataset/ml1m-images/2326.jpg
#   inflating: content/dataset/ml1m-images/2900.jpg
#   inflating: content/dataset/ml1m-images/3918.jpg
#   inflating: content/dataset/ml1m-images/1771.jpg
#   inflating: content/dataset/ml1m-images/1883.jpg
#   inflating: content/dataset/ml1m-images/3924.jpg
#   inflating: content/dataset/ml1m-images/648.jpg
#   inflating: content/dataset/ml1m-images/1224.jpg
#   inflating: content/dataset/ml1m-images/1051.jpg
#   inflating: content/dataset/ml1m-images/2794.jpg
#   inflating: content/dataset/ml1m-images/2265.jpg
#   inflating: content/dataset/ml1m-images/2537.jpg
#   inflating: content/dataset/ml1m-images/3132.jpg
#   inflating: content/dataset/ml1m-images/1748.jpg
#   inflating: content/dataset/ml1m-images/1334.jpg
#   inflating: content/dataset/ml1m-images/2925.jpg
#   inflating: content/dataset/ml1m-images/2405.jpg
#   inflating: content/dataset/ml1m-images/3271.jpg
#   inflating: content/dataset/ml1m-images/2560.jpg
#   inflating: content/dataset/ml1m-images/2432.jpg
#   inflating: content/dataset/ml1m-images/1810.jpg
#   inflating: content/dataset/ml1m-images/3258.jpg
#   inflating: content/dataset/ml1m-images/3822.jpg
#   inflating: content/dataset/ml1m-images/3013.jpg
#   inflating: content/dataset/ml1m-images/1626.jpg
#   inflating: content/dataset/ml1m-images/986.jpg
#   inflating: content/dataset/ml1m-images/3399.jpg
#   inflating: content/dataset/ml1m-images/300.jpg
#   inflating: content/dataset/ml1m-images/3758.jpg
#   inflating: content/dataset/ml1m-images/1262.jpg
#   inflating: content/dataset/ml1m-images/917.jpg
#   inflating: content/dataset/ml1m-images/946.jpg
#   inflating: content/dataset/ml1m-images/3736.jpg
#   inflating: content/dataset/ml1m-images/1580.jpg
#   inflating: content/dataset/ml1m-images/2412.jpg
#   inflating: content/dataset/ml1m-images/3426.jpg
#   inflating: content/dataset/ml1m-images/745.jpg
#   inflating: content/dataset/ml1m-images/1934.jpg
#   inflating: content/dataset/ml1m-images/3432.jpg
#   inflating: content/dataset/ml1m-images/2924.jpg
#   inflating: content/dataset/ml1m-images/2779.jpg
#   inflating: content/dataset/ml1m-images/242.jpg
#   inflating: content/dataset/ml1m-images/293.jpg
#   inflating: content/dataset/ml1m-images/2067.jpg
#   inflating: content/dataset/ml1m-images/393.jpg
#   inflating: content/dataset/ml1m-images/1564.jpg
#   inflating: content/dataset/ml1m-images/3141.jpg
#   inflating: content/dataset/ml1m-images/1674.jpg
#   inflating: content/dataset/ml1m-images/24.jpg
#   inflating: content/dataset/ml1m-images/2052.jpg
#   inflating: content/dataset/ml1m-images/1080.jpg
#   inflating: content/dataset/ml1m-images/638.jpg
#   inflating: content/dataset/ml1m-images/60.jpg
#   inflating: content/dataset/ml1m-images/710.jpg
#   inflating: content/dataset/ml1m-images/3239.jpg
#   inflating: content/dataset/ml1m-images/1875.jpg
#   inflating: content/dataset/ml1m-images/336.jpg
#   inflating: content/dataset/ml1m-images/212.jpg
#   inflating: content/dataset/ml1m-images/1814.jpg
#   inflating: content/dataset/ml1m-images/2620.jpg
#   inflating: content/dataset/ml1m-images/249.jpg
#   inflating: content/dataset/ml1m-images/2447.jpg
#   inflating: content/dataset/ml1m-images/761.jpg
#   inflating: content/dataset/ml1m-images/3301.jpg
#   inflating: content/dataset/ml1m-images/3208.jpg
#   inflating: content/dataset/ml1m-images/3540.jpg
#   inflating: content/dataset/ml1m-images/920.jpg
#   inflating: content/dataset/ml1m-images/2292.jpg
#   inflating: content/dataset/ml1m-images/2097.jpg
#   inflating: content/dataset/ml1m-images/1441.jpg
#   inflating: content/dataset/ml1m-images/434.jpg
#   inflating: content/dataset/ml1m-images/806.jpg
#   inflating: content/dataset/ml1m-images/1550.jpg
#   inflating: content/dataset/ml1m-images/512.jpg
#   inflating: content/dataset/ml1m-images/2943.jpg
#   inflating: content/dataset/ml1m-images/2841.jpg
#   inflating: content/dataset/ml1m-images/645.jpg
#   inflating: content/dataset/ml1m-images/462.jpg
#   inflating: content/dataset/ml1m-images/3577.jpg
#   inflating: content/dataset/ml1m-images/3326.jpg
#   inflating: content/dataset/ml1m-images/1241.jpg
#   inflating: content/dataset/ml1m-images/2191.jpg

# %%
# !pip install -q torchmetrics
from torchmetrics.classification import MultilabelF1Score

import torch
import torch.nn as nn
import torch.optim as optim
import torch.nn.functional as F

from torchvision import models
from torchvision.models import ResNet18_Weights
from torch.utils.data import Dataset, DataLoader, random_split


import matplotlib.pyplot as plt
import matplotlib.image as mpimg

import os
import re
import cv2
import pandas
import numpy as np

from nltk import wordpunct_tokenize
# Out:
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 806.1/806.1 kB 4.6 MB/s eta 0:00:00

# %% [markdown]
# ## Some hyper parameters

# %%
BATCH_SIZE = 16
hidden_size = 128

# %% [markdown]
# # DATA PROCESSING
# ## Parse .csv into dataframe

# %%
movies_train = pandas.read_csv('/content/project/content/dataset/movies_train.dat', engine='python',
                         sep='::', names=['movie_id', 'title', 'genre'], encoding='latin-1', index_col=False).set_index('movie_id')
movies_test = pandas.read_csv('/content/project/content/dataset/movies_test.dat', engine='python',
                         sep='::', names=['movie_id', 'title', 'genre'], encoding='latin-1', index_col=False).set_index('movie_id')
movies_train['genre'] = movies_train.genre.str.split('|')
movies_test['genre'] = movies_test.genre.str.split('|')

source_img_folder = '/content/project/content/dataset/ml1m-images'
movies_train['title'] = movies_train.title.str[:-6]
movies_test['title'] = movies_test.title.str[:-6]
movies_train['id'] = movies_train.index
movies_train.reset_index(inplace=True)
movies_test['id'] = movies_test.index
movies_test.reset_index(inplace=True)

movies_test['img_path'] = movies_test.apply(lambda row: os.path.join(source_img_folder, f'{row.id}.jpg'), axis = 1)
movies_train['img_path'] = movies_train.apply(lambda row: os.path.join(source_img_folder, f'{row.id}.jpg'), axis = 1)

movies_train
# Out:
#       movie_id                   title  \
# 0         1650      Washington Square
# 1          185               Net, The
# 2         1377         Batman Returns
# 3         3204  Boys from Brazil, The
# 4         1901             Dear Jesse
# ...        ...                     ...
# 3101      2539           Analyze This
# 3102      3038   Face in the Crowd, A
# 3103      1832       Heaven's Burning
# 3104       657            Yankee Zulu
# 3105      1750               Star Kid
#
#                                          genre    id  \
# 0                                      [Drama]  1650
# 1                           [Sci-Fi, Thriller]   185
# 2           [Action, Adventure, Comedy, Crime]  1377
# 3                                   [Thriller]  3204
# 4                                [Documentary]  1901
# ...                                        ...   ...
# 3101                                  [Comedy]  2539
# 3102                                   [Drama]  3038
# 3103                           [Action, Drama]  1832
# 3104                           [Comedy, Drama]   657
# 3105  [Adventure, Children's, Fantasy, Sci-Fi]  1750
#
#                                                img_path
# 0     /content/project/content/dataset/ml1m-images/1...
# 1     /content/project/content/dataset/ml1m-images/1...
# 2     /content/project/content/dataset/ml1m-images/1...
# 3     /content/project/content/dataset/ml1m-images/3...
# 4     /content/project/content/dataset/ml1m-images/1...
# ...                                                 ...
# 3101  /content/project/content/dataset/ml1m-images/2...
# 3102  /content/project/content/dataset/ml1m-images/3...
# 3103  /content/project/content/dataset/ml1m-images/1...
# 3104  /content/project/content/dataset/ml1m-images/6...
# 3105  /content/project/content/dataset/ml1m-images/1...
#
# [3106 rows x 5 columns]

# %% [markdown]
# ## Process data

# %%
with open('/content/project/content/dataset/genres.txt', 'r') as f:
    genre_all = f.readlines()
num_classes = len(genre_all)
for i, genre in enumerate(genre_all):
  genre_all[i] = genre.strip('\n')

train_dropped = 0
test_dropped  = 0

for index, row in movies_train.iterrows():
  image_path = row['img_path']
  if not os.path.exists(image_path):
    movies_train.drop(index, inplace=True)
    train_dropped += 1

print(f"Number of data train without image: {train_dropped}")

for index, row in movies_test.iterrows():
  image_path = row['img_path']
  if not os.path.exists(image_path):
    movies_test.drop(index, inplace=True)
    test_dropped += 1

print(f"Number of data test without image: {test_dropped}")
# Out:
# Number of data train without image: 504
# Number of data test without image: 123

# %% [markdown]
# ## Visualize data train

# %%
df_exploded = movies_train.explode('genre')
genre_counts = df_exploded['genre'].value_counts()
genre_counts.plot(kind='bar', rot=45, xlabel='Genre', ylabel='Number', title='Train Distribution')
plt.show()
class_count = []
for count in genre_counts:
  class_count.append(count)
print(class_count)
# Out:
# [1007, 832, 384, 349, 345, 244, 223, 219, 196, 161, 110, 96, 83, 79, 58, 53, 51, 34]

# %% [markdown]
# ## Visualize data test

# %%
df_exploded = movies_test.explode('genre')
genre_counts = df_exploded['genre'].value_counts()
genre_counts.plot(kind='bar', rot=45, xlabel='Genre', ylabel='Number', title='Test Distribution')
plt.show()

# %% [markdown]
# ## Build Vocabulary list

# %%
pad_token = '<PAD>'
unk_token = '<UNK>'
def tokenize(text):
  text = re.sub(r'[^\w\s]', '', text)
  text = text.lower()
  tokens = wordpunct_tokenize(text)
  return tokens

def create_vocab():
  df = movies_train.copy()
  arr_title = df['title'].tolist()
  vocab = set()
  for title in arr_title:
    tokens = tokenize(title)
    vocab.update(tokens)
  vocab = list(vocab)
  vocab.append(pad_token)
  vocab.append(unk_token)
  return vocab

# %% [markdown]
# ## Dataset type

# %%
"""
Abstract class of Dataset.
According to document, need these attributes: __init__, __getitem__
__len__ is optional
"""
class customDataset(Dataset):
  def __init__(self, data):
    self.data = data
    self.data['title_tokens'] = [tokenize(x) for x in self.data.title]
    vocab = create_vocab()
    self.token2idx = {token : idx for idx, token in enumerate(vocab)}
    #print(self.token2idx)
    MAX_LENGTH = 7
    vectors = []
    for title_tokens in self.data.title_tokens.tolist():
      if len(title_tokens) < MAX_LENGTH:
        num_pad = MAX_LENGTH - len(title_tokens)
        for idx in range(num_pad):
          title_tokens.append(pad_token)
      else:
        title_tokens = title_tokens[:MAX_LENGTH]
      title_vectors = []
      for word in title_tokens:
        binary_vector = np.zeros(len(vocab))
        if word in vocab:
          binary_vector[self.token2idx[word]] = 1
        else:
          binary_vector[self.token2idx[unk_token]] = 1
        title_vectors.append(binary_vector)

      vectors.append(np.array(title_vectors))
    self.data['vectors'] = vectors
    with open('/content/project/content/dataset/genres.txt', 'r') as f:
      genres = f.readlines()
      genres = [genre.strip('\n') for genre in genres]
    self.genre2idx = {genre : idx for idx, genre in enumerate(genres)}
  def __getitem__(self, index):
    title = self.data.iloc[index].title
    img_path = self.data.iloc[index].img_path
    genre = self.data.iloc[index].genre

    title_vector = self.data.iloc[index].vectors
    title_tensor = torch.from_numpy(title_vector).float()

    if os.path.exists(img_path):
      img = cv2.imread(img_path)
    else:
      img = np.random.rand(256,256,3)
    img = cv2.resize(img, (256,256))
    img_tensor = torch.from_numpy(img.transpose(2,0,1)).float()
    genre_vector = np.zeros(len(self.genre2idx))
    for g in genre:
      genre_vector[self.genre2idx[g]] = 1
    genre_tensor = torch.from_numpy(genre_vector).float()

    return title_tensor, img_tensor, genre_tensor

  def __len__(self):
    return len(self.data)

# %%
training_set = customDataset(data = movies_train)
testing_set = customDataset(data = movies_test)
len(testing_set)
# Out:
# 654

# %% [markdown]
# ## Split data into train and validation

# %%
# Random split validation set, training set and initialize testing set
val_size = int(0.2 * len(training_set))
train_size = len(training_set) - val_size
train_set, val_set = random_split(training_set, [train_size, val_size])
train_dataloader = DataLoader(train_set, batch_size=BATCH_SIZE)
val_dataloader = DataLoader(val_set, batch_size = BATCH_SIZE)
test_dataloader = DataLoader(testing_set, batch_size=BATCH_SIZE)
len(test_dataloader)
# Out:
# 41

# %%
for title_tensor, img_tensor, genre_tensor in train_dataloader:
  print(title_tensor.shape, img_tensor.shape, genre_tensor.shape)
  break
for title_tensor, img_tensor, genre_tensor in test_dataloader:
  print(title_tensor.shape, img_tensor.shape, genre_tensor.shape)
  break
# Out:
# torch.Size([16, 7, 3321]) torch.Size([16, 3, 256, 256]) torch.Size([16, 18])
# torch.Size([16, 7, 3321]) torch.Size([16, 3, 256, 256]) torch.Size([16, 18])

# %%
# Init vocaburary list and double check
vocab = create_vocab()
len_vocab = len(vocab)
len_vocab
# Out:
# 3321

# %% [markdown]
# # FIRST APPROACH
# ## Base model with conv and maxpool layer for image
# ## Only linear layer for text

# %%
######################################
############DEPRECATED################
######################################
# Do not use, stay here for report
class deprecated_model(nn.Module):
  def __init__(self):
    super(deprecated_model, self).__init__()
    self.hidden_size = hidden_size

    # img
    self.conv1 = nn.Conv2d(3, 16, kernel_size=3, stride=1, padding=1)
    self.maxpool = nn.MaxPool2d(kernel_size=4, stride=4)
    self.conv2 = nn.Conv2d(16, 32, kernel_size=3, stride=1, padding=1)
    self.bn2 = nn.BatchNorm2d(32)
    self.flatten = nn.Flatten()
    self.fc1 = nn.Linear(32 * 64 * 64, hidden_size)

    # text
    self.fc2 = nn.Linear(7*len_vocab, hidden_size)
    self.fc3 = nn.Linear(hidden_size*2, num_classes)

  def forward(self, title_tensor, img_tensor):
    text_feat = F.relu(self.fc2(self.flatten(title_tensor)))
    img_feat = self.conv1(img_tensor)
    img_feat = F.relu(self.maxpool(img_feat))
    img_feat = self.conv2(img_feat)
    img_feat = F.relu(self.fc1(self.flatten(img_feat)))

    out = self.fc3(torch.cat([text_feat, img_feat], dim=1))
    return out

# %% [markdown]
# # SECOND APPROACH
# ## Using ResNet18 hopefully to improve quality

# %%
# TODO: Try better base model i guess
"""
Abstract class of nn.Module.
Using pretrained Resnet18 for image process.
Number of output neurons = number of classes
"""
class BaseModel(nn.Module):
  def __init__(self):
    super(BaseModel, self).__init__()
    self.hidden_size = hidden_size

    # img
    resnet18 = models.resnet18(weights=ResNet18_Weights.IMAGENET1K_V1)
    self.resnet18_features = nn.Sequential(*list(resnet18.children())[:-1])
    self.bn2 = nn.BatchNorm2d(512)

    # text
    self.fc1 = nn.Linear(7*len_vocab, hidden_size)
    self.flatten = nn.Flatten()

    # combine
    self.fc2 = nn.Linear(hidden_size + 512, hidden_size)

    # out
    self.fc3 = nn.Linear(hidden_size, num_classes)

  def forward(self, title_tensor, img_tensor):

    # Text feature
    text_feat = F.relu(self.fc1(self.flatten(title_tensor)))

    # Img feature
    img_feat = self.resnet18_features(img_tensor)
    img_feat = F.relu(self.bn2(img_feat))
    img_feat = img_feat.view(img_feat.size(0), -1)

    # Combine feature
    combined_feat = torch.cat([text_feat, img_feat], dim=1)
    combined_feat = F.relu(self.fc2(combined_feat))

    # Out feature
    out = self.fc3(combined_feat)
    return out

# %% [markdown]
# # THIRD APPROACH
# ## Trying to modify weight to solve imbalance data problem

# %%
class_weight = 1.0 / torch.tensor(class_count, dtype=torch.float)
class_weight /= class_weight.sum()
class_weight
# Out:
# tensor([0.0060, 0.0073, 0.0158, 0.0174, 0.0176, 0.0249, 0.0273, 0.0278, 0.0310,
#         0.0378, 0.0553, 0.0634, 0.0733, 0.0770, 0.1049, 0.1148, 0.1193, 0.1789])

# %%
class_weight[0] *= 10
class_weight[1] *= 10
class_weight /= class_weight.sum()
class_weight
# Out:
# tensor([0.0539, 0.0653, 0.0141, 0.0156, 0.0157, 0.0223, 0.0244, 0.0248, 0.0277,
#         0.0337, 0.0494, 0.0566, 0.0654, 0.0687, 0.0936, 0.1025, 0.1065, 0.1597])

# %% [markdown]
# # Multiple attemps on tuning parameters, loss function and weight
# ## Implementation attempt of dropout and early stop

# %%
# TODO: Implementation of dropout and weight save (especially best weight save)
def train(model, train_loader, val_loader, criterion, optimizer, num_epochs, dropout_prob, early_stopping_patience):
  """
  Train function
  ---------
  Params:
  model:  abstract class of nn.Module
          trained model
  train_loader: Dataloader
                for train set
  val_loader: Dataloader
              for val set
  criterion:  loss function
  num_epochs: int
              number of epochs to train
  dropout_prob: int | None
  early_stopping_patience:  int | None
                            How many time of no improvement on validation set to stop
  --------
  """
  best_val_loss = float('inf')
  patience_counter = 0
  train_losses = []
  val_losses = []
  for epoch in range(num_epochs):
    # Train process implementation
    model.train()
    total_loss = 0.0
    for batch_idx, (title_tensor, img_tensor, genre_tensor) in enumerate(train_loader):
      title_tensor, img_tensor, genre_tensor = title_tensor.to(device), img_tensor.to(device), genre_tensor.to(device)

      optimizer.zero_grad()

      outputs = model(title_tensor, img_tensor)
      loss = criterion(outputs, genre_tensor)

      loss.backward()
      optimizer.step()

      total_loss += loss.item()
      if batch_idx % 100 == 99:
        print(f"Epoch {epoch + 1}, Batch {batch_idx + 1}, Training Loss: {total_loss / 100:.4f}")
        total_loss = 0.0
    train_losses.append(total_loss / len(train_loader))
    # Validation process implementation
    model.eval()
    val_loss = 0.0
    all_predictions = []
    all_labels = []
    with torch.no_grad():
      for val_title_tensor, val_img_tensor, val_genre_tensor in val_loader:
        val_title_tensor, val_img_tensor, val_genre_tensor = val_title_tensor.to(device), val_img_tensor.to(device), val_genre_tensor.to(device)
        val_outputs = model(val_title_tensor, val_img_tensor)
        val_loss += criterion(val_outputs, val_genre_tensor).item()
        all_predictions.extend((val_outputs > 0.5).float().cpu().numpy())
        all_labels.extend(val_genre_tensor.cpu().numpy())
    val_loss /= len(val_loader)
    val_losses.append(val_loss)
    print(f"Epoch {epoch + 1}, Validation Loss: {val_loss:.4f}")

    all_predictions = torch.tensor(all_predictions).to(device)
    all_labels = torch.tensor(all_labels).to(device)
    f1_val = f1(all_predictions, all_labels)
    print(f"Epoch {epoch + 1}, F1 Score (Validation): {f1_val:.4f}")

    # Early stopping implementation
    if early_stopping_patience is not None:
      if val_loss < best_val_loss:
        best_val_loss = val_loss
        patience_counter = 0
      else:
        patience_counter += 1
        if patience_counter >= early_stopping_patience:
          print(f"Early stopped. No improvement for {early_stopping_patience} epochs.")
          break
  epochs = np.arange(1, num_epochs + 1)
  plt.plot(epochs, train_losses, label='Training Loss')
  plt.plot(epochs, val_losses, label='Validation Loss')
  plt.xlabel('Epoch')
  plt.ylabel('Loss')
  plt.legend()
  plt.title('Training and Validation Losses')
  plt.show()
  print("Done")

model = BaseModel()
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
model.to(device)

# Init F1
N, C = genre_tensor.shape
f1_all = 0
f1 = MultilabelF1Score(num_labels=C, threshold=0.5, average='macro')
f1 = f1.to(device)

# Call the train method with neccessary variables
learning_rate = 0.001
dropout_prob=None
early_stopping_patience=None
num_epochs=20
criterion = nn.BCEWithLogitsLoss()
criterion.to(device)
optimizer = optim.Adam(model.parameters(), lr=learning_rate)
train(model, train_dataloader, val_dataloader, criterion, optimizer, num_epochs=num_epochs, dropout_prob=dropout_prob, early_stopping_patience=early_stopping_patience)
# Out:
# Epoch 1, Batch 100, Training Loss: 0.3001
# Epoch 1, Validation Loss: 0.2850
# Epoch 1, F1 Score (Validation): 0.0172
# Epoch 2, Batch 100, Training Loss: 0.2638
# Epoch 2, Validation Loss: 0.2694
# Epoch 2, F1 Score (Validation): 0.0033
# Epoch 3, Batch 100, Training Loss: 0.2498
# Epoch 3, Validation Loss: 0.2640
# Epoch 3, F1 Score (Validation): 0.0176
# Epoch 4, Batch 100, Training Loss: 0.2203
# Epoch 4, Validation Loss: 0.2563
# Epoch 4, F1 Score (Validation): 0.0500
# Epoch 5, Batch 100, Training Loss: 0.1794
# Epoch 5, Validation Loss: 0.2621
# Epoch 5, F1 Score (Validation): 0.0745
# Epoch 6, Batch 100, Training Loss: 0.1348
# Epoch 6, Validation Loss: 0.2852
# Epoch 6, F1 Score (Validation): 0.0999
# Epoch 7, Batch 100, Training Loss: 0.1035
# Epoch 7, Validation Loss: 0.3037
# Epoch 7, F1 Score (Validation): 0.1266
# Epoch 8, Batch 100, Training Loss: 0.0834
# Epoch 8, Validation Loss: 0.3472
# Epoch 8, F1 Score (Validation): 0.1334
# Epoch 9, Batch 100, Training Loss: 0.0746
# Epoch 9, Validation Loss: 0.3675
# Epoch 9, F1 Score (Validation): 0.1648
# Epoch 10, Batch 100, Training Loss: 0.0606
# Epoch 10, Validation Loss: 0.4223
# Epoch 10, F1 Score (Validation): 0.1417
# Epoch 11, Batch 100, Training Loss: 0.0497
# Epoch 11, Validation Loss: 0.4011
# Epoch 11, F1 Score (Validation): 0.1565
# Epoch 12, Batch 100, Training Loss: 0.0351
# Epoch 12, Validation Loss: 0.4633
# Epoch 12, F1 Score (Validation): 0.1574
# Epoch 13, Batch 100, Training Loss: 0.0272
# Epoch 13, Validation Loss: 0.4826
# Epoch 13, F1 Score (Validation): 0.1513
# Epoch 14, Batch 100, Training Loss: 0.0195
# Epoch 14, Validation Loss: 0.5003
# Epoch 14, F1 Score (Validation): 0.1663
# Epoch 15, Batch 100, Training Loss: 0.0146
# Epoch 15, Validation Loss: 0.5180
# Epoch 15, F1 Score (Validation): 0.1756
# Epoch 16, Batch 100, Training Loss: 0.0117
# Epoch 16, Validation Loss: 0.5371
# Epoch 16, F1 Score (Validation): 0.1709
# Epoch 17, Batch 100, Training Loss: 0.0094
# Epoch 17, Validation Loss: 0.5467
# Epoch 17, F1 Score (Validation): 0.1804
# Epoch 18, Batch 100, Training Loss: 0.0071
# Epoch 18, Validation Loss: 0.5852
# Epoch 18, F1 Score (Validation): 0.1706
# Epoch 19, Batch 100, Training Loss: 0.0053
# Epoch 19, Validation Loss: 0.6033
# Epoch 19, F1 Score (Validation): 0.1631
# Epoch 20, Batch 100, Training Loss: 0.0038
# Epoch 20, Validation Loss: 0.6598
# Epoch 20, F1 Score (Validation): 0.1648
# Done

# %%
# Double check the dimensions of tensors, useful when coding
for items in test_dataloader:
  title_tensor, img_tensor, genre_tensor = items
  print("Title Tensor Sizes:", title_tensor.size())
  print("Image Tensor Sizes:", img_tensor.size())
  print("Genre Tensor Sizes:", genre_tensor.size())
  break
# Out:
# Title Tensor Sizes: torch.Size([16, 7, 3321])
# Image Tensor Sizes: torch.Size([16, 3, 256, 256])
# Genre Tensor Sizes: torch.Size([16, 18])

# %%
N, C = genre_tensor.shape

auroc_all = 0
f1_all = 0
f1 = MultilabelF1Score(num_labels=C, threshold=0.3, average='weighted')
f1 = f1.to(device)
model.eval()
for title_tensor, img_tensor, genre_tensor in test_dataloader:
  title_tensor = title_tensor.to(device)
  img_tensor = img_tensor.to(device)
  genre_tensor = genre_tensor.to(device)

  out = model(title_tensor, img_tensor)
  f1_batch = f1(out, genre_tensor)
  f1_all += f1_batch

print('F1: ', f1_all/len(test_dataloader))
# Out:
# F1:  tensor(0.3386, device='cuda:0')

# %% [markdown]
# # Predict base on thresholding
# ## The result is not good

# %%
def predict(model, title_tensor, img_tensor):
  """
  Predict classes base on thresholding.
  ---------
  Params:
  model:  abstract class of nn.Module
          trained model
  title_tensor:   torch.Tensor
                  Tensor for text data, here is the title
  img_tensor: torch.Tensor
              Tensor for image data, here is the cover picture
  --------
  Output:
  Array of C elements after thresholded, with C is number of classes
  """
  device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
  model.to(device)
  model.eval()

  with torch.no_grad():
    title_tensor, img_tensor = title_tensor.to(device), img_tensor.to(device)
    outputs = model(title_tensor, img_tensor)
    predicted_probs = torch.sigmoid(outputs)
    predicted_labels = (predicted_probs > 0.5).float()

  return predicted_labels.cpu().numpy()

for test_idx, (title_tensor, img_tensor, genre_tensor) in enumerate(test_dataloader):
  titles = testing_set.data['title'].tolist()
  img_paths = testing_set.data['img_path'].tolist()
  genres =  testing_set.data['genre'].tolist()
  target_title_tensor = title_tensor
  target_img_tensor = img_tensor
  predictions = predict(model, target_title_tensor, target_img_tensor)
  print(len(predictions))
  for i in range(title_tensor.size(0)):
    index = test_idx * title_tensor.size(0) + i
    title = titles[index]
    genre = genres[index]
    predicted_categories = [genre for genre, pred in zip(genre_all, predictions[i]) if pred == 1]
    predicted_categories_str = ','.join(predicted_categories)
    print(f"Ex. {index}: {title} - {genre} - Predicted: {predicted_categories_str}")
# Out:
# 16
# Ex. 0: Great Muppet Caper, The  - ["Children's", 'Comedy'] - Predicted:
# Ex. 1: Doctor Zhivago  - ['Drama', 'Romance', 'War'] - Predicted: Comedy
# Ex. 2: Frankenstein Meets the Wolf Man  - ['Horror'] - Predicted:
# Ex. 3: For Your Eyes Only  - ['Action'] - Predicted:
# Ex. 4: Mirror, The (Zerkalo)  - ['Drama'] - Predicted: Comedy
# Ex. 5: Wolf  - ['Drama', 'Horror'] - Predicted:
# Ex. 6: All Quiet on the Western Front  - ['War'] - Predicted: Drama
# Ex. 7: Nelly & Monsieur Arnaud  - ['Drama'] - Predicted: Drama
# Ex. 8: Freedom for Us (Ã nous la libertÃ© )  - ['Comedy'] - Predicted: Drama
# Ex. 9: Wag the Dog  - ['Comedy', 'Drama'] - Predicted: Drama
# Ex. 10: Thelma & Louise  - ['Action', 'Drama'] - Predicted:
# Ex. 11: Prisoner of the Mountains (Kavkazsky Plennik)  - ['War'] - Predicted: Drama
# Ex. 12: Great Race, The  - ['Comedy', 'Musical'] - Predicted:
# Ex. 13: Splendor in the Grass  - ['Drama'] - Predicted: Comedy
# Ex. 14: Crime and Punishment in Suburbia  - ['Comedy', 'Drama'] - Predicted: Comedy,Drama
# Ex. 15: People vs. Larry Flynt, The  - ['Drama'] - Predicted: Drama
# 16
# Ex. 16: Jade  - ['Thriller'] - Predicted: Drama
# Ex. 17: Wild Man Blues  - ['Documentary'] - Predicted: Drama
# Ex. 18: When We Were Kings  - ['Documentary'] - Predicted: Drama
# Ex. 19: Dead Poets Society  - ['Drama'] - Predicted: Comedy
# Ex. 20: Death Wish 3  - ['Action', 'Drama'] - Predicted: Drama,Action
# Ex. 21: Other Sister, The  - ['Comedy', 'Drama', 'Romance'] - Predicted: Drama
# Ex. 22: Henry: Portrait of a Serial Killer, Part 2  - ['Crime', 'Horror'] - Predicted: Drama,War
# Ex. 23: Heartburn  - ['Comedy', 'Drama'] - Predicted: Drama
# Ex. 24: Taxi Driver  - ['Drama', 'Thriller'] - Predicted: Drama
# Ex. 25: Scream  - ['Horror', 'Thriller'] - Predicted: Thriller
# Ex. 26: American Graffiti  - ['Comedy', 'Drama'] - Predicted: Comedy
# Ex. 27: Destination Moon  - ['Sci-Fi'] - Predicted: Drama
# Ex. 28: Problem Child  - ['Comedy'] - Predicted: Comedy
# Ex. 29: Love and a .45  - ['Thriller'] - Predicted: Comedy
# Ex. 30: Pitch Black  - ['Action', 'Sci-Fi'] - Predicted:
# Ex. 31: Contempt (Le MÃ©pris)  - ['Drama'] - Predicted: Comedy,Drama
# 16
# Ex. 32: Love Bug, The  - ["Children's", 'Comedy'] - Predicted: Comedy
# Ex. 33: Sixth Man, The  - ['Comedy'] - Predicted:
# Ex. 34: House on Haunted Hill, The  - ['Horror'] - Predicted: Horror
# Ex. 35: 2010  - ['Mystery', 'Sci-Fi'] - Predicted: Drama
# Ex. 36: Canadian Bacon  - ['Comedy', 'War'] - Predicted: Drama
# Ex. 37: Jack  - ['Comedy', 'Drama'] - Predicted: Comedy,Drama
# Ex. 38: Shooting Fish  - ['Romance'] - Predicted: Drama
# Ex. 39: Grifters, The  - ['Crime', 'Drama', 'Film-Noir'] - Predicted: Drama
# Ex. 40: Mr. Jones  - ['Drama', 'Romance'] - Predicted: Comedy,Romance
# Ex. 41: Irma la Douce  - ['Comedy'] - Predicted: Drama
# Ex. 42: Village of the Damned  - ['Horror', 'Sci-Fi', 'Thriller'] - Predicted: Thriller,Sci-Fi
# Ex. 43: Dog's Life, A  - ['Comedy'] - Predicted: Drama
# Ex. 44: Omen, The  - ['Horror'] - Predicted: Drama
# Ex. 45: Hard 8 (a.k.a. Sydney, a.k.a. Hard Eight)  - ['Crime', 'Thriller'] - Predicted: Comedy
# Ex. 46: Nosferatu (Nosferatu, eine Symphonie des Grauens)  - ['Horror'] - Predicted: Horror
# Ex. 47: Come See the Paradise  - ['Drama', 'Romance'] - Predicted: Drama
# 16
# Ex. 48: Persuasion  - ['Romance'] - Predicted: Drama
# Ex. 49: Sixteen Candles  - ['Comedy'] - Predicted: Comedy,Drama
# Ex. 50: Short Cuts  - ['Drama'] - Predicted: Comedy,Drama
# Ex. 51: Last Action Hero  - ['Action', 'Comedy'] - Predicted:
# Ex. 52: Patriot Games  - ['Action', 'Thriller'] - Predicted: Drama
# Ex. 53: Good, The Bad and The Ugly, The  - ['Action', 'Western'] - Predicted: Drama
# Ex. 54: War, The  - ['Adventure', 'Drama'] - Predicted: Drama
# Ex. 55: Jaws 2  - ['Action', 'Horror'] - Predicted: Horror,Action
# Ex. 56: Reindeer Games  - ['Action', 'Thriller'] - Predicted: Drama
# Ex. 57: King of the Hill  - ['Drama'] - Predicted: Drama
# Ex. 58: Re-Animator  - ['Horror'] - Predicted:
# Ex. 59: They Shoot Horses, Don't They?  - ['Drama'] - Predicted: Drama
# Ex. 60: Shall We Dance? (Shall We Dansu?)  - ['Comedy'] - Predicted:
# Ex. 61: Pocahontas  - ['Animation', "Children's", 'Musical', 'Romance'] - Predicted:
# Ex. 62: Stalingrad  - ['War'] - Predicted: Comedy
# Ex. 63: Plunkett & MaCleane  - ['Action', 'Drama'] - Predicted: Drama
# 16
# Ex. 64: Foxfire  - ['Drama'] - Predicted: Drama
# Ex. 65: Four Days in September  - ['Drama'] - Predicted: Comedy
# Ex. 66: Threesome  - ['Comedy', 'Romance'] - Predicted: Drama
# Ex. 67: Lady of Burlesque  - ['Comedy', 'Mystery'] - Predicted: Comedy,Romance
# Ex. 68: Alice and Martin (Alice et Martin)  - ['Drama'] - Predicted: Drama
# Ex. 69: Great Mouse Detective, The  - ['Animation', "Children's"] - Predicted: Drama
# Ex. 70: Gentleman's Agreement  - ['Drama'] - Predicted: Comedy
# Ex. 71: Fathers' Day  - ['Comedy'] - Predicted: Drama
# Ex. 72: Crossing Guard, The  - ['Drama'] - Predicted: Drama
# Ex. 73: Iron Giant, The  - ['Animation', "Children's"] - Predicted: Comedy,Action
# Ex. 74: Boys on the Side  - ['Comedy', 'Drama'] - Predicted: Drama
# Ex. 75: Ruthless People  - ['Comedy'] - Predicted: Comedy
# Ex. 76: You Can't Take It With You  - ['Comedy'] - Predicted: Comedy
# Ex. 77: Blue Chips  - ['Drama'] - Predicted: Comedy,Romance
# Ex. 78: I Know What You Did Last Summer  - ['Horror', 'Mystery', 'Thriller'] - Predicted: Thriller,Sci-Fi
# Ex. 79: Alien Nation  - ['Crime', 'Drama', 'Sci-Fi'] - Predicted: Thriller,Sci-Fi,Action
# 16
# Ex. 80: Trading Places  - ['Comedy'] - Predicted: Drama
# Ex. 81: Things Change  - ['Comedy'] - Predicted: Drama
# Ex. 82: Bossa Nova  - ['Comedy'] - Predicted: Comedy
# Ex. 83: Pompatus of Love, The  - ['Comedy', 'Drama'] - Predicted: Comedy
# Ex. 84: Silent Fall  - ['Drama', 'Thriller'] - Predicted: Drama
# Ex. 85: Cruel Intentions  - ['Drama'] - Predicted: Drama
# Ex. 86: Just Cause  - ['Mystery', 'Thriller'] - Predicted: Drama
# Ex. 87: West Side Story  - ['Musical', 'Romance'] - Predicted: Drama
# Ex. 88: Spartacus  - ['Drama'] - Predicted:
# Ex. 89: Play it to the Bone  - ['Comedy', 'Drama'] - Predicted: Comedy
# Ex. 90: Amityville: Dollhouse  - ['Horror'] - Predicted: Horror
# Ex. 91: March of the Wooden Soldiers (a.k.a. Laurel & Hardy in Toyland)  - ['Comedy'] - Predicted:
# Ex. 92: Forces of Nature  - ['Comedy', 'Romance'] - Predicted:
# Ex. 93: Modern Times  - ['Comedy'] - Predicted: Comedy
# Ex. 94: Bronco Billy  - ['Adventure', 'Drama', 'Romance'] - Predicted:
# Ex. 95: Pulp Fiction  - ['Crime', 'Drama'] - Predicted:
# 16
# Ex. 96: Welcome To Sarajevo  - ['Drama', 'War'] - Predicted: Comedy,Drama
# Ex. 97: Trixie  - ['Comedy'] - Predicted:
# Ex. 98: Faster Pussycat! Kill! Kill!  - ['Action', 'Comedy', 'Drama'] - Predicted: Action
# Ex. 99: Sum of Us, The  - ['Comedy'] - Predicted: Comedy,Drama
# Ex. 100: Nurse Betty  - ['Comedy', 'Thriller'] - Predicted: Drama
# Ex. 101: Dead Ringers  - ['Drama', 'Thriller'] - Predicted:
# Ex. 102: Devil's Own, The  - ['Action', 'Drama', 'Thriller', 'War'] - Predicted: Thriller,Drama
# Ex. 103: Creepshow  - ['Horror'] - Predicted:
# Ex. 104: Grand Day Out, A  - ['Animation', 'Comedy'] - Predicted: Drama
# Ex. 105: Devil Girl From Mars  - ['Sci-Fi'] - Predicted: Action
# Ex. 106: Mission to Mars  - ['Sci-Fi'] - Predicted: Thriller,Drama
# Ex. 107: Mother Night  - ['Drama'] - Predicted: Comedy
# Ex. 108: Postino, Il (The Postman)  - ['Drama', 'Romance'] - Predicted: Drama
# Ex. 109: Hellraiser: Bloodline  - ['Action', 'Horror', 'Sci-Fi'] - Predicted: Horror
# Ex. 110: BASEketball  - ['Comedy'] - Predicted:
# Ex. 111: Angel Heart  - ['Film-Noir', 'Mystery', 'Thriller'] - Predicted: Drama
# 16
# Ex. 112: Frankie Starlight  - ['Drama', 'Romance'] - Predicted: Drama
# Ex. 113: Flirting With Disaster  - ['Comedy'] - Predicted: Drama
# Ex. 114: Tales from the Hood  - ['Comedy', 'Horror'] - Predicted: Horror
# Ex. 115: Bad Moon  - ['Horror'] - Predicted: Drama
# Ex. 116: Farewell My Concubine  - ['Drama', 'Romance'] - Predicted: Comedy,Drama
# Ex. 117: Black Dog  - ['Action', 'Thriller'] - Predicted: Drama
# Ex. 118: Butcher Boy, The  - ['Drama'] - Predicted: Drama
# Ex. 119: Sword in the Stone, The  - ['Animation', "Children's"] - Predicted:
# Ex. 120: Wings  - ['Drama', 'Romance', 'War'] - Predicted: Comedy
# Ex. 121: Michael Collins  - ['Drama', 'War'] - Predicted: Comedy,Romance
# Ex. 122: Wedding Singer, The  - ['Comedy', 'Romance'] - Predicted: Drama
# Ex. 123: Whipped  - ['Comedy'] - Predicted:
# Ex. 124: Waterboy, The  - ['Comedy'] - Predicted: Drama
# Ex. 125: Ghost and the Darkness, The  - ['Action', 'Adventure'] - Predicted: Romance
# Ex. 126: Robocop 3  - ['Sci-Fi', 'Thriller'] - Predicted: Drama
# Ex. 127: Little Odessa  - ['Drama'] - Predicted: Drama
# 16
# Ex. 128: Moonstruck  - ['Comedy'] - Predicted: Drama
# Ex. 129: My Best Fiend (Mein liebster Feind)  - ['Documentary'] - Predicted: Comedy
# Ex. 130: Greatest Show on Earth, The  - ['Drama'] - Predicted: Drama
# Ex. 131: Alvarez Kelly  - ['Western'] - Predicted: Drama
# Ex. 132: Goofy Movie, A  - ['Animation', "Children's", 'Comedy', 'Romance'] - Predicted: Comedy
# Ex. 133: Cook the Thief His Wife & Her Lover, The  - ['Drama'] - Predicted: Thriller,Drama
# Ex. 134: How to Stuff a Wild Bikini  - ['Comedy'] - Predicted: Comedy,Drama
# Ex. 135: Getaway, The  - ['Action'] - Predicted: Drama
# Ex. 136: Limbo  - ['Drama'] - Predicted: Drama
# Ex. 137: Heavyweights  - ["Children's", 'Comedy'] - Predicted: Comedy
# Ex. 138: Switchback  - ['Thriller'] - Predicted: Drama
# Ex. 139: Grace of My Heart  - ['Comedy', 'Drama'] - Predicted: Drama
# Ex. 140: I Love Trouble  - ['Action', 'Comedy'] - Predicted: Comedy,Drama
# Ex. 141: Creature From the Black Lagoon, The  - ['Horror'] - Predicted:
# Ex. 142: Poison Ivy: New Seduction  - ['Thriller'] - Predicted: Thriller
# Ex. 143: Fly Away Home  - ['Adventure', "Children's"] - Predicted:
# 16
# Ex. 144: Big Night  - ['Drama'] - Predicted: Comedy
# Ex. 145: Three Days of the Condor  - ['Thriller'] - Predicted: Drama
# Ex. 146: Strawberry and Chocolate (Fresa y chocolate)  - ['Drama'] - Predicted: Drama
# Ex. 147: 187  - ['Drama'] - Predicted: Thriller,Drama
# Ex. 148: Ride with the Devil  - ['Drama', 'Romance', 'War'] - Predicted: Drama
# Ex. 149: Midnight Express  - ['Drama'] - Predicted: Drama,Mystery
# Ex. 150: Oliver!  - ['Musical'] - Predicted: Children's
# Ex. 151: Hollywood Knights, The  - ['Comedy'] - Predicted:
# Ex. 152: While You Were Sleeping  - ['Comedy', 'Romance'] - Predicted: Comedy,Drama
# Ex. 153: Rescuers, The  - ['Animation', "Children's"] - Predicted:
# Ex. 154: Barney's Great Adventure  - ['Adventure', "Children's"] - Predicted: Comedy
# Ex. 155: New Age, The  - ['Drama'] - Predicted: Drama
# Ex. 156: On the Ropes  - ['Documentary'] - Predicted: Drama
# Ex. 157: Marked for Death  - ['Action', 'Drama'] - Predicted: Drama
# Ex. 158: Man for All Seasons, A  - ['Drama'] - Predicted: Drama
# Ex. 159: Spy Hard  - ['Comedy'] - Predicted: Thriller,Action
# 16
# Ex. 160: Birdcage, The  - ['Comedy'] - Predicted:
# Ex. 161: Dying Young  - ['Drama', 'Romance'] - Predicted:
# Ex. 162: My Science Project  - ['Adventure', 'Sci-Fi'] - Predicted: Comedy
# Ex. 163: White Men Can't Jump  - ['Comedy'] - Predicted: Comedy
# Ex. 164: Hard Rain  - ['Action', 'Thriller'] - Predicted: Comedy
# Ex. 165: Dogma  - ['Comedy'] - Predicted:
# Ex. 166: In the Name of the Father  - ['Drama'] - Predicted: Thriller
# Ex. 167: Love Stinks  - ['Comedy'] - Predicted: Comedy,Romance
# Ex. 168: Wonderland  - ['Drama'] - Predicted:
# Ex. 169: Live Flesh  - ['Drama'] - Predicted: Thriller,Action
# Ex. 170: Hell Night  - ['Horror'] - Predicted:
# Ex. 171: Men With Guns  - ['Action', 'Drama'] - Predicted: Action
# Ex. 172: Patton  - ['Drama', 'War'] - Predicted: Drama
# Ex. 173: Governess, The  - ['Drama', 'Romance'] - Predicted: Drama
# Ex. 174: Apollo 13  - ['Drama'] - Predicted:
# Ex. 175: King Kong vs. Godzilla (Kingukongu tai Gojira)  - ['Action', 'Sci-Fi'] - Predicted: Adventure,Action
# 16
# Ex. 176: Johnny Mnemonic  - ['Action', 'Sci-Fi', 'Thriller'] - Predicted:
# Ex. 177: Waking Ned Devine  - ['Comedy'] - Predicted: Drama
# Ex. 178: Angels in the Outfield  - ["Children's", 'Comedy'] - Predicted: Comedy
# Ex. 179: Psycho II  - ['Horror', 'Thriller'] - Predicted: Thriller,Horror
# Ex. 180: Air Force One  - ['Action', 'Thriller'] - Predicted: Comedy
# Ex. 181: 42 Up  - ['Documentary'] - Predicted: Comedy,Drama
# Ex. 182: Tom and Huck  - ['Adventure', "Children's"] - Predicted: Drama
# Ex. 183: Friday the 13th Part VI: Jason Lives  - ['Horror'] - Predicted: Horror
# Ex. 184: Galaxy Quest  - ['Adventure', 'Comedy', 'Sci-Fi'] - Predicted:
# Ex. 185: Othello  - ['Drama'] - Predicted: Drama
# Ex. 186: Swan Princess, The  - ['Animation', "Children's"] - Predicted: Drama,Children's
# Ex. 187: Zero Effect  - ['Comedy', 'Thriller'] - Predicted: Drama
# Ex. 188: Blow-Out (La Grande Bouffe)  - ['Drama'] - Predicted: Drama
# Ex. 189: Miami Rhapsody  - ['Comedy'] - Predicted: Drama
# Ex. 190: Tie That Binds, The  - ['Thriller'] - Predicted:
# Ex. 191: Boys  - ['Drama'] - Predicted: Drama
# 16
# Ex. 192: Swamp Thing  - ['Horror', 'Sci-Fi'] - Predicted: Drama
# Ex. 193: Richie Rich  - ["Children's", 'Comedy'] - Predicted: Comedy,Drama
# Ex. 194: Plenty  - ['Drama'] - Predicted: Drama
# Ex. 195: Davy Crockett, King of the Wild Frontier  - ['Western'] - Predicted: Drama
# Ex. 196: Godzilla (Gojira)  - ['Action', 'Sci-Fi'] - Predicted:
# Ex. 197: Adventures of Robin Hood, The  - ['Action', 'Adventure'] - Predicted:
# Ex. 198: Ghostbusters II  - ['Comedy', 'Horror'] - Predicted: Horror,Comedy
# Ex. 199: Alive  - ['Drama'] - Predicted: Comedy,Drama
# Ex. 200: Faculty, The  - ['Horror', 'Sci-Fi'] - Predicted:
# Ex. 201: Dumb & Dumber  - ['Comedy'] - Predicted: Drama
# Ex. 202: Medicine Man  - ['Adventure', 'Romance'] - Predicted: Drama
# Ex. 203: Mrs. Miniver  - ['Drama', 'War'] - Predicted: Comedy
# Ex. 204: Sabotage  - ['Thriller'] - Predicted:
# Ex. 205: Last of the Mohicans, The  - ['Action', 'Romance', 'War'] - Predicted:
# Ex. 206: Kronos  - ['Horror'] - Predicted: Sci-Fi
# Ex. 207: Glass Bottom Boat, The  - ['Comedy', 'Romance'] - Predicted: Drama
# 16
# Ex. 208: Gossip  - ['Drama', 'Thriller'] - Predicted: Drama
# Ex. 209: Killer Shrews, The  - ['Horror', 'Sci-Fi'] - Predicted:
# Ex. 210: Next Stop, Wonderland  - ['Comedy', 'Drama', 'Romance'] - Predicted: Comedy,Drama
# Ex. 211: Poltergeist III  - ['Horror', 'Thriller'] - Predicted: Thriller,Horror
# Ex. 212: Saturn 3  - ['Adventure', 'Sci-Fi', 'Thriller'] - Predicted: Mystery
# Ex. 213: Mr. Saturday Night  - ['Comedy', 'Drama'] - Predicted: Comedy
# Ex. 214: American Flyers  - ['Drama'] - Predicted: Comedy
# Ex. 215: Land Before Time III: The Time of the Great Giving  - ['Animation', "Children's"] - Predicted: War,Children's
# Ex. 216: Quiz Show  - ['Drama'] - Predicted: Drama
# Ex. 217: Whatever It Takes  - ['Comedy', 'Romance'] - Predicted: Comedy,Drama
# Ex. 218: Private School  - ['Comedy'] - Predicted: Comedy
# Ex. 219: Princess Caraboo  - ['Drama'] - Predicted: Comedy
# Ex. 220: Kids  - ['Drama'] - Predicted: Comedy
# Ex. 221: Superman II  - ['Action', 'Adventure', 'Sci-Fi'] - Predicted:
# Ex. 222: Hollow Man  - ['Horror', 'Sci-Fi', 'Thriller'] - Predicted: Thriller,Drama
# Ex. 223: Nico Icon  - ['Documentary'] - Predicted:
# 16
# Ex. 224: H.O.T.S.  - ['Comedy'] - Predicted: Drama
# Ex. 225: Nell  - ['Drama'] - Predicted: Drama
# Ex. 226: Far From Home: The Adventures of Yellow Dog  - ['Adventure', "Children's"] - Predicted:
# Ex. 227: Stop! Or My Mom Will Shoot  - ['Action', 'Comedy'] - Predicted: Drama
# Ex. 228: I'll Do Anything  - ['Comedy', 'Drama'] - Predicted: Drama
# Ex. 229: Verdict, The  - ['Drama'] - Predicted: Drama
# Ex. 230: Next Friday  - ['Comedy'] - Predicted: Comedy
# Ex. 231: Heidi Fleiss: Hollywood Madam  - ['Documentary'] - Predicted:
# Ex. 232: Damien: Omen II  - ['Horror'] - Predicted:
# Ex. 233: Assignment, The  - ['Thriller'] - Predicted:
# Ex. 234: Sugarland Express, The  - ['Drama'] - Predicted: Drama
# Ex. 235: Star Trek: Insurrection  - ['Action', 'Sci-Fi'] - Predicted: Sci-Fi,Adventure,Action
# Ex. 236: All Dogs Go to Heaven 2  - ['Animation', "Children's", 'Musical'] - Predicted: Drama
# Ex. 237: Rambo III  - ['Action', 'War'] - Predicted: Drama
# Ex. 238: Rage: Carrie 2, The  - ['Horror'] - Predicted:
# Ex. 239: Cousin Bette  - ['Comedy'] - Predicted: Drama
# 16
# Ex. 240: Rocky V  - ['Action', 'Drama'] - Predicted: Drama
# Ex. 241: Misery  - ['Horror'] - Predicted:
# Ex. 242: Snow Falling on Cedars  - ['Drama'] - Predicted: Comedy
# Ex. 243: From Russia with Love  - ['Action'] - Predicted:
# Ex. 244: Baby-Sitters Club, The  - ["Children's"] - Predicted: Comedy,Drama
# Ex. 245: Return from Witch Mountain  - ["Children's", 'Sci-Fi'] - Predicted: Sci-Fi
# Ex. 246: Hands on a Hard Body  - ['Documentary'] - Predicted: Drama
# Ex. 247: Blame It on Rio  - ['Comedy', 'Romance'] - Predicted: Comedy
# Ex. 248: Eyes of Tammy Faye, The  - ['Documentary'] - Predicted:
# Ex. 249: Hurlyburly  - ['Drama'] - Predicted: Drama
# Ex. 250: Grumpy Old Men  - ['Comedy'] - Predicted: Comedy,Romance
# Ex. 251: Artemisia  - ['Drama'] - Predicted: Drama
# Ex. 252: It Takes Two  - ['Comedy'] - Predicted: Comedy
# Ex. 253: Saludos Amigos  - ['Animation', "Children's", 'Comedy'] - Predicted: Comedy
# Ex. 254: Corruptor, The  - ['Action', 'Crime', 'Drama', 'Thriller'] - Predicted:
# Ex. 255: Real Blonde, The  - ['Comedy'] - Predicted: Comedy
# 16
# Ex. 256: Beyond Silence  - ['Drama'] - Predicted:
# Ex. 257: Felicia's Journey  - ['Thriller'] - Predicted:
# Ex. 258: Poison  - ['Drama'] - Predicted: Thriller
# Ex. 259: Ridicule  - ['Drama'] - Predicted: Drama
# Ex. 260: Once Upon a Time in the West  - ['Western'] - Predicted: Thriller,Drama
# Ex. 261: Rocketship X-M  - ['Sci-Fi'] - Predicted:
# Ex. 262: Paradine Case, The  - ['Drama'] - Predicted: Drama
# Ex. 263: Pawnbroker, The  - ['Drama'] - Predicted: Drama
# Ex. 264: Devil's Brigade, The  - ['War'] - Predicted: Drama
# Ex. 265: Bachelor, The  - ['Comedy', 'Romance'] - Predicted: Comedy
# Ex. 266: Apt Pupil  - ['Drama', 'Thriller'] - Predicted: Drama
# Ex. 267: Bridges of Madison County, The  - ['Drama', 'Romance'] - Predicted: Drama
# Ex. 268: Back to the Future  - ['Comedy', 'Sci-Fi'] - Predicted: Comedy
# Ex. 269: Angels and Insects  - ['Drama', 'Romance'] - Predicted: Drama
# Ex. 270: Tales of Terror  - ['Horror'] - Predicted:
# Ex. 271: Force of Evil  - ['Film-Noir'] - Predicted: Thriller
# 16
# Ex. 272: Safe Passage  - ['Drama'] - Predicted: Comedy
# Ex. 273: Mad City  - ['Action', 'Drama'] - Predicted: Thriller,Action
# Ex. 274: Bikini Beach  - ['Comedy'] - Predicted: Comedy
# Ex. 275: Tough Guys  - ['Comedy'] - Predicted: Drama
# Ex. 276: Better Than Chocolate  - ['Comedy', 'Romance'] - Predicted: Comedy
# Ex. 277: Black Sheep  - ['Comedy'] - Predicted:
# Ex. 278: Nightmares  - ['Horror'] - Predicted: Drama
# Ex. 279: Steel Magnolias  - ['Drama'] - Predicted:
# Ex. 280: Girls Town  - ['Drama'] - Predicted: Comedy,Drama
# Ex. 281: Watership Down  - ['Animation', "Children's", 'Drama', 'Fantasy'] - Predicted: Action
# Ex. 282: Rebel Without a Cause  - ['Drama'] - Predicted: Drama
# Ex. 283: Thirteenth Floor, The  - ['Drama', 'Sci-Fi', 'Thriller'] - Predicted: Drama
# Ex. 284: Third Miracle, The  - ['Drama'] - Predicted:
# Ex. 285: Madonna: Truth or Dare  - ['Documentary'] - Predicted:
# Ex. 286: Mickey Blue Eyes  - ['Comedy', 'Romance'] - Predicted:
# Ex. 287: American Pie  - ['Comedy'] - Predicted:
# 16
# Ex. 288: Daddy Long Legs  - ['Comedy'] - Predicted: Comedy
# Ex. 289: Cemetery Man (Dellamorte Dellamore)  - ['Comedy', 'Horror'] - Predicted:
# Ex. 290: Shaggy Dog, The  - ["Children's", 'Comedy'] - Predicted: Comedy,Drama
# Ex. 291: Farewell to Arms, A  - ['Romance', 'War'] - Predicted: Comedy,Drama
# Ex. 292: Children of the Corn III  - ['Horror'] - Predicted: Thriller,Horror
# Ex. 293: Crash  - ['Drama', 'Thriller'] - Predicted: Drama
# Ex. 294: Henry: Portrait of a Serial Killer  - ['Crime', 'Horror'] - Predicted: Drama
# Ex. 295: Never Been Kissed  - ['Comedy', 'Romance'] - Predicted: Drama
# Ex. 296: Exorcist, The  - ['Horror'] - Predicted:
# Ex. 297: Perfect Murder, A  - ['Mystery', 'Thriller'] - Predicted: Crime,Action
# Ex. 298: Outbreak  - ['Action', 'Drama', 'Thriller'] - Predicted: Drama
# Ex. 299: Whole Wide World, The  - ['Drama'] - Predicted: Drama
# Ex. 300: Jupiter's Wife  - ['Documentary'] - Predicted: Drama
# Ex. 301: Education of Little Tree, The  - ['Drama'] - Predicted: Drama
# Ex. 302: Woo  - ['Comedy', 'Romance'] - Predicted:
# Ex. 303: White Man's Burden  - ['Drama'] - Predicted: Thriller,Drama
# 16
# Ex. 304: Saint, The  - ['Action', 'Romance', 'Thriller'] - Predicted: Drama
# Ex. 305: Mafia!  - ['Comedy', 'Crime'] - Predicted: Comedy,Drama
# Ex. 306: On Her Majesty's Secret Service  - ['Action'] - Predicted: Drama
# Ex. 307: Girl on the Bridge, The (La Fille sur le Pont)  - ['Drama', 'Romance'] - Predicted: Drama
# Ex. 308: Benji  - ['Adventure', "Children's"] - Predicted: Drama
# Ex. 309: Romeo Must Die  - ['Action', 'Romance'] - Predicted: Thriller,Comedy
# Ex. 310: Price Above Rubies, A  - ['Drama'] - Predicted: Comedy
# Ex. 311: Class of Nuke 'Em High  - ['Comedy', 'Horror'] - Predicted: Comedy
# Ex. 312: Replacements, The  - ['Comedy'] - Predicted: Drama
# Ex. 313: Shiloh  - ["Children's", 'Drama'] - Predicted: Drama
# Ex. 314: Taming of the Shrew, The  - ['Comedy'] - Predicted: Drama
# Ex. 315: Alien: Resurrection  - ['Action', 'Horror', 'Sci-Fi'] - Predicted: Thriller,Horror,Sci-Fi,Action
# Ex. 316: Month by the Lake, A  - ['Comedy', 'Drama'] - Predicted: Drama
# Ex. 317: Larger Than Life  - ['Comedy'] - Predicted: Comedy
# Ex. 318: Believers, The  - ['Horror', 'Thriller'] - Predicted: Drama
# Ex. 319: Lady and the Tramp  - ['Animation', "Children's", 'Comedy', 'Musical', 'Romance'] - Predicted: Comedy
# 16
# Ex. 320: Raven, The  - ['Comedy', 'Horror'] - Predicted:
# Ex. 321: Close Encounters of the Third Kind  - ['Drama', 'Sci-Fi'] - Predicted:
# Ex. 322: Crow: City of Angels, The  - ['Action', 'Thriller'] - Predicted: Comedy,Romance
# Ex. 323: Sling Blade  - ['Drama', 'Thriller'] - Predicted: Drama
# Ex. 324: Turtle Diary  - ['Drama'] - Predicted: Comedy,Drama
# Ex. 325: Once Were Warriors  - ['Crime', 'Drama'] - Predicted: Drama
# Ex. 326: Repo Man  - ['Comedy', 'Sci-Fi'] - Predicted:
# Ex. 327: Bait  - ['Action', 'Comedy'] - Predicted:
# Ex. 328: Tin Men  - ['Comedy', 'Drama'] - Predicted: Comedy,Drama
# Ex. 329: Blank Check  - ["Children's", 'Comedy'] - Predicted: Drama
# Ex. 330: Any Given Sunday  - ['Drama'] - Predicted:
# Ex. 331: Mr. Holland's Opus  - ['Drama'] - Predicted: Comedy
# Ex. 332: Heavy  - ['Drama', 'Romance'] - Predicted: Sci-Fi
# Ex. 333: French Kiss  - ['Comedy', 'Romance'] - Predicted: Thriller,Drama
# Ex. 334: Back to the Future Part III  - ['Comedy', 'Sci-Fi', 'Western'] - Predicted: Comedy
# Ex. 335: Senseless  - ['Comedy'] - Predicted:
# 16
# Ex. 336: Predator 2  - ['Action', 'Sci-Fi', 'Thriller'] - Predicted: Thriller,Horror,Sci-Fi,Action
# Ex. 337: Dunston Checks In  - ["Children's", 'Comedy'] - Predicted: Comedy
# Ex. 338: Avalanche  - ['Action'] - Predicted: Drama
# Ex. 339: Candyman  - ['Horror'] - Predicted:
# Ex. 340: Star Trek III: The Search for Spock  - ['Action', 'Adventure', 'Sci-Fi'] - Predicted: Sci-Fi,Adventure,Action
# Ex. 341: Young Poisoner's Handbook, The  - ['Crime'] - Predicted: Comedy
# Ex. 342: I Went Down  - ['Action', 'Comedy', 'Crime'] - Predicted: Drama
# Ex. 343: Wrongfully Accused  - ['Action', 'Comedy'] - Predicted: Drama
# Ex. 344: Substitute, The  - ['Action'] - Predicted: Drama
# Ex. 345: Sugar Town  - ['Comedy'] - Predicted: Comedy
# Ex. 346: Female Perversions  - ['Drama'] - Predicted: Drama
# Ex. 347: Nick of Time  - ['Action', 'Thriller'] - Predicted:
# Ex. 348: Mouse Hunt  - ["Children's", 'Comedy'] - Predicted: Drama
# Ex. 349: Kingpin  - ['Comedy'] - Predicted: Drama
# Ex. 350: Haunting, The  - ['Horror', 'Thriller'] - Predicted: Thriller,Horror
# Ex. 351: Breakfast of Champions  - ['Comedy'] - Predicted: Comedy,Drama
# 16
# Ex. 352: Slam  - ['Drama'] - Predicted: Drama
# Ex. 353: Ref, The  - ['Comedy'] - Predicted: Drama
# Ex. 354: Up at the Villa  - ['Drama'] - Predicted: Drama
# Ex. 355: Bound for Glory  - ['Drama'] - Predicted: Drama
# Ex. 356: Man Bites Dog (C'est arrivÃ© prÃ¨s de chez vous)  - ['Action', 'Comedy', 'Crime', 'Drama'] - Predicted: Comedy,Drama
# Ex. 357: Trouble with Harry, The  - ['Mystery', 'Thriller'] - Predicted: Comedy
# Ex. 358: Falling Down  - ['Action', 'Drama'] - Predicted: Drama
# Ex. 359: Magnum Force  - ['Western'] - Predicted: Drama
# Ex. 360: Frighteners, The  - ['Comedy', 'Horror'] - Predicted: Comedy,Drama
# Ex. 361: Road to El Dorado, The  - ['Animation', "Children's"] - Predicted: Comedy
# Ex. 362: Assassins  - ['Thriller'] - Predicted: Drama
# Ex. 363: Committed  - ['Comedy', 'Drama'] - Predicted: Drama
# Ex. 364: Manon of the Spring (Manon des sources)  - ['Drama'] - Predicted: Romance,Drama
# Ex. 365: Clean Slate  - ['Comedy'] - Predicted:
# Ex. 366: Porky's  - ['Comedy'] - Predicted: Comedy
# Ex. 367: Robin Hood  - ['Animation', "Children's"] - Predicted: Comedy
# 16
# Ex. 368: Diner  - ['Comedy', 'Drama'] - Predicted:
# Ex. 369: Third Man, The  - ['Mystery', 'Thriller'] - Predicted:
# Ex. 370: Boiler Room  - ['Drama'] - Predicted: Comedy
# Ex. 371: Hard Core Logo  - ['Comedy'] - Predicted: Comedy
# Ex. 372: Thirty-Two Short Films About Glenn Gould  - ['Documentary'] - Predicted: Comedy,Drama
# Ex. 373: Wings of the Dove, The  - ['Drama', 'Romance', 'Thriller'] - Predicted: Drama
# Ex. 374: Stepford Wives, The  - ['Sci-Fi', 'Thriller'] - Predicted: Comedy
# Ex. 375: Belle de jour  - ['Drama'] - Predicted: Comedy,Romance,Drama
# Ex. 376: Drugstore Cowboy  - ['Crime', 'Drama'] - Predicted: Drama
# Ex. 377: Right Stuff, The  - ['Drama'] - Predicted: Drama
# Ex. 378: Filth and the Fury, The  - ['Documentary'] - Predicted: Drama
# Ex. 379: Get Carter  - ['Action', 'Drama', 'Thriller'] - Predicted: Thriller
# Ex. 380: Black Beauty  - ['Adventure', "Children's"] - Predicted: Drama
# Ex. 381: Life of Ãmile Zola, The  - ['Drama'] - Predicted: Comedy
# Ex. 382: Green Mile, The  - ['Drama', 'Thriller'] - Predicted: Drama
# Ex. 383: Braindead  - ['Comedy', 'Horror'] - Predicted: Drama
# 16
# Ex. 384: Fled  - ['Action', 'Adventure'] - Predicted:
# Ex. 385: No Small Affair  - ['Comedy', 'Romance'] - Predicted:
# Ex. 386: Endurance  - ['Documentary', 'Drama'] - Predicted: Drama
# Ex. 387: Bed of Roses  - ['Drama', 'Romance'] - Predicted:
# Ex. 388: Party Girl  - ['Comedy'] - Predicted: Comedy
# Ex. 389: Hollow Reed  - ['Drama'] - Predicted: Drama
# Ex. 390: Skulls, The  - ['Thriller'] - Predicted: Thriller
# Ex. 391: Everest  - ['Documentary'] - Predicted: Comedy
# Ex. 392: Flying Saucer, The  - ['Sci-Fi'] - Predicted: Drama
# Ex. 393: Road to Wellville, The  - ['Comedy'] - Predicted: Comedy
# Ex. 394: Time Regained (Le Temps RetrouvÃ©)  - ['Drama'] - Predicted: Drama
# Ex. 395: Santa Claus: The Movie  - ['Adventure', "Children's", 'Fantasy'] - Predicted: Children's
# Ex. 396: Big  - ['Comedy', 'Fantasy'] - Predicted: Comedy,Drama
# Ex. 397: Fatal Attraction  - ['Thriller'] - Predicted: Comedy,Action
# Ex. 398: Sleepless in Seattle  - ['Comedy', 'Romance'] - Predicted: Comedy,Drama
# Ex. 399: Destiny Turns on the Radio  - ['Comedy'] - Predicted: Comedy,Drama
# 16
# Ex. 400: Slumber Party Massacre III, The  - ['Horror'] - Predicted: Horror
# Ex. 401: Hard Target  - ['Action', 'Adventure', 'Crime', 'Thriller'] - Predicted: Comedy
# Ex. 402: Jawbreaker  - ['Comedy'] - Predicted: Comedy
# Ex. 403: Max Dugan Returns  - ['Comedy'] - Predicted:
# Ex. 404: Back to the Future Part II  - ['Comedy', 'Sci-Fi'] - Predicted: Comedy
# Ex. 405: Gaslight  - ['Mystery', 'Thriller'] - Predicted:
# Ex. 406: Backdraft  - ['Action', 'Drama'] - Predicted: Drama
# Ex. 407: Sorority House Massacre  - ['Horror'] - Predicted: Horror
# Ex. 408: Dear Diary (Caro Diario)  - ['Comedy', 'Drama'] - Predicted: Comedy
# Ex. 409: Rear Window  - ['Mystery', 'Thriller'] - Predicted:
# Ex. 410: Hi-Lo Country, The  - ['Drama', 'Western'] - Predicted:
# Ex. 411: Crow: Salvation, The  - ['Action', 'Horror'] - Predicted: Thriller,Romance
# Ex. 412: Notorious  - ['Film-Noir', 'Romance', 'Thriller'] - Predicted: Drama
# Ex. 413: Tales from the Darkside: The Movie  - ['Horror'] - Predicted: Horror,Sci-Fi
# Ex. 414: Meet the Deedles  - ["Children's", 'Comedy'] - Predicted: Drama
# Ex. 415: ...And Justice for All  - ['Drama', 'Thriller'] - Predicted: Drama
# 16
# Ex. 416: Adventures of Priscilla, Queen of the Desert, The  - ['Comedy', 'Drama'] - Predicted:
# Ex. 417: Exorcist III, The  - ['Horror'] - Predicted: Horror,Drama
# Ex. 418: Apartment, The  - ['Comedy', 'Drama'] - Predicted: Drama
# Ex. 419: Ready to Rumble  - ['Comedy'] - Predicted: Comedy
# Ex. 420: One Magic Christmas  - ['Drama', 'Fantasy'] - Predicted: Comedy,Drama
# Ex. 421: Mary Reilly  - ['Drama', 'Thriller'] - Predicted: Comedy,Drama
# Ex. 422: On Golden Pond  - ['Drama'] - Predicted: Drama
# Ex. 423: Duel in the Sun  - ['Western'] - Predicted: Drama
# Ex. 424: Ipcress File, The  - ['Thriller'] - Predicted:
# Ex. 425: Murder, My Sweet  - ['Film-Noir', 'Thriller'] - Predicted: Thriller,Drama
# Ex. 426: Benji the Hunted  - ['Adventure', "Children's"] - Predicted: Drama
# Ex. 427: King Kong  - ['Action', 'Adventure', 'Horror'] - Predicted: Horror
# Ex. 428: McHale's Navy  - ['Comedy', 'War'] - Predicted:
# Ex. 429: Some Kind of Wonderful  - ['Drama', 'Romance'] - Predicted: Drama
# Ex. 430: Sour Grapes  - ['Comedy'] - Predicted:
# Ex. 431: City of Industry  - ['Crime', 'Thriller'] - Predicted: Drama
# 16
# Ex. 432: Mask of Zorro, The  - ['Action', 'Adventure', 'Romance'] - Predicted: Drama
# Ex. 433: Before the Rain (Pred dozhdot)  - ['Drama'] - Predicted: Drama
# Ex. 434: Big Lebowski, The  - ['Comedy', 'Crime', 'Mystery', 'Thriller'] - Predicted: Comedy
# Ex. 435: Radio Days  - ['Comedy', 'Drama'] - Predicted:
# Ex. 436: Highlander III: The Sorcerer  - ['Action', 'Sci-Fi'] - Predicted: Action
# Ex. 437: Mighty Joe Young  - ['Adventure', "Children's", 'Drama'] - Predicted: Adventure,Drama,Children's
# Ex. 438: Holy Smoke  - ['Drama'] - Predicted: Comedy
# Ex. 439: Down Periscope  - ['Comedy'] - Predicted: Comedy
# Ex. 440: Four Rooms  - ['Thriller'] - Predicted: Comedy
# Ex. 441: Traveller  - ['Drama'] - Predicted: Drama
# Ex. 442: Terminal Velocity  - ['Action'] - Predicted:
# Ex. 443: Interview with the Vampire  - ['Drama', 'Horror'] - Predicted: Drama
# Ex. 444: Tall Tale  - ['Adventure', "Children's"] - Predicted:
# Ex. 445: Sleepy Hollow  - ['Horror', 'Romance'] - Predicted: Drama
# Ex. 446: Pushing Hands  - ['Comedy'] - Predicted: Comedy
# Ex. 447: And the Band Played On  - ['Drama'] - Predicted: Drama
# 16
# Ex. 448: One False Move  - ['Thriller'] - Predicted: Drama
# Ex. 449: Beneath the Planet of the Apes  - ['Action', 'Sci-Fi'] - Predicted: Drama
# Ex. 450: Man of No Importance, A  - ['Drama'] - Predicted: Drama
# Ex. 451: Phenomenon  - ['Drama', 'Romance'] - Predicted: Drama
# Ex. 452: Dracula  - ['Horror'] - Predicted: Horror
# Ex. 453: Class Reunion  - ['Comedy'] - Predicted: Comedy
# Ex. 454: Life Is Beautiful (La Vita Ã¨ bella)  - ['Comedy', 'Drama'] - Predicted: Comedy
# Ex. 455: Three Kings  - ['Drama', 'War'] - Predicted: Comedy,Drama
# Ex. 456: Six Days Seven Nights  - ['Adventure', 'Comedy', 'Romance'] - Predicted:
# Ex. 457: Extremities  - ['Drama', 'Thriller'] - Predicted: Drama
# Ex. 458: Piano, The  - ['Drama', 'Romance'] - Predicted: Drama
# Ex. 459: Jason's Lyric  - ['Crime', 'Drama'] - Predicted: Drama
# Ex. 460: Awfully Big Adventure, An  - ['Drama'] - Predicted: Comedy
# Ex. 461: Baraka  - ['Documentary'] - Predicted:
# Ex. 462: Cool Hand Luke  - ['Comedy', 'Drama'] - Predicted: Comedy
# Ex. 463: Popeye  - ['Adventure', 'Comedy', 'Musical'] - Predicted:
# 16
# Ex. 464: Police Academy 3: Back in Training  - ['Comedy'] - Predicted: Comedy
# Ex. 465: Instinct  - ['Drama', 'Thriller'] - Predicted: Comedy,Drama
# Ex. 466: Dumbo  - ['Animation', "Children's", 'Musical'] - Predicted:
# Ex. 467: Contender, The  - ['Drama', 'Thriller'] - Predicted: Drama
# Ex. 468: What's Love Got to Do with It?  - ['Drama'] - Predicted: Comedy,Romance,Drama
# Ex. 469: Lady Eve, The  - ['Comedy', 'Romance'] - Predicted: Romance
# Ex. 470: Voyage of the Damned  - ['Drama'] - Predicted: Sci-Fi
# Ex. 471: Raisin in the Sun, A  - ['Drama'] - Predicted: Drama
# Ex. 472: Vanya on 42nd Street  - ['Drama'] - Predicted: Drama
# Ex. 473: Soylent Green  - ['Sci-Fi', 'Thriller'] - Predicted:
# Ex. 474: Beautician and the Beast, The  - ['Comedy', 'Romance'] - Predicted:
# Ex. 475: Harvey  - ['Comedy'] - Predicted:
# Ex. 476: Man Who Knew Too Much, The  - ['Thriller'] - Predicted: Thriller
# Ex. 477: Glen or Glenda  - ['Drama'] - Predicted: Drama
# Ex. 478: Hairspray  - ['Comedy', 'Drama'] - Predicted: Drama
# Ex. 479: F/X 2  - ['Action', 'Crime', 'Thriller'] - Predicted:
# 16
# Ex. 480: Agnes of God  - ['Drama', 'Mystery'] - Predicted: Drama
# Ex. 481: Phantom, The  - ['Adventure'] - Predicted: Thriller,Drama
# Ex. 482: Mating Habits of the Earthbound Human, The  - ['Comedy'] - Predicted: Drama
# Ex. 483: Children of Paradise (Les enfants du paradis)  - ['Drama', 'Romance'] - Predicted: Drama
# Ex. 484: Nights of Cabiria (Le Notti di Cabiria)  - ['Drama'] - Predicted: Drama
# Ex. 485: Cry, the Beloved Country  - ['Drama'] - Predicted: Drama
# Ex. 486: Fletch  - ['Comedy'] - Predicted: Drama
# Ex. 487: Sweet and Lowdown  - ['Comedy', 'Drama'] - Predicted: Drama
# Ex. 488: Police Academy 4: Citizens on Patrol  - ['Comedy'] - Predicted: Comedy
# Ex. 489: Fly, The  - ['Horror', 'Sci-Fi'] - Predicted: Horror
# Ex. 490: Last Detail, The  - ['Comedy', 'Drama'] - Predicted: Drama
# Ex. 491: Devil in a Blue Dress  - ['Crime', 'Film-Noir', 'Mystery', 'Thriller'] - Predicted: Comedy
# Ex. 492: Two Family House  - ['Drama'] - Predicted: Comedy,Drama
# Ex. 493: Diabolique  - ['Drama', 'Thriller'] - Predicted: Drama
# Ex. 494: Big Daddy  - ['Comedy'] - Predicted: Comedy
# Ex. 495: House II: The Second Story  - ['Comedy', 'Horror'] - Predicted: Horror,Comedy
# 16
# Ex. 496: Radioland Murders  - ['Comedy', 'Mystery', 'Romance'] - Predicted:
# Ex. 497: Urban Legends: Final Cut  - ['Horror'] - Predicted:
# Ex. 498: Con Air  - ['Action', 'Adventure', 'Thriller'] - Predicted: Drama
# Ex. 499: Crocodile Dundee  - ['Adventure', 'Comedy'] - Predicted: Comedy,Adventure
# Ex. 500: Tom Jones  - ['Comedy'] - Predicted: Drama
# Ex. 501: Niagara  - ['Drama', 'Thriller'] - Predicted: Drama
# Ex. 502: Casino  - ['Drama', 'Thriller'] - Predicted: Drama
# Ex. 503: Cobb  - ['Drama'] - Predicted: Drama
# Ex. 504: Alaska  - ['Adventure', "Children's"] - Predicted: Drama
# Ex. 505: I.Q.  - ['Comedy', 'Romance'] - Predicted:
# Ex. 506: Under the Rainbow  - ['Comedy'] - Predicted:
# Ex. 507: Working Girl  - ['Comedy', 'Drama'] - Predicted: Thriller
# Ex. 508: Jennifer 8  - ['Thriller'] - Predicted: Drama
# Ex. 509: And Now for Something Completely Different  - ['Comedy'] - Predicted:
# Ex. 510: Suspicion  - ['Mystery', 'Thriller'] - Predicted: Drama
# Ex. 511: Godzilla (Gojira)  - ['Action', 'Sci-Fi'] - Predicted:
# 16
# Ex. 512: Can't Hardly Wait  - ['Comedy', 'Drama', 'Romance'] - Predicted: Comedy
# Ex. 513: Indochine  - ['Drama', 'Romance'] - Predicted: Drama
# Ex. 514: Carnival of Souls  - ['Horror', 'Thriller'] - Predicted:
# Ex. 515: Die Hard  - ['Action', 'Thriller'] - Predicted: Thriller,Action
# Ex. 516: Cool as Ice  - ['Drama'] - Predicted: Comedy
# Ex. 517: Mephisto  - ['Drama', 'War'] - Predicted: Drama
# Ex. 518: Legend  - ['Adventure', 'Fantasy', 'Romance'] - Predicted: Drama
# Ex. 519: In Dreams  - ['Thriller'] - Predicted:
# Ex. 520: Losing Chase  - ['Drama'] - Predicted: Drama
# Ex. 521: Castle, The  - ['Comedy'] - Predicted:
# Ex. 522: Absent Minded Professor, The  - ["Children's", 'Comedy', 'Fantasy'] - Predicted:
# Ex. 523: Velocity of Gary, The  - ['Comedy', 'Romance'] - Predicted: Drama
# Ex. 524: Breaker Morant  - ['Drama', 'War'] - Predicted:
# Ex. 525: Dream for an Insomniac  - ['Drama', 'Romance'] - Predicted: Drama
# Ex. 526: White Balloon, The (Badkonake Sefid )  - ['Drama'] - Predicted: Drama
# Ex. 527: Communion (a.k.a. Alice, Sweet Alice/Holy Terror)  - ['Horror'] - Predicted: Sci-Fi,Drama
# 16
# Ex. 528: Sorority House Massacre II  - ['Horror'] - Predicted: Horror
# Ex. 529: Brothers McMullen, The  - ['Comedy'] - Predicted: Drama
# Ex. 530: Little Rascals, The  - ["Children's", 'Comedy'] - Predicted: Drama
# Ex. 531: From the Hip  - ['Comedy'] - Predicted:
# Ex. 532: Women on the Verge of a Nervous Breakdown  - ['Comedy', 'Drama'] - Predicted:
# Ex. 533: Ed Wood  - ['Comedy', 'Drama'] - Predicted: Drama
# Ex. 534: Single Girl, A (La Fille Seule)  - ['Drama'] - Predicted: Action
# Ex. 535: Blade  - ['Action', 'Adventure', 'Horror'] - Predicted: Drama
# Ex. 536: Lost Horizon  - ['Drama'] - Predicted: Drama
# Ex. 537: Killer (Bulletproof Heart)  - ['Thriller'] - Predicted: Drama
# Ex. 538: Woman on Top  - ['Comedy', 'Romance'] - Predicted: Drama
# Ex. 539: My Life in Pink (Ma vie en rose)  - ['Comedy', 'Drama'] - Predicted:
# Ex. 540: Arthur  - ['Comedy', 'Romance'] - Predicted: Drama
# Ex. 541: MatchMaker, The  - ['Comedy', 'Romance'] - Predicted: Drama
# Ex. 542: Shawshank Redemption, The  - ['Drama'] - Predicted: Drama
# Ex. 543: Unzipped  - ['Documentary'] - Predicted: Drama
# 16
# Ex. 544: Indiana Jones and the Last Crusade  - ['Action', 'Adventure'] - Predicted:
# Ex. 545: Lawnmower Man, The  - ['Action', 'Sci-Fi', 'Thriller'] - Predicted: Thriller,Sci-Fi,Drama
# Ex. 546: Nothing to Lose  - ['Drama'] - Predicted: Comedy,Drama
# Ex. 547: Shooter, The  - ['Action'] - Predicted:
# Ex. 548: Apple Dumpling Gang Rides Again, The  - ["Children's", 'Comedy', 'Western'] - Predicted: Comedy,Children's
# Ex. 549: Vacation  - ['Comedy'] - Predicted:
# Ex. 550: Vagabond (Sans toit ni loi)  - ['Drama'] - Predicted:
# Ex. 551: Don't Look in the Basement!  - ['Horror'] - Predicted: Comedy,Drama
# Ex. 552: Even Cowgirls Get the Blues  - ['Comedy', 'Romance'] - Predicted:
# Ex. 553: Judge Dredd  - ['Action', 'Adventure', 'Sci-Fi'] - Predicted:
# Ex. 554: Dead Man on Campus  - ['Comedy'] - Predicted:
# Ex. 555: Inventing the Abbotts  - ['Drama', 'Romance'] - Predicted:
# Ex. 556: Disturbing Behavior  - ['Horror', 'Thriller'] - Predicted: Drama
# Ex. 557: Love & Sex  - ['Comedy', 'Romance'] - Predicted:
# Ex. 558: Lost in Space  - ['Action', 'Sci-Fi', 'Thriller'] - Predicted: Drama
# Ex. 559: Sliding Doors  - ['Drama', 'Romance'] - Predicted: Comedy
# 16
# Ex. 560: Man on the Moon  - ['Comedy', 'Drama'] - Predicted: Drama
# Ex. 561: Primary Colors  - ['Drama'] - Predicted: Drama
# Ex. 562: Gabbeh  - ['Drama'] - Predicted:
# Ex. 563: Killing Fields, The  - ['Drama', 'War'] - Predicted: Comedy,Drama
# Ex. 564: Sesame Street Presents Follow That Bird  - ["Children's", 'Comedy'] - Predicted: Comedy,Children's
# Ex. 565: Secret Adventures of Tom Thumb, The  - ['Adventure', "Children's"] - Predicted: Drama
# Ex. 566: Return of the Pink Panther, The  - ['Comedy'] - Predicted: Drama
# Ex. 567: Ed  - ['Comedy'] - Predicted:
# Ex. 568: Superman  - ['Action', 'Adventure', 'Sci-Fi'] - Predicted:
# Ex. 569: Red Rock West  - ['Thriller'] - Predicted:
# Ex. 570: No Looking Back  - ['Comedy', 'Drama', 'Romance'] - Predicted: Comedy
# Ex. 571: Patch Adams  - ['Comedy', 'Drama'] - Predicted: Drama
# Ex. 572: Bullets Over Broadway  - ['Comedy'] - Predicted: Drama
# Ex. 573: Object of My Affection, The  - ['Comedy', 'Romance'] - Predicted: Drama
# Ex. 574: Faces  - ['Drama'] - Predicted: Drama
# Ex. 575: Rounders  - ['Crime', 'Drama'] - Predicted: Drama
# 16
# Ex. 576: One Fine Day  - ['Drama', 'Romance'] - Predicted: Drama
# Ex. 577: Alan Smithee Film: Burn Hollywood Burn, An  - ['Comedy'] - Predicted: Comedy
# Ex. 578: Death Wish 4: The Crackdown  - ['Action', 'Drama'] - Predicted: Drama,Action
# Ex. 579: Shanghai Noon  - ['Action'] - Predicted: Western
# Ex. 580: Creature Comforts  - ['Animation', 'Comedy'] - Predicted:
# Ex. 581: Devil and Max Devlin, The  - ['Comedy'] - Predicted:
# Ex. 582: Small Time Crooks  - ['Comedy'] - Predicted: Drama,Children's
# Ex. 583: From Dusk Till Dawn  - ['Action', 'Comedy', 'Crime', 'Horror', 'Thriller'] - Predicted:
# Ex. 584: Big Blue, The (Le Grand Bleu)  - ['Adventure', 'Romance'] - Predicted: Comedy
# Ex. 585: Almost Heroes  - ['Adventure', 'Comedy'] - Predicted: Comedy,Drama
# Ex. 586: Cliffhanger  - ['Action', 'Adventure', 'Crime'] - Predicted: Drama
# Ex. 587: Celestial Clockwork  - ['Comedy'] - Predicted: Drama
# Ex. 588: Bad Seed, The  - ['Drama', 'Thriller'] - Predicted:
# Ex. 589: Career Girls  - ['Drama'] - Predicted: Drama
# Ex. 590: Picture Bride  - ['Drama', 'Romance'] - Predicted: Comedy,Romance
# Ex. 591: Tie Me Up! Tie Me Down!  - ['Drama'] - Predicted:
# 16
# Ex. 592: My Man Godfrey  - ['Comedy'] - Predicted: Comedy
# Ex. 593: Paper Chase, The  - ['Drama'] - Predicted: Comedy,Drama
# Ex. 594: Two Women (La Ciociara)  - ['Drama', 'War'] - Predicted: Drama
# Ex. 595: Coogan's Bluff  - ['Crime'] - Predicted:
# Ex. 596: Isn't She Great?  - ['Comedy'] - Predicted:
# Ex. 597: Rocky II  - ['Action', 'Drama'] - Predicted: Drama
# Ex. 598: Payback  - ['Action', 'Thriller'] - Predicted: Drama
# Ex. 599: Playing God  - ['Crime', 'Thriller'] - Predicted: Drama
# Ex. 600: Pagemaster, The  - ['Action', 'Adventure', 'Animation', "Children's", 'Fantasy'] - Predicted:
# Ex. 601: To Die For  - ['Comedy', 'Drama'] - Predicted: Drama
# Ex. 602: PokÃ©mon the Movie 2000  - ['Animation', "Children's"] - Predicted: Animation,Children's
# Ex. 603: My Favorite Year  - ['Comedy'] - Predicted:
# Ex. 604: I'm the One That I Want  - ['Comedy'] - Predicted: Comedy
# Ex. 605: Urbania  - ['Drama'] - Predicted:
# Ex. 606: Lodger, The  - ['Thriller'] - Predicted: Drama
# Ex. 607: Living Out Loud  - ['Comedy', 'Romance'] - Predicted: Comedy
# 16
# Ex. 608: Dirty Dancing  - ['Musical', 'Romance'] - Predicted: Drama
# Ex. 609: Hero  - ['Comedy', 'Drama'] - Predicted:
# Ex. 610: Final Destination  - ['Drama', 'Thriller'] - Predicted:
# Ex. 611: Fun and Fancy Free  - ['Animation', "Children's", 'Musical'] - Predicted:
# Ex. 612: Postman Always Rings Twice, The  - ['Crime', 'Thriller'] - Predicted: Drama
# Ex. 613: Night Falls on Manhattan  - ['Crime', 'Drama'] - Predicted:
# Ex. 614: Longest Day, The  - ['Action', 'Drama', 'War'] - Predicted:
# Ex. 615: Stupids, The  - ['Comedy'] - Predicted:
# Ex. 616: Philadelphia Story, The  - ['Comedy', 'Romance'] - Predicted: Drama
# Ex. 617: Murder at 1600  - ['Mystery', 'Thriller'] - Predicted: Thriller
# Ex. 618: Tombstone  - ['Western'] - Predicted: Drama
# Ex. 619: In Too Deep  - ['Action', 'Thriller'] - Predicted: Comedy
# Ex. 620: And God Created Woman  - ['Comedy', 'Drama', 'Romance'] - Predicted: Drama
# Ex. 621: Robocop  - ['Action', 'Crime', 'Sci-Fi'] - Predicted:
# Ex. 622: Edge, The  - ['Adventure', 'Thriller'] - Predicted: Comedy,Drama
# Ex. 623: Disclosure  - ['Drama', 'Thriller'] - Predicted: Drama
# 16
# Ex. 624: Blast from the Past  - ['Comedy', 'Romance'] - Predicted:
# Ex. 625: Malice  - ['Thriller'] - Predicted: Thriller
# Ex. 626: End of Days  - ['Action', 'Thriller'] - Predicted: Thriller,Drama
# Ex. 627: Children of the Corn II: The Final Sacrifice  - ['Horror'] - Predicted: Thriller
# Ex. 628: Cool Dry Place, A  - ['Drama'] - Predicted: Comedy
# Ex. 629: Hush  - ['Thriller'] - Predicted:
# Ex. 630: Mission: Impossible  - ['Action', 'Adventure', 'Mystery'] - Predicted: Thriller,Action
# Ex. 631: Sunshine  - ['Drama'] - Predicted: Comedy,Drama
# Ex. 632: My Fellow Americans  - ['Comedy'] - Predicted: Drama
# Ex. 633: Glory  - ['Action', 'Drama', 'War'] - Predicted: Drama
# Ex. 634: Crumb  - ['Documentary'] - Predicted:
# Ex. 635: Tango Lesson, The  - ['Romance'] - Predicted: Drama
# Ex. 636: Giant  - ['Drama'] - Predicted:
# Ex. 637: Network  - ['Comedy', 'Drama'] - Predicted: Drama
# Ex. 638: Getting Even with Dad  - ['Comedy'] - Predicted: Drama
# Ex. 639: Sister Act 2: Back in the Habit  - ['Comedy'] - Predicted: Crime,Comedy
# 14
# Ex. 560: Man on the Moon  - ['Comedy', 'Drama'] - Predicted: Comedy
# Ex. 561: Primary Colors  - ['Drama'] - Predicted: Thriller
# Ex. 562: Gabbeh  - ['Drama'] - Predicted: Action
# Ex. 563: Killing Fields, The  - ['Drama', 'War'] - Predicted:
# Ex. 564: Sesame Street Presents Follow That Bird  - ["Children's", 'Comedy'] - Predicted: Comedy,Drama
# Ex. 565: Secret Adventures of Tom Thumb, The  - ['Adventure', "Children's"] - Predicted: Horror
# Ex. 566: Return of the Pink Panther, The  - ['Comedy'] - Predicted: Comedy
# Ex. 567: Ed  - ['Comedy'] - Predicted: Horror
# Ex. 568: Superman  - ['Action', 'Adventure', 'Sci-Fi'] - Predicted: Thriller
# Ex. 569: Red Rock West  - ['Thriller'] - Predicted: Comedy
# Ex. 570: No Looking Back  - ['Comedy', 'Drama', 'Romance'] - Predicted: Adventure,Action
# Ex. 571: Patch Adams  - ['Comedy', 'Drama'] - Predicted:
# Ex. 572: Bullets Over Broadway  - ['Comedy'] - Predicted: Drama
# Ex. 573: Object of My Affection, The  - ['Comedy', 'Romance'] - Predicted:

# %% [markdown]
# # topk approach
# ## Used on both predict and evaluation via map@k

# %%
topk = 3
def percent_classes(model, title_tensor, img_tensor, topk=3):
  """
  Predict the top k classes and their corresponding percentage.
  ---------
  Params:
  model:  abstract class of nn.Module
          trained model
  title_tensor:   torch.Tensor
                  Tensor for text data, here is the title
  img_tensor: torch.Tensor
              Tensor for image data, here is the cover picture
  topk: int
        the top number of classes with highest predict percentage
  ---------
  Output:
  Tuple of Ndarray of top classes and their probabilities.
  """
  device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
  model.to(device)
  model.eval()

  with torch.no_grad():
    title_tensor, img_tensor = title_tensor.to(device), img_tensor.to(device)
    outputs = model(title_tensor, img_tensor)
    predicted_probs = torch.sigmoid(outputs)
    top_probs, top_classes = torch.topk(predicted_probs, topk, dim=1)
    top_probs = top_probs.cpu().numpy()
    top_classes = top_classes.cpu().numpy()

  return top_probs, top_classes

for test_idx, (title_tensor, img_tensor, genre_tensor) in enumerate(test_dataloader):
  titles = testing_set.data['title'].tolist()
  img_paths = testing_set.data['img_path'].tolist()
  genres = testing_set.data['genre'].tolist()
  target_title_tensor = title_tensor
  target_img_tensor = img_tensor
  top_probs, top_classes = percent_classes(model, target_title_tensor, target_img_tensor, topk=topk)
  for i in range(title_tensor.size(0)):
    index = test_idx * title_tensor.size(0) + i
    title = titles[index]
    genre = genres[index]
    predicted_categories = [genre_all[class_idx] for class_idx in top_classes[i]]
    predicted_probabilities = [f"{prob * 100:.2f}%" for prob in top_probs[i]]
    prediction = []
    for idx in range(topk):
      prediction.append(predicted_categories[idx] + "-" + predicted_probabilities[idx])
    print(f"Ex. {index}: {title} - {genre} - Predicted: {prediction} ")
# Out:
# Ex. 0: Great Muppet Caper, The  - ["Children's", 'Comedy'] - Predicted: ['Drama-44.90%', 'Musical-2.64%', "Children's-1.15%"]
# Ex. 1: Doctor Zhivago  - ['Drama', 'Romance', 'War'] - Predicted: ['Comedy-100.00%', 'Drama-0.55%', 'Documentary-0.00%']
# Ex. 2: Frankenstein Meets the Wolf Man  - ['Horror'] - Predicted: ['Drama-3.59%', 'Comedy-1.49%', 'Romance-0.07%']
# Ex. 3: For Your Eyes Only  - ['Action'] - Predicted: ['Comedy-7.41%', 'Drama-0.50%', 'Romance-0.21%']
# Ex. 4: Mirror, The (Zerkalo)  - ['Drama'] - Predicted: ['Comedy-77.30%', 'Drama-3.03%', 'Romance-0.07%']
# Ex. 5: Wolf  - ['Drama', 'Horror'] - Predicted: ['Drama-30.61%', 'Thriller-19.80%', 'Action-0.94%']
# Ex. 6: All Quiet on the Western Front  - ['War'] - Predicted: ['Drama-100.00%', 'Crime-0.00%', 'Comedy-0.00%']
# Ex. 7: Nelly & Monsieur Arnaud  - ['Drama'] - Predicted: ['Drama-90.19%', 'Comedy-19.75%', 'Thriller-0.12%']
# Ex. 8: Freedom for Us (Ã nous la libertÃ© )  - ['Comedy'] - Predicted: ['Drama-99.97%', 'Comedy-45.62%', 'Romance-3.89%']
# Ex. 9: Wag the Dog  - ['Comedy', 'Drama'] - Predicted: ['Drama-89.93%', 'Comedy-46.09%', 'Thriller-0.17%']
# Ex. 10: Thelma & Louise  - ['Action', 'Drama'] - Predicted: ['Drama-13.96%', 'Comedy-5.56%', 'Action-0.18%']
# Ex. 11: Prisoner of the Mountains (Kavkazsky Plennik)  - ['War'] - Predicted: ['Drama-98.45%', 'Thriller-6.22%', 'Romance-2.79%']
# Ex. 12: Great Race, The  - ['Comedy', 'Musical'] - Predicted: ['Drama-27.28%', 'Romance-0.43%', 'War-0.22%']
# Ex. 13: Splendor in the Grass  - ['Drama'] - Predicted: ['Comedy-99.99%', 'Drama-0.47%', 'Musical-0.07%']
# Ex. 14: Crime and Punishment in Suburbia  - ['Comedy', 'Drama'] - Predicted: ['Comedy-95.73%', 'Drama-75.03%', 'Romance-0.09%']
# Ex. 15: People vs. Larry Flynt, The  - ['Drama'] - Predicted: ['Drama-73.82%', 'Sci-Fi-0.31%', 'Action-0.06%']
# Ex. 16: Jade  - ['Thriller'] - Predicted: ['Drama-71.09%', 'Thriller-7.22%', 'Action-1.38%']
# Ex. 17: Wild Man Blues  - ['Documentary'] - Predicted: ['Drama-87.08%', 'Horror-6.53%', 'Western-5.68%']
# Ex. 18: When We Were Kings  - ['Documentary'] - Predicted: ['Drama-100.00%', 'Romance-0.05%', 'Comedy-0.01%']
# Ex. 19: Dead Poets Society  - ['Drama'] - Predicted: ['Comedy-66.05%', 'Drama-1.94%', 'Crime-1.88%']
# Ex. 20: Death Wish 3  - ['Action', 'Drama'] - Predicted: ['Drama-100.00%', 'Action-99.51%', 'Adventure-0.00%']
# Ex. 21: Other Sister, The  - ['Comedy', 'Drama', 'Romance'] - Predicted: ['Drama-99.98%', 'Comedy-44.46%', 'Romance-0.13%']
# Ex. 22: Henry: Portrait of a Serial Killer, Part 2  - ['Crime', 'Horror'] - Predicted: ['Drama-100.00%', 'War-79.59%', 'Crime-11.66%']
# Ex. 23: Heartburn  - ['Comedy', 'Drama'] - Predicted: ['Drama-96.25%', 'Comedy-13.17%', 'Romance-1.18%']
# Ex. 24: Taxi Driver  - ['Drama', 'Thriller'] - Predicted: ['Drama-62.12%', 'Comedy-5.68%', 'Action-0.05%']
# Ex. 25: Scream  - ['Horror', 'Thriller'] - Predicted: ['Thriller-99.31%', 'Mystery-5.68%', 'Drama-3.25%']
# Ex. 26: American Graffiti  - ['Comedy', 'Drama'] - Predicted: ['Comedy-99.15%', 'Musical-1.90%', 'Drama-0.39%']
# Ex. 27: Destination Moon  - ['Sci-Fi'] - Predicted: ['Drama-100.00%', 'Comedy-0.03%', 'Crime-0.00%']
# Ex. 28: Problem Child  - ['Comedy'] - Predicted: ['Comedy-100.00%', "Children's-0.01%", 'Musical-0.00%']
# Ex. 29: Love and a .45  - ['Thriller'] - Predicted: ['Comedy-98.21%', 'Romance-5.90%', 'Drama-0.87%']
# Ex. 30: Pitch Black  - ['Action', 'Sci-Fi'] - Predicted: ['Action-9.87%', 'Drama-9.25%', 'Comedy-1.39%']
# Ex. 31: Contempt (Le MÃ©pris)  - ['Drama'] - Predicted: ['Drama-88.26%', 'Comedy-87.63%', 'Romance-0.04%']
# Ex. 32: Love Bug, The  - ["Children's", 'Comedy'] - Predicted: ['Comedy-98.44%', 'Drama-5.66%', 'Romance-4.85%']
# Ex. 33: Sixth Man, The  - ['Comedy'] - Predicted: ['Comedy-31.84%', 'Thriller-18.06%', 'Drama-0.16%']
# Ex. 34: House on Haunted Hill, The  - ['Horror'] - Predicted: ['Horror-100.00%', 'Drama-0.18%', 'Comedy-0.02%']
# Ex. 35: 2010  - ['Mystery', 'Sci-Fi'] - Predicted: ['Drama-87.98%', 'Thriller-9.35%', 'Romance-0.57%']
# Ex. 36: Canadian Bacon  - ['Comedy', 'War'] - Predicted: ['Drama-72.10%', 'Comedy-2.83%', 'Thriller-0.13%']
# Ex. 37: Jack  - ['Comedy', 'Drama'] - Predicted: ['Drama-99.99%', 'Comedy-99.75%', 'Romance-0.03%']
# Ex. 38: Shooting Fish  - ['Romance'] - Predicted: ['Drama-88.41%', 'Comedy-0.81%', 'Romance-0.43%']
# Ex. 39: Grifters, The  - ['Crime', 'Drama', 'Film-Noir'] - Predicted: ['Drama-88.40%', 'Thriller-7.31%', 'Mystery-0.28%']
# Ex. 40: Mr. Jones  - ['Drama', 'Romance'] - Predicted: ['Romance-99.99%', 'Comedy-96.89%', 'Drama-0.19%']
# Ex. 41: Irma la Douce  - ['Comedy'] - Predicted: ['Drama-99.63%', 'Comedy-2.17%', 'Western-0.00%']
# Ex. 42: Village of the Damned  - ['Horror', 'Sci-Fi', 'Thriller'] - Predicted: ['Sci-Fi-97.52%', 'Thriller-58.13%', 'Horror-15.09%']
# Ex. 43: Dog's Life, A  - ['Comedy'] - Predicted: ['Drama-99.97%', 'Comedy-1.26%', 'Western-0.08%']
# Ex. 44: Omen, The  - ['Horror'] - Predicted: ['Drama-77.75%', 'Thriller-1.13%', 'Mystery-0.23%']
# Ex. 45: Hard 8 (a.k.a. Sydney, a.k.a. Hard Eight)  - ['Crime', 'Thriller'] - Predicted: ['Comedy-96.70%', 'Romance-14.78%', 'Western-7.81%']
# Ex. 46: Nosferatu (Nosferatu, eine Symphonie des Grauens)  - ['Horror'] - Predicted: ['Horror-90.60%', 'Sci-Fi-27.25%', 'Comedy-0.27%']
# Ex. 47: Come See the Paradise  - ['Drama', 'Romance'] - Predicted: ['Drama-98.13%', 'Western-1.36%', 'Mystery-0.98%']
# Ex. 48: Persuasion  - ['Romance'] - Predicted: ['Drama-74.48%', 'Comedy-3.99%', 'Action-0.37%']
# Ex. 49: Sixteen Candles  - ['Comedy'] - Predicted: ['Drama-81.74%', 'Comedy-67.78%', 'Romance-0.02%']
# Ex. 50: Short Cuts  - ['Drama'] - Predicted: ['Drama-99.18%', 'Comedy-93.11%', 'Thriller-0.14%']
# Ex. 51: Last Action Hero  - ['Action', 'Comedy'] - Predicted: ['Drama-42.18%', 'War-0.04%', 'Comedy-0.03%']
# Ex. 52: Patriot Games  - ['Action', 'Thriller'] - Predicted: ['Drama-57.15%', 'Comedy-4.96%', 'Action-0.09%']
# Ex. 53: Good, The Bad and The Ugly, The  - ['Action', 'Western'] - Predicted: ['Drama-98.20%', 'War-0.08%', 'Action-0.02%']
# Ex. 54: War, The  - ['Adventure', 'Drama'] - Predicted: ['Drama-99.90%', 'Action-0.36%', 'Mystery-0.24%']
# Ex. 55: Jaws 2  - ['Action', 'Horror'] - Predicted: ['Horror-99.98%', 'Action-87.54%', 'Sci-Fi-2.35%']
# Ex. 56: Reindeer Games  - ['Action', 'Thriller'] - Predicted: ['Drama-83.10%', 'Thriller-4.50%', 'Crime-0.93%']
# Ex. 57: King of the Hill  - ['Drama'] - Predicted: ['Drama-93.24%', 'Comedy-0.46%', 'Documentary-0.24%']
# Ex. 58: Re-Animator  - ['Horror'] - Predicted: ['Drama-5.32%', 'Comedy-4.58%', 'Action-2.09%']
# Ex. 59: They Shoot Horses, Don't They?  - ['Drama'] - Predicted: ['Drama-100.00%', 'Romance-3.68%', 'Mystery-0.28%']
# Ex. 60: Shall We Dance? (Shall We Dansu?)  - ['Comedy'] - Predicted: ['Drama-39.89%', "Children's-4.29%", 'Sci-Fi-2.32%']
# Ex. 61: Pocahontas  - ['Animation', "Children's", 'Musical', 'Romance'] - Predicted: ['Drama-20.70%', 'Comedy-2.47%', 'Action-1.65%']
# Ex. 62: Stalingrad  - ['War'] - Predicted: ['Comedy-80.00%', 'Drama-1.03%', 'Romance-0.15%']
# Ex. 63: Plunkett & MaCleane  - ['Action', 'Drama'] - Predicted: ['Drama-56.71%', 'Comedy-3.29%', 'Horror-0.17%']
# Ex. 64: Foxfire  - ['Drama'] - Predicted: ['Drama-72.15%', 'Comedy-8.16%', 'Thriller-0.44%']
# Ex. 65: Four Days in September  - ['Drama'] - Predicted: ['Comedy-99.48%', 'Horror-0.95%', 'Action-0.44%']
# Ex. 66: Threesome  - ['Comedy', 'Romance'] - Predicted: ['Drama-57.38%', 'Comedy-2.99%', 'Romance-0.64%']
# Ex. 67: Lady of Burlesque  - ['Comedy', 'Mystery'] - Predicted: ['Comedy-95.79%', 'Romance-55.38%', 'Thriller-41.81%']
# Ex. 68: Alice and Martin (Alice et Martin)  - ['Drama'] - Predicted: ['Drama-99.99%', 'Musical-1.55%', "Children's-0.03%"]
# Ex. 69: Great Mouse Detective, The  - ['Animation', "Children's"] - Predicted: ['Drama-76.61%', 'Comedy-0.52%', 'Musical-0.37%']
# Ex. 70: Gentleman's Agreement  - ['Drama'] - Predicted: ['Comedy-68.63%', 'Musical-1.08%', 'Drama-0.08%']
# Ex. 71: Fathers' Day  - ['Comedy'] - Predicted: ['Drama-92.18%', 'Comedy-5.95%', 'Romance-0.26%']
# Ex. 72: Crossing Guard, The  - ['Drama'] - Predicted: ['Drama-79.96%', 'Thriller-0.61%', 'Comedy-0.15%']
# Ex. 73: Iron Giant, The  - ['Animation', "Children's"] - Predicted: ['Comedy-99.55%', 'Action-80.12%', 'War-0.11%']
# Ex. 74: Boys on the Side  - ['Comedy', 'Drama'] - Predicted: ['Drama-100.00%', 'Romance-9.55%', 'Thriller-0.01%']
# Ex. 75: Ruthless People  - ['Comedy'] - Predicted: ['Comedy-99.68%', 'Drama-0.22%', 'Action-0.01%']
# Ex. 76: You Can't Take It With You  - ['Comedy'] - Predicted: ['Comedy-99.96%', 'Romance-0.15%', 'Western-0.07%']
# Ex. 77: Blue Chips  - ['Drama'] - Predicted: ['Comedy-99.54%', 'Romance-64.13%', 'Drama-1.19%']
# Ex. 78: I Know What You Did Last Summer  - ['Horror', 'Mystery', 'Thriller'] - Predicted: ['Thriller-98.52%', 'Sci-Fi-94.82%', 'Romance-39.06%']
# Ex. 79: Alien Nation  - ['Crime', 'Drama', 'Sci-Fi'] - Predicted: ['Thriller-97.48%', 'Action-88.70%', 'Sci-Fi-70.19%']
# Ex. 80: Trading Places  - ['Comedy'] - Predicted: ['Drama-85.74%', 'Comedy-4.45%', 'Western-0.11%']
# Ex. 81: Things Change  - ['Comedy'] - Predicted: ['Drama-99.98%', 'Comedy-18.82%', 'Romance-1.68%']
# Ex. 82: Bossa Nova  - ['Comedy'] - Predicted: ['Comedy-63.83%', 'Drama-3.53%', 'Action-0.01%']
# Ex. 83: Pompatus of Love, The  - ['Comedy', 'Drama'] - Predicted: ['Comedy-81.47%', 'Drama-0.47%', 'Romance-0.01%']
# Ex. 84: Silent Fall  - ['Drama', 'Thriller'] - Predicted: ['Drama-96.23%', 'Thriller-15.59%', 'Crime-0.39%']
# Ex. 85: Cruel Intentions  - ['Drama'] - Predicted: ['Drama-92.83%', 'Thriller-5.33%', 'Crime-0.43%']
# Ex. 86: Just Cause  - ['Mystery', 'Thriller'] - Predicted: ['Drama-90.86%', 'Crime-0.46%', 'Action-0.28%']
# Ex. 87: West Side Story  - ['Musical', 'Romance'] - Predicted: ['Drama-99.98%', 'Comedy-10.03%', 'Romance-0.02%']
# Ex. 88: Spartacus  - ['Drama'] - Predicted: ['Drama-3.70%', 'Comedy-0.82%', 'Action-0.53%']
# Ex. 89: Play it to the Bone  - ['Comedy', 'Drama'] - Predicted: ['Comedy-94.75%', 'Drama-0.41%', 'Western-0.04%']
# Ex. 90: Amityville: Dollhouse  - ['Horror'] - Predicted: ['Horror-60.20%', 'Thriller-0.73%', 'Drama-0.42%']
# Ex. 91: March of the Wooden Soldiers (a.k.a. Laurel & Hardy in Toyland)  - ['Comedy'] - Predicted: ['Mystery-32.31%', 'Musical-15.38%', 'Romance-12.62%']
# Ex. 92: Forces of Nature  - ['Comedy', 'Romance'] - Predicted: ['Comedy-10.84%', 'Drama-0.08%', 'Romance-0.08%']
# Ex. 93: Modern Times  - ['Comedy'] - Predicted: ['Comedy-97.60%', 'Drama-12.49%', 'Western-0.00%']
# Ex. 94: Bronco Billy  - ['Adventure', 'Drama', 'Romance'] - Predicted: ['Drama-14.98%', 'Western-1.53%', 'Comedy-1.27%']
# Ex. 95: Pulp Fiction  - ['Crime', 'Drama'] - Predicted: ['Drama-45.71%', 'Comedy-16.63%', 'Horror-0.02%']
# Ex. 96: Welcome To Sarajevo  - ['Drama', 'War'] - Predicted: ['Comedy-99.97%', 'Drama-99.91%', 'Romance-0.06%']
# Ex. 97: Trixie  - ['Comedy'] - Predicted: ['Crime-5.28%', 'Drama-4.83%', 'Comedy-0.97%']
# Ex. 98: Faster Pussycat! Kill! Kill!  - ['Action', 'Comedy', 'Drama'] - Predicted: ['Action-96.60%', 'War-0.12%', 'Thriller-0.06%']
# Ex. 99: Sum of Us, The  - ['Comedy'] - Predicted: ['Drama-99.99%', 'Comedy-88.38%', 'Romance-0.02%']
# Ex. 100: Nurse Betty  - ['Comedy', 'Thriller'] - Predicted: ['Drama-54.65%', 'Comedy-38.92%', 'Crime-0.00%']
# Ex. 101: Dead Ringers  - ['Drama', 'Thriller'] - Predicted: ['Drama-21.80%', 'Crime-6.45%', 'Action-4.00%']
# Ex. 102: Devil's Own, The  - ['Action', 'Drama', 'Thriller', 'War'] - Predicted: ['Thriller-97.71%', 'Drama-67.23%', 'Horror-42.15%']
# Ex. 103: Creepshow  - ['Horror'] - Predicted: ['Drama-42.63%', 'Western-3.28%', 'Mystery-0.81%']
# Ex. 104: Grand Day Out, A  - ['Animation', 'Comedy'] - Predicted: ['Drama-100.00%', 'Crime-0.34%', 'War-0.00%']
# Ex. 105: Devil Girl From Mars  - ['Sci-Fi'] - Predicted: ['Action-61.19%', 'Comedy-33.07%', 'Western-1.81%']
# Ex. 106: Mission to Mars  - ['Sci-Fi'] - Predicted: ['Drama-87.24%', 'Thriller-72.53%', 'Action-30.99%']
# Ex. 107: Mother Night  - ['Drama'] - Predicted: ['Comedy-99.97%', 'Thriller-12.33%', 'Action-0.88%']
# Ex. 108: Postino, Il (The Postman)  - ['Drama', 'Romance'] - Predicted: ['Drama-97.08%', 'Comedy-0.55%', 'Musical-0.19%']
# Ex. 109: Hellraiser: Bloodline  - ['Action', 'Horror', 'Sci-Fi'] - Predicted: ['Horror-98.69%', 'Drama-0.94%', 'Comedy-0.27%']
# Ex. 110: BASEketball  - ['Comedy'] - Predicted: ['Comedy-48.48%', 'Drama-8.75%', 'Musical-0.07%']
# Ex. 111: Angel Heart  - ['Film-Noir', 'Mystery', 'Thriller'] - Predicted: ['Drama-100.00%', 'Crime-0.01%', 'Thriller-0.00%']
# Ex. 112: Frankie Starlight  - ['Drama', 'Romance'] - Predicted: ['Drama-71.90%', 'Thriller-0.25%', 'Western-0.23%']
# Ex. 113: Flirting With Disaster  - ['Comedy'] - Predicted: ['Drama-91.43%', 'Comedy-10.83%', 'Romance-0.27%']
# Ex. 114: Tales from the Hood  - ['Comedy', 'Horror'] - Predicted: ['Horror-78.18%', 'Sci-Fi-23.13%', 'Thriller-0.54%']
# Ex. 115: Bad Moon  - ['Horror'] - Predicted: ['Drama-83.72%', 'Action-11.03%', 'Thriller-1.49%']
# Ex. 116: Farewell My Concubine  - ['Drama', 'Romance'] - Predicted: ['Drama-99.46%', 'Comedy-98.40%', 'Thriller-0.00%']
# Ex. 117: Black Dog  - ['Action', 'Thriller'] - Predicted: ['Drama-93.30%', 'Comedy-43.91%', 'Romance-0.04%']
# Ex. 118: Butcher Boy, The  - ['Drama'] - Predicted: ['Drama-51.82%', 'Comedy-8.35%', 'Thriller-0.10%']
# Ex. 119: Sword in the Stone, The  - ['Animation', "Children's"] - Predicted: ['Comedy-20.45%', 'Drama-5.48%', 'Musical-0.46%']
# Ex. 120: Wings  - ['Drama', 'Romance', 'War'] - Predicted: ['Comedy-91.63%', 'Drama-35.46%', 'Musical-0.87%']
# Ex. 121: Michael Collins  - ['Drama', 'War'] - Predicted: ['Comedy-100.00%', 'Romance-82.81%', 'Drama-0.17%']
# Ex. 122: Wedding Singer, The  - ['Comedy', 'Romance'] - Predicted: ['Drama-99.15%', 'Action-0.36%', 'Crime-0.06%']
# Ex. 123: Whipped  - ['Comedy'] - Predicted: ['Drama-26.10%', 'Comedy-25.00%', 'Romance-0.09%']
# Ex. 124: Waterboy, The  - ['Comedy'] - Predicted: ['Drama-69.45%', 'Comedy-4.94%', 'War-0.05%']
# Ex. 125: Ghost and the Darkness, The  - ['Action', 'Adventure'] - Predicted: ['Romance-82.08%', 'Comedy-11.50%', 'Drama-2.21%']
# Ex. 126: Robocop 3  - ['Sci-Fi', 'Thriller'] - Predicted: ['Drama-63.29%', 'Mystery-7.02%', 'Thriller-4.74%']
# Ex. 127: Little Odessa  - ['Drama'] - Predicted: ['Drama-90.51%', 'Comedy-1.59%', 'Crime-0.63%']
# Ex. 128: Moonstruck  - ['Comedy'] - Predicted: ['Drama-64.52%', 'Thriller-1.66%', 'Comedy-0.85%']
# Ex. 129: My Best Fiend (Mein liebster Feind)  - ['Documentary'] - Predicted: ['Comedy-100.00%', 'Drama-37.26%', 'Romance-29.74%']
# Ex. 130: Greatest Show on Earth, The  - ['Drama'] - Predicted: ['Drama-98.72%', 'Comedy-0.07%', 'Western-0.04%']
# Ex. 131: Alvarez Kelly  - ['Western'] - Predicted: ['Drama-61.27%', 'Comedy-6.37%', 'Western-0.93%']
# Ex. 132: Goofy Movie, A  - ['Animation', "Children's", 'Comedy', 'Romance'] - Predicted: ['Comedy-99.50%', "Children's-25.01%", 'Animation-18.07%']
# Ex. 133: Cook the Thief His Wife & Her Lover, The  - ['Drama'] - Predicted: ['Thriller-69.63%', 'Drama-67.62%', 'Action-20.93%']
# Ex. 134: How to Stuff a Wild Bikini  - ['Comedy'] - Predicted: ['Drama-99.94%', 'Comedy-98.63%', "Children's-0.30%"]
# Ex. 135: Getaway, The  - ['Action'] - Predicted: ['Drama-92.51%', 'Thriller-19.11%', 'Western-9.53%']
# Ex. 136: Limbo  - ['Drama'] - Predicted: ['Drama-81.89%', 'Thriller-5.88%', 'Action-0.63%']
# Ex. 137: Heavyweights  - ["Children's", 'Comedy'] - Predicted: ['Comedy-66.24%', "Children's-1.53%", 'Drama-0.27%']
# Ex. 138: Switchback  - ['Thriller'] - Predicted: ['Drama-58.88%', 'Thriller-32.15%', 'Action-0.29%']
# Ex. 139: Grace of My Heart  - ['Comedy', 'Drama'] - Predicted: ['Drama-100.00%', 'Comedy-0.08%', 'Crime-0.00%']
# Ex. 140: I Love Trouble  - ['Action', 'Comedy'] - Predicted: ['Drama-96.33%', 'Comedy-78.42%', 'Romance-1.94%']
# Ex. 141: Creature From the Black Lagoon, The  - ['Horror'] - Predicted: ['Comedy-1.30%', 'Western-0.31%', 'Thriller-0.05%']
# Ex. 142: Poison Ivy: New Seduction  - ['Thriller'] - Predicted: ['Thriller-100.00%', 'Comedy-0.11%', 'Crime-0.09%']
# Ex. 143: Fly Away Home  - ['Adventure', "Children's"] - Predicted: ['Romance-5.16%', 'Comedy-0.05%', 'Drama-0.05%']
# Ex. 144: Big Night  - ['Drama'] - Predicted: ['Comedy-97.67%', 'Thriller-9.94%', 'Drama-4.21%']
# Ex. 145: Three Days of the Condor  - ['Thriller'] - Predicted: ['Drama-72.49%', 'Western-17.10%', 'Comedy-10.81%']
# Ex. 146: Strawberry and Chocolate (Fresa y chocolate)  - ['Drama'] - Predicted: ['Drama-72.51%', 'Musical-0.02%', 'Comedy-0.01%']
# Ex. 147: 187  - ['Drama'] - Predicted: ['Thriller-79.24%', 'Drama-70.96%', 'Crime-1.48%']
# Ex. 148: Ride with the Devil  - ['Drama', 'Romance', 'War'] - Predicted: ['Drama-99.28%', 'Comedy-24.43%', 'Romance-0.65%']
# Ex. 149: Midnight Express  - ['Drama'] - Predicted: ['Drama-99.97%', 'Mystery-64.40%', 'Musical-0.54%']
# Ex. 150: Oliver!  - ['Musical'] - Predicted: ["Children's-71.23%", 'Comedy-6.79%', 'Animation-3.84%']
# Ex. 151: Hollywood Knights, The  - ['Comedy'] - Predicted: ['Drama-33.97%', 'Comedy-11.63%', "Children's-0.03%"]
# Ex. 152: While You Were Sleeping  - ['Comedy', 'Romance'] - Predicted: ['Comedy-99.32%', 'Drama-63.15%', 'Romance-1.88%']
# Ex. 153: Rescuers, The  - ['Animation', "Children's"] - Predicted: ['Comedy-3.42%', 'Animation-0.47%', "Children's-0.11%"]
# Ex. 154: Barney's Great Adventure  - ['Adventure', "Children's"] - Predicted: ['Comedy-99.42%', "Children's-37.76%", 'Animation-1.02%']
# Ex. 155: New Age, The  - ['Drama'] - Predicted: ['Drama-100.00%', 'Comedy-1.19%', 'War-0.05%']
# Ex. 156: On the Ropes  - ['Documentary'] - Predicted: ['Drama-99.99%', 'Crime-0.30%', 'Thriller-0.16%']
# Ex. 157: Marked for Death  - ['Action', 'Drama'] - Predicted: ['Drama-96.03%', 'Thriller-46.95%', 'Comedy-2.92%']
# Ex. 158: Man for All Seasons, A  - ['Drama'] - Predicted: ['Drama-93.14%', 'Comedy-1.20%', 'War-0.00%']
# Ex. 159: Spy Hard  - ['Comedy'] - Predicted: ['Action-99.83%', 'Thriller-71.57%', 'Drama-0.15%']
# Ex. 160: Birdcage, The  - ['Comedy'] - Predicted: ['Drama-3.67%', 'Action-2.48%', 'Thriller-1.84%']
# Ex. 161: Dying Young  - ['Drama', 'Romance'] - Predicted: ['Drama-48.96%', 'Sci-Fi-3.25%', 'Romance-2.78%']
# Ex. 162: My Science Project  - ['Adventure', 'Sci-Fi'] - Predicted: ['Comedy-99.02%', 'Romance-0.01%', 'Western-0.00%']
# Ex. 163: White Men Can't Jump  - ['Comedy'] - Predicted: ['Comedy-89.06%', 'Action-13.75%', 'Drama-1.87%']
# Ex. 164: Hard Rain  - ['Action', 'Thriller'] - Predicted: ['Comedy-98.65%', 'Western-0.23%', 'Musical-0.20%']
# Ex. 165: Dogma  - ['Comedy'] - Predicted: ['Drama-35.56%', 'Comedy-2.76%', 'Action-0.69%']
# Ex. 166: In the Name of the Father  - ['Drama'] - Predicted: ['Thriller-56.91%', 'Action-3.66%', 'Horror-1.85%']
# Ex. 167: Love Stinks  - ['Comedy'] - Predicted: ['Comedy-99.70%', 'Romance-87.26%', 'Drama-0.10%']
# Ex. 168: Wonderland  - ['Drama'] - Predicted: ['Documentary-24.18%', 'Sci-Fi-10.62%', 'Mystery-1.28%']
# Ex. 169: Live Flesh  - ['Drama'] - Predicted: ['Action-99.71%', 'Thriller-80.73%', 'Drama-42.74%']
# Ex. 170: Hell Night  - ['Horror'] - Predicted: ['Comedy-21.97%', 'Thriller-4.46%', 'Action-1.18%']
# Ex. 171: Men With Guns  - ['Action', 'Drama'] - Predicted: ['Action-84.74%', 'Adventure-35.95%', 'Drama-29.42%']
# Ex. 172: Patton  - ['Drama', 'War'] - Predicted: ['Drama-89.35%', 'Comedy-49.62%', "Children's-0.09%"]
# Ex. 173: Governess, The  - ['Drama', 'Romance'] - Predicted: ['Drama-78.93%', 'Action-6.04%', 'Thriller-0.92%']
# Ex. 174: Apollo 13  - ['Drama'] - Predicted: ['Thriller-18.68%', 'Action-3.80%', 'Drama-1.08%']
# Ex. 175: King Kong vs. Godzilla (Kingukongu tai Gojira)  - ['Action', 'Sci-Fi'] - Predicted: ['Action-77.09%', 'Adventure-67.16%', 'War-21.75%']
# Ex. 176: Johnny Mnemonic  - ['Action', 'Sci-Fi', 'Thriller'] - Predicted: ['Drama-22.26%', 'Action-1.80%', 'Comedy-1.03%']
# Ex. 177: Waking Ned Devine  - ['Comedy'] - Predicted: ['Drama-99.98%', 'Comedy-23.67%', 'Romance-0.00%']
# Ex. 178: Angels in the Outfield  - ["Children's", 'Comedy'] - Predicted: ['Comedy-90.63%', 'Drama-4.11%', "Children's-0.46%"]
# Ex. 179: Psycho II  - ['Horror', 'Thriller'] - Predicted: ['Horror-99.91%', 'Thriller-99.81%', 'Comedy-4.26%']
# Ex. 180: Air Force One  - ['Action', 'Thriller'] - Predicted: ['Comedy-100.00%', 'Western-23.08%', 'Drama-0.05%']
# Ex. 181: 42 Up  - ['Documentary'] - Predicted: ['Drama-99.93%', 'Comedy-95.22%', 'Romance-0.07%']
# Ex. 182: Tom and Huck  - ['Adventure', "Children's"] - Predicted: ['Drama-99.91%', 'Western-0.05%', 'Comedy-0.01%']
# Ex. 183: Friday the 13th Part VI: Jason Lives  - ['Horror'] - Predicted: ['Horror-100.00%', 'Thriller-0.02%', 'Drama-0.01%']
# Ex. 184: Galaxy Quest  - ['Adventure', 'Comedy', 'Sci-Fi'] - Predicted: ['Drama-31.69%', 'Comedy-13.14%', 'Action-0.37%']
# Ex. 185: Othello  - ['Drama'] - Predicted: ['Drama-100.00%', 'Thriller-0.02%', 'Crime-0.01%']
# Ex. 186: Swan Princess, The  - ['Animation', "Children's"] - Predicted: ['Drama-92.28%', "Children's-75.47%", 'War-0.30%']
# Ex. 187: Zero Effect  - ['Comedy', 'Thriller'] - Predicted: ['Drama-99.90%', 'Thriller-1.28%', 'Crime-0.19%']
# Ex. 188: Blow-Out (La Grande Bouffe)  - ['Drama'] - Predicted: ['Drama-99.70%', 'War-0.24%', 'Crime-0.00%']
# Ex. 189: Miami Rhapsody  - ['Comedy'] - Predicted: ['Drama-93.23%', 'Thriller-2.08%', 'Comedy-0.14%']
# Ex. 190: Tie That Binds, The  - ['Thriller'] - Predicted: ['Drama-0.70%', 'Horror-0.33%', 'Western-0.14%']
# Ex. 191: Boys  - ['Drama'] - Predicted: ['Drama-99.95%', 'Romance-37.88%', 'Thriller-25.68%']
# Ex. 192: Swamp Thing  - ['Horror', 'Sci-Fi'] - Predicted: ['Drama-90.32%', 'Comedy-5.69%', 'Romance-2.92%']
# Ex. 193: Richie Rich  - ["Children's", 'Comedy'] - Predicted: ['Drama-98.03%', 'Comedy-81.65%', 'Romance-0.08%']
# Ex. 194: Plenty  - ['Drama'] - Predicted: ['Drama-96.07%', 'Comedy-4.55%', 'Thriller-0.27%']
# Ex. 195: Davy Crockett, King of the Wild Frontier  - ['Western'] - Predicted: ['Drama-99.00%', 'Western-0.01%', 'Mystery-0.01%']
# Ex. 196: Godzilla (Gojira)  - ['Action', 'Sci-Fi'] - Predicted: ['Action-42.89%', 'Sci-Fi-8.95%', 'Thriller-6.98%']
# Ex. 197: Adventures of Robin Hood, The  - ['Action', 'Adventure'] - Predicted: ['Comedy-39.95%', 'Adventure-3.28%', "Children's-2.37%"]
# Ex. 198: Ghostbusters II  - ['Comedy', 'Horror'] - Predicted: ['Horror-100.00%', 'Comedy-99.93%', 'Western-0.59%']
# Ex. 199: Alive  - ['Drama'] - Predicted: ['Drama-98.83%', 'Comedy-83.37%', 'Romance-2.34%']
# Ex. 200: Faculty, The  - ['Horror', 'Sci-Fi'] - Predicted: ['Drama-27.71%', 'Horror-5.91%', 'Action-2.09%']
# Ex. 201: Dumb & Dumber  - ['Comedy'] - Predicted: ['Drama-67.51%', 'Comedy-1.84%', 'Romance-0.40%']
# Ex. 202: Medicine Man  - ['Adventure', 'Romance'] - Predicted: ['Drama-88.40%', 'Thriller-2.01%', 'Comedy-1.10%']
# Ex. 203: Mrs. Miniver  - ['Drama', 'War'] - Predicted: ['Comedy-98.11%', 'Musical-0.56%', 'Drama-0.38%']
# Ex. 204: Sabotage  - ['Thriller'] - Predicted: ['Comedy-36.12%', 'Animation-26.04%', "Children's-12.59%"]
# Ex. 205: Last of the Mohicans, The  - ['Action', 'Romance', 'War'] - Predicted: ['Drama-3.28%', 'Documentary-0.03%', 'Mystery-0.02%']
# Ex. 206: Kronos  - ['Horror'] - Predicted: ['Sci-Fi-62.02%', 'Thriller-2.10%', 'Drama-1.90%']
# Ex. 207: Glass Bottom Boat, The  - ['Comedy', 'Romance'] - Predicted: ['Drama-100.00%', 'Comedy-6.03%', 'Crime-3.78%']
# Ex. 208: Gossip  - ['Drama', 'Thriller'] - Predicted: ['Drama-78.93%', 'Thriller-3.60%', 'Comedy-1.27%']
# Ex. 209: Killer Shrews, The  - ['Horror', 'Sci-Fi'] - Predicted: ['Drama-25.99%', 'Thriller-0.35%', 'Action-0.28%']
# Ex. 210: Next Stop, Wonderland  - ['Comedy', 'Drama', 'Romance'] - Predicted: ['Drama-99.51%', 'Comedy-88.31%', 'Musical-0.49%']
# Ex. 211: Poltergeist III  - ['Horror', 'Thriller'] - Predicted: ['Horror-100.00%', 'Thriller-95.24%', 'Sci-Fi-0.21%']
# Ex. 212: Saturn 3  - ['Adventure', 'Sci-Fi', 'Thriller'] - Predicted: ['Mystery-88.57%', 'Sci-Fi-4.93%', 'Action-0.72%']
# Ex. 213: Mr. Saturday Night  - ['Comedy', 'Drama'] - Predicted: ['Comedy-99.99%', 'Romance-18.06%', 'Drama-17.55%']
# Ex. 214: American Flyers  - ['Drama'] - Predicted: ['Comedy-98.94%', 'Drama-28.31%', 'Documentary-0.43%']
# Ex. 215: Land Before Time III: The Time of the Great Giving  - ['Animation', "Children's"] - Predicted: ["Children's-77.97%", 'War-67.09%', 'Comedy-30.51%']
# Ex. 216: Quiz Show  - ['Drama'] - Predicted: ['Drama-99.95%', 'Thriller-0.69%', 'Crime-0.05%']
# Ex. 217: Whatever It Takes  - ['Comedy', 'Romance'] - Predicted: ['Drama-99.40%', 'Comedy-64.41%', 'Crime-0.00%']
# Ex. 218: Private School  - ['Comedy'] - Predicted: ['Comedy-99.92%', 'Drama-0.60%', 'Musical-0.01%']
# Ex. 219: Princess Caraboo  - ['Drama'] - Predicted: ['Comedy-98.61%', 'Action-4.47%', 'Romance-1.01%']
# Ex. 220: Kids  - ['Drama'] - Predicted: ['Comedy-78.72%', 'Drama-0.63%', 'Action-0.25%']
# Ex. 221: Superman II  - ['Action', 'Adventure', 'Sci-Fi'] - Predicted: ['Comedy-0.19%', 'Horror-0.08%', 'Sci-Fi-0.02%']
# Ex. 222: Hollow Man  - ['Horror', 'Sci-Fi', 'Thriller'] - Predicted: ['Drama-85.13%', 'Thriller-56.56%', 'Romance-1.73%']
# Ex. 223: Nico Icon  - ['Documentary'] - Predicted: ['Drama-34.50%', 'Action-1.30%', 'Comedy-1.27%']
# Ex. 224: H.O.T.S.  - ['Comedy'] - Predicted: ['Drama-74.74%', 'Comedy-19.51%', 'Thriller-0.04%']
# Ex. 225: Nell  - ['Drama'] - Predicted: ['Drama-99.59%', 'Comedy-9.02%', 'Thriller-0.43%']
# Ex. 226: Far From Home: The Adventures of Yellow Dog  - ['Adventure', "Children's"] - Predicted: ['Comedy-10.88%', 'Adventure-7.52%', 'Action-6.59%']
# Ex. 227: Stop! Or My Mom Will Shoot  - ['Action', 'Comedy'] - Predicted: ['Drama-98.83%', 'Romance-16.56%', 'Documentary-0.50%']
# Ex. 228: I'll Do Anything  - ['Comedy', 'Drama'] - Predicted: ['Drama-99.52%', 'Comedy-40.49%', 'Romance-0.18%']
# Ex. 229: Verdict, The  - ['Drama'] - Predicted: ['Drama-80.46%', 'Thriller-10.96%', 'Action-0.45%']
# Ex. 230: Next Friday  - ['Comedy'] - Predicted: ['Comedy-100.00%', "Children's-48.90%", 'Drama-0.20%']
# Ex. 231: Heidi Fleiss: Hollywood Madam  - ['Documentary'] - Predicted: ['Comedy-7.58%', 'Drama-4.78%', 'Action-0.07%']
# Ex. 232: Damien: Omen II  - ['Horror'] - Predicted: ['Comedy-46.84%', 'Drama-45.43%', 'Thriller-0.01%']
# Ex. 233: Assignment, The  - ['Thriller'] - Predicted: ['Drama-34.98%', 'Horror-0.80%', 'Comedy-0.62%']
# Ex. 234: Sugarland Express, The  - ['Drama'] - Predicted: ['Drama-96.55%', 'Western-1.32%', 'Mystery-1.08%']
# Ex. 235: Star Trek: Insurrection  - ['Action', 'Sci-Fi'] - Predicted: ['Sci-Fi-100.00%', 'Action-99.99%', 'Adventure-99.88%']
# Ex. 236: All Dogs Go to Heaven 2  - ['Animation', "Children's", 'Musical'] - Predicted: ['Drama-100.00%', 'Thriller-0.00%', 'Comedy-0.00%']
# Ex. 237: Rambo III  - ['Action', 'War'] - Predicted: ['Drama-71.10%', 'War-40.49%', 'Crime-1.14%']
# Ex. 238: Rage: Carrie 2, The  - ['Horror'] - Predicted: ['Drama-13.36%', 'Comedy-5.33%', 'Action-0.49%']
# Ex. 239: Cousin Bette  - ['Comedy'] - Predicted: ['Drama-50.22%', 'Comedy-1.71%', 'Action-1.28%']
# Ex. 240: Rocky V  - ['Action', 'Drama'] - Predicted: ['Drama-100.00%', 'War-21.55%', 'Action-10.16%']
# Ex. 241: Misery  - ['Horror'] - Predicted: ['Drama-20.83%', 'Sci-Fi-7.60%', 'Action-4.07%']
# Ex. 242: Snow Falling on Cedars  - ['Drama'] - Predicted: ['Comedy-100.00%', 'Drama-34.96%', 'Romance-0.02%']
# Ex. 243: From Russia with Love  - ['Action'] - Predicted: ['Comedy-32.37%', 'Drama-28.54%', 'Musical-0.00%']
# Ex. 244: Baby-Sitters Club, The  - ["Children's"] - Predicted: ['Drama-90.54%', 'Comedy-82.93%', 'Crime-0.05%']
# Ex. 245: Return from Witch Mountain  - ["Children's", 'Sci-Fi'] - Predicted: ['Sci-Fi-87.78%', 'Adventure-11.07%', 'Thriller-0.69%']
# Ex. 246: Hands on a Hard Body  - ['Documentary'] - Predicted: ['Drama-99.96%', 'Comedy-1.51%', 'Romance-0.32%']
# Ex. 247: Blame It on Rio  - ['Comedy', 'Romance'] - Predicted: ['Comedy-99.99%', 'Drama-3.60%', "Children's-0.00%"]
# Ex. 248: Eyes of Tammy Faye, The  - ['Documentary'] - Predicted: ['Comedy-0.16%', 'Thriller-0.14%', 'Drama-0.01%']
# Ex. 249: Hurlyburly  - ['Drama'] - Predicted: ['Drama-96.94%', 'Comedy-10.01%', 'Thriller-0.10%']
# Ex. 250: Grumpy Old Men  - ['Comedy'] - Predicted: ['Comedy-99.99%', 'Romance-99.09%', 'Drama-15.22%']
# Ex. 251: Artemisia  - ['Drama'] - Predicted: ['Drama-76.19%', 'Thriller-1.42%', 'Romance-1.37%']
# Ex. 252: It Takes Two  - ['Comedy'] - Predicted: ['Comedy-99.91%', 'Romance-1.14%', 'Drama-0.30%']
# Ex. 253: Saludos Amigos  - ['Animation', "Children's", 'Comedy'] - Predicted: ['Comedy-50.12%', 'Drama-16.79%', 'Musical-0.02%']
# Ex. 254: Corruptor, The  - ['Action', 'Crime', 'Drama', 'Thriller'] - Predicted: ['Drama-27.93%', 'Action-2.11%', 'Thriller-1.38%']
# Ex. 255: Real Blonde, The  - ['Comedy'] - Predicted: ['Comedy-99.98%', "Children's-0.04%", 'Drama-0.03%']
# Ex. 256: Beyond Silence  - ['Drama'] - Predicted: ['Drama-4.88%', 'Thriller-0.48%', 'Comedy-0.33%']
# Ex. 257: Felicia's Journey  - ['Thriller'] - Predicted: ['Drama-8.61%', 'Action-6.06%', 'Adventure-0.17%']
# Ex. 258: Poison  - ['Drama'] - Predicted: ['Thriller-63.53%', 'Action-2.47%', 'Mystery-1.83%']
# Ex. 259: Ridicule  - ['Drama'] - Predicted: ['Drama-94.09%', 'Comedy-26.34%', 'Romance-0.10%']
# Ex. 260: Once Upon a Time in the West  - ['Western'] - Predicted: ['Drama-100.00%', 'Thriller-58.03%', 'Crime-17.37%']
# Ex. 261: Rocketship X-M  - ['Sci-Fi'] - Predicted: ['Drama-21.42%', 'Comedy-3.12%', 'Western-0.33%']
# Ex. 262: Paradine Case, The  - ['Drama'] - Predicted: ['Drama-58.65%', 'Western-0.47%', 'Comedy-0.07%']
# Ex. 263: Pawnbroker, The  - ['Drama'] - Predicted: ['Drama-92.75%', 'Comedy-0.53%', 'Thriller-0.50%']
# Ex. 264: Devil's Brigade, The  - ['War'] - Predicted: ['Drama-55.97%', 'Western-49.03%', 'Thriller-45.41%']
# Ex. 265: Bachelor, The  - ['Comedy', 'Romance'] - Predicted: ['Comedy-98.03%', 'Drama-0.35%', 'Crime-0.03%']
# Ex. 266: Apt Pupil  - ['Drama', 'Thriller'] - Predicted: ['Drama-65.79%', 'Thriller-2.09%', 'Comedy-0.84%']
# Ex. 267: Bridges of Madison County, The  - ['Drama', 'Romance'] - Predicted: ['Drama-80.46%', 'Thriller-0.24%', 'Western-0.05%']
# Ex. 268: Back to the Future  - ['Comedy', 'Sci-Fi'] - Predicted: ['Comedy-84.05%', 'Romance-2.78%', 'Drama-0.13%']
# Ex. 269: Angels and Insects  - ['Drama', 'Romance'] - Predicted: ['Drama-53.39%', 'Comedy-0.69%', 'Thriller-0.02%']
# Ex. 270: Tales of Terror  - ['Horror'] - Predicted: ['Western-6.77%', 'Drama-2.32%', 'Comedy-0.17%']
# Ex. 271: Force of Evil  - ['Film-Noir'] - Predicted: ['Thriller-91.31%', 'Action-46.23%', 'Crime-43.21%']
# Ex. 272: Safe Passage  - ['Drama'] - Predicted: ['Comedy-97.04%', 'Drama-19.46%', 'Western-0.04%']
# Ex. 273: Mad City  - ['Action', 'Drama'] - Predicted: ['Action-99.75%', 'Thriller-81.56%', 'Sci-Fi-22.66%']
# Ex. 274: Bikini Beach  - ['Comedy'] - Predicted: ['Comedy-99.99%', 'Musical-0.13%', "Children's-0.00%"]
# Ex. 275: Tough Guys  - ['Comedy'] - Predicted: ['Drama-67.48%', 'Comedy-38.18%', 'Action-0.02%']
# Ex. 276: Better Than Chocolate  - ['Comedy', 'Romance'] - Predicted: ['Comedy-98.75%', 'Action-0.13%', 'Drama-0.01%']
# Ex. 277: Black Sheep  - ['Comedy'] - Predicted: ['Drama-30.77%', 'Comedy-0.20%', 'Romance-0.03%']
# Ex. 278: Nightmares  - ['Horror'] - Predicted: ['Drama-88.27%', 'Comedy-1.20%', 'Thriller-0.87%']
# Ex. 279: Steel Magnolias  - ['Drama'] - Predicted: ['Action-40.44%', 'Comedy-29.45%', 'Drama-3.90%']
# Ex. 280: Girls Town  - ['Drama'] - Predicted: ['Comedy-99.19%', 'Drama-69.38%', 'Crime-0.39%']
# Ex. 281: Watership Down  - ['Animation', "Children's", 'Drama', 'Fantasy'] - Predicted: ['Action-69.86%', 'Drama-45.39%', 'Thriller-5.86%']
# Ex. 282: Rebel Without a Cause  - ['Drama'] - Predicted: ['Drama-99.26%', 'Musical-0.29%', 'Mystery-0.05%']
# Ex. 283: Thirteenth Floor, The  - ['Drama', 'Sci-Fi', 'Thriller'] - Predicted: ['Drama-67.82%', 'Action-0.29%', 'Thriller-0.25%']
# Ex. 284: Third Miracle, The  - ['Drama'] - Predicted: ['Drama-42.28%', 'Western-1.90%', 'Comedy-0.11%']
# Ex. 285: Madonna: Truth or Dare  - ['Documentary'] - Predicted: ['Action-8.00%', 'Thriller-1.08%', 'Drama-0.66%']
# Ex. 286: Mickey Blue Eyes  - ['Comedy', 'Romance'] - Predicted: ['Comedy-48.72%', 'Documentary-12.81%', 'Romance-11.08%']
# Ex. 287: American Pie  - ['Comedy'] - Predicted: ['Comedy-26.69%', 'Drama-14.44%', 'Western-1.05%']
# Ex. 288: Daddy Long Legs  - ['Comedy'] - Predicted: ['Comedy-51.07%', 'Drama-48.65%', 'Romance-0.56%']
# Ex. 289: Cemetery Man (Dellamorte Dellamore)  - ['Comedy', 'Horror'] - Predicted: ['Drama-16.88%', 'Action-0.83%', 'Sci-Fi-0.67%']
# Ex. 290: Shaggy Dog, The  - ["Children's", 'Comedy'] - Predicted: ['Comedy-99.56%', 'Drama-53.92%', 'Crime-0.01%']
# Ex. 291: Farewell to Arms, A  - ['Romance', 'War'] - Predicted: ['Drama-99.58%', 'Comedy-87.75%', 'Action-1.43%']
# Ex. 292: Children of the Corn III  - ['Horror'] - Predicted: ['Horror-99.98%', 'Thriller-98.39%', 'Sci-Fi-26.18%']
# Ex. 293: Crash  - ['Drama', 'Thriller'] - Predicted: ['Drama-82.73%', 'Thriller-25.62%', 'Action-2.23%']
# Ex. 294: Henry: Portrait of a Serial Killer  - ['Crime', 'Horror'] - Predicted: ['Drama-100.00%', 'War-0.39%', 'Musical-0.10%']
# Ex. 295: Never Been Kissed  - ['Comedy', 'Romance'] - Predicted: ['Drama-99.61%', 'Comedy-0.46%', 'Thriller-0.20%']
# Ex. 296: Exorcist, The  - ['Horror'] - Predicted: ['Drama-39.48%', 'Horror-13.00%', 'Thriller-0.49%']
# Ex. 297: Perfect Murder, A  - ['Mystery', 'Thriller'] - Predicted: ['Crime-94.11%', 'Action-92.14%', 'Horror-18.05%']
# Ex. 298: Outbreak  - ['Action', 'Drama', 'Thriller'] - Predicted: ['Drama-55.74%', 'Thriller-6.81%', 'Action-1.22%']
# Ex. 299: Whole Wide World, The  - ['Drama'] - Predicted: ['Drama-99.48%', 'Comedy-4.76%', 'Western-0.06%']
# Ex. 300: Jupiter's Wife  - ['Documentary'] - Predicted: ['Drama-66.29%', 'Thriller-13.21%', 'Comedy-1.48%']
# Ex. 301: Education of Little Tree, The  - ['Drama'] - Predicted: ['Drama-62.07%', 'Thriller-0.92%', 'Action-0.24%']
# Ex. 302: Woo  - ['Comedy', 'Romance'] - Predicted: ['Comedy-20.76%', 'Drama-0.80%', 'Romance-0.15%']
# Ex. 303: White Man's Burden  - ['Drama'] - Predicted: ['Drama-98.35%', 'Thriller-76.80%', 'Action-0.10%']
# Ex. 304: Saint, The  - ['Action', 'Romance', 'Thriller'] - Predicted: ['Drama-99.72%', 'Thriller-1.03%', 'Action-0.19%']
# Ex. 305: Mafia!  - ['Comedy', 'Crime'] - Predicted: ['Comedy-57.01%', 'Drama-54.42%', 'War-0.03%']
# Ex. 306: On Her Majesty's Secret Service  - ['Action'] - Predicted: ['Drama-99.97%', 'Musical-0.15%', 'War-0.05%']
# Ex. 307: Girl on the Bridge, The (La Fille sur le Pont)  - ['Drama', 'Romance'] - Predicted: ['Drama-100.00%', 'Romance-0.20%', 'Mystery-0.05%']
# Ex. 308: Benji  - ['Adventure', "Children's"] - Predicted: ['Drama-99.17%', 'Comedy-19.88%', 'Thriller-0.07%']
# Ex. 309: Romeo Must Die  - ['Action', 'Romance'] - Predicted: ['Thriller-97.14%', 'Comedy-79.44%', 'Crime-10.39%']
# Ex. 310: Price Above Rubies, A  - ['Drama'] - Predicted: ['Comedy-69.37%', 'Action-32.63%', 'Thriller-32.41%']
# Ex. 311: Class of Nuke 'Em High  - ['Comedy', 'Horror'] - Predicted: ['Comedy-100.00%', 'Western-0.09%', 'Thriller-0.00%']
# Ex. 312: Replacements, The  - ['Comedy'] - Predicted: ['Drama-54.38%', 'Comedy-0.80%', 'Horror-0.06%']
# Ex. 313: Shiloh  - ["Children's", 'Drama'] - Predicted: ['Drama-98.24%', 'Romance-5.35%', 'Comedy-3.10%']
# Ex. 314: Taming of the Shrew, The  - ['Comedy'] - Predicted: ['Drama-76.26%', 'Western-0.18%', 'Thriller-0.06%']
# Ex. 315: Alien: Resurrection  - ['Action', 'Horror', 'Sci-Fi'] - Predicted: ['Thriller-99.81%', 'Action-96.83%', 'Sci-Fi-95.59%']
# Ex. 316: Month by the Lake, A  - ['Comedy', 'Drama'] - Predicted: ['Drama-100.00%', 'Comedy-33.97%', 'Romance-12.03%']
# Ex. 317: Larger Than Life  - ['Comedy'] - Predicted: ['Comedy-100.00%', 'Western-0.51%', 'Romance-0.03%']
# Ex. 318: Believers, The  - ['Horror', 'Thriller'] - Predicted: ['Drama-81.74%', 'Horror-5.49%', 'Action-3.62%']
# Ex. 319: Lady and the Tramp  - ['Animation', "Children's", 'Comedy', 'Musical', 'Romance'] - Predicted: ['Comedy-98.65%', 'Romance-6.06%', 'Animation-0.22%']
# Ex. 320: Raven, The  - ['Comedy', 'Horror'] - Predicted: ['Drama-34.27%', 'Action-0.32%', 'Western-0.24%']
# Ex. 321: Close Encounters of the Third Kind  - ['Drama', 'Sci-Fi'] - Predicted: ['Comedy-24.66%', 'Action-1.78%', 'Sci-Fi-0.94%']
# Ex. 322: Crow: City of Angels, The  - ['Action', 'Thriller'] - Predicted: ['Romance-99.60%', 'Comedy-93.16%', 'Drama-49.10%']
# Ex. 323: Sling Blade  - ['Drama', 'Thriller'] - Predicted: ['Drama-72.42%', 'Romance-0.83%', 'Comedy-0.52%']
# Ex. 324: Turtle Diary  - ['Drama'] - Predicted: ['Drama-99.25%', 'Comedy-96.33%', 'Romance-7.36%']
# Ex. 325: Once Were Warriors  - ['Crime', 'Drama'] - Predicted: ['Drama-99.84%', 'Thriller-4.12%', 'Action-2.94%']
# Ex. 326: Repo Man  - ['Comedy', 'Sci-Fi'] - Predicted: ['Drama-3.89%', 'Comedy-1.53%', 'Thriller-0.93%']
# Ex. 327: Bait  - ['Action', 'Comedy'] - Predicted: ['Action-23.31%', 'Sci-Fi-3.06%', 'Comedy-1.78%']
# Ex. 328: Tin Men  - ['Comedy', 'Drama'] - Predicted: ['Comedy-100.00%', 'Drama-77.89%', 'Romance-48.03%']
# Ex. 329: Blank Check  - ["Children's", 'Comedy'] - Predicted: ['Drama-94.92%', 'Comedy-47.10%', 'Thriller-0.01%']
# Ex. 330: Any Given Sunday  - ['Drama'] - Predicted: ['Comedy-4.29%', 'Drama-2.81%', 'Action-0.64%']
# Ex. 331: Mr. Holland's Opus  - ['Drama'] - Predicted: ['Comedy-99.97%', 'Romance-2.84%', 'Drama-0.09%']
# Ex. 332: Heavy  - ['Drama', 'Romance'] - Predicted: ['Sci-Fi-60.79%', 'Action-21.62%', 'Thriller-10.89%']
# Ex. 333: French Kiss  - ['Comedy', 'Romance'] - Predicted: ['Drama-95.49%', 'Thriller-65.94%', 'Comedy-37.99%']
# Ex. 334: Back to the Future Part III  - ['Comedy', 'Sci-Fi', 'Western'] - Predicted: ['Comedy-99.99%', 'Action-0.02%', 'Sci-Fi-0.00%']
# Ex. 335: Senseless  - ['Comedy'] - Predicted: ['Comedy-33.59%', 'Drama-10.32%', 'Romance-0.04%']
# Ex. 336: Predator 2  - ['Action', 'Sci-Fi', 'Thriller'] - Predicted: ['Thriller-99.58%', 'Sci-Fi-99.22%', 'Action-79.71%']
# Ex. 337: Dunston Checks In  - ["Children's", 'Comedy'] - Predicted: ['Comedy-80.61%', 'Drama-6.96%', 'Action-0.64%']
# Ex. 338: Avalanche  - ['Action'] - Predicted: ['Drama-96.04%', 'Comedy-12.12%', 'Romance-1.94%']
# Ex. 339: Candyman  - ['Horror'] - Predicted: ['Drama-20.96%', 'Comedy-8.51%', 'Documentary-4.43%']
# Ex. 340: Star Trek III: The Search for Spock  - ['Action', 'Adventure', 'Sci-Fi'] - Predicted: ['Adventure-99.99%', 'Sci-Fi-99.98%', 'Action-99.90%']
# Ex. 341: Young Poisoner's Handbook, The  - ['Crime'] - Predicted: ['Comedy-91.56%', 'Western-21.44%', 'Drama-9.26%']
# Ex. 342: I Went Down  - ['Action', 'Comedy', 'Crime'] - Predicted: ['Drama-99.54%', 'Thriller-24.36%', 'Crime-1.04%']
# Ex. 343: Wrongfully Accused  - ['Action', 'Comedy'] - Predicted: ['Drama-63.93%', 'Comedy-1.05%', 'Action-0.12%']
# Ex. 344: Substitute, The  - ['Action'] - Predicted: ['Drama-73.46%', 'Thriller-2.17%', 'Action-1.88%']
# Ex. 345: Sugar Town  - ['Comedy'] - Predicted: ['Comedy-97.16%', 'Crime-45.35%', 'Drama-21.30%']
# Ex. 346: Female Perversions  - ['Drama'] - Predicted: ['Drama-84.50%', 'Comedy-1.28%', 'Thriller-0.35%']
# Ex. 347: Nick of Time  - ['Action', 'Thriller'] - Predicted: ['Drama-31.74%', 'Comedy-0.71%', 'Thriller-0.58%']
# Ex. 348: Mouse Hunt  - ["Children's", 'Comedy'] - Predicted: ['Drama-97.42%', 'Thriller-1.38%', 'Comedy-0.48%']
# Ex. 349: Kingpin  - ['Comedy'] - Predicted: ['Drama-54.89%', 'Comedy-3.52%', 'Thriller-0.13%']
# Ex. 350: Haunting, The  - ['Horror', 'Thriller'] - Predicted: ['Thriller-99.98%', 'Horror-98.90%', 'Action-3.64%']
# Ex. 351: Breakfast of Champions  - ['Comedy'] - Predicted: ['Comedy-99.41%', 'Drama-91.50%', 'Romance-2.64%']
# Ex. 352: Slam  - ['Drama'] - Predicted: ['Drama-94.37%', 'Thriller-46.68%', 'Western-3.84%']
# Ex. 353: Ref, The  - ['Comedy'] - Predicted: ['Drama-57.92%', 'Action-4.61%', 'Comedy-0.58%']
# Ex. 354: Up at the Villa  - ['Drama'] - Predicted: ['Drama-89.24%', 'Romance-3.68%', 'Comedy-3.16%']
# Ex. 355: Bound for Glory  - ['Drama'] - Predicted: ['Drama-99.99%', 'Comedy-29.50%', 'Crime-11.02%']
# Ex. 356: Man Bites Dog (C'est arrivÃ© prÃ¨s de chez vous)  - ['Action', 'Comedy', 'Crime', 'Drama'] - Predicted: ['Drama-100.00%', 'Comedy-94.96%', 'War-0.02%']
# Ex. 357: Trouble with Harry, The  - ['Mystery', 'Thriller'] - Predicted: ['Comedy-99.80%', 'Adventure-9.42%', 'Action-3.34%']
# Ex. 358: Falling Down  - ['Action', 'Drama'] - Predicted: ['Drama-96.88%', 'Comedy-18.05%', 'Thriller-0.60%']
# Ex. 359: Magnum Force  - ['Western'] - Predicted: ['Drama-97.77%', 'Comedy-35.39%', 'Thriller-0.02%']
# Ex. 360: Frighteners, The  - ['Comedy', 'Horror'] - Predicted: ['Drama-99.56%', 'Comedy-56.92%', 'Thriller-3.71%']
# Ex. 361: Road to El Dorado, The  - ['Animation', "Children's"] - Predicted: ['Comedy-99.40%', 'Action-1.20%', 'Drama-0.05%']
# Ex. 362: Assassins  - ['Thriller'] - Predicted: ['Drama-58.56%', 'Comedy-1.53%', 'Action-0.49%']
# Ex. 363: Committed  - ['Comedy', 'Drama'] - Predicted: ['Drama-84.44%', 'Comedy-5.66%', 'Romance-0.07%']
# Ex. 364: Manon of the Spring (Manon des sources)  - ['Drama'] - Predicted: ['Romance-78.34%', 'Drama-55.33%', 'Mystery-8.39%']
# Ex. 365: Clean Slate  - ['Comedy'] - Predicted: ['Drama-49.00%', 'Crime-3.56%', 'Comedy-2.86%']
# Ex. 366: Porky's  - ['Comedy'] - Predicted: ['Comedy-99.99%', 'Drama-48.13%', 'Romance-0.02%']
# Ex. 367: Robin Hood  - ['Animation', "Children's"] - Predicted: ['Comedy-99.98%', "Children's-0.00%", 'Thriller-0.00%']
# Ex. 368: Diner  - ['Comedy', 'Drama'] - Predicted: ['Drama-27.59%', 'Thriller-1.97%', 'Comedy-0.36%']
# Ex. 369: Third Man, The  - ['Mystery', 'Thriller'] - Predicted: ['Drama-22.07%', 'Romance-0.45%', 'Thriller-0.12%']
# Ex. 370: Boiler Room  - ['Drama'] - Predicted: ['Comedy-60.41%', 'Romance-1.15%', 'Drama-0.84%']
# Ex. 371: Hard Core Logo  - ['Comedy'] - Predicted: ['Comedy-75.20%', 'Drama-0.51%', 'Western-0.19%']
# Ex. 372: Thirty-Two Short Films About Glenn Gould  - ['Documentary'] - Predicted: ['Drama-94.87%', 'Comedy-70.54%', 'Romance-5.17%']
# Ex. 373: Wings of the Dove, The  - ['Drama', 'Romance', 'Thriller'] - Predicted: ['Drama-96.44%', 'Romance-0.34%', 'Comedy-0.05%']
# Ex. 374: Stepford Wives, The  - ['Sci-Fi', 'Thriller'] - Predicted: ['Comedy-99.96%', "Children's-0.06%", 'Romance-0.05%']
# Ex. 375: Belle de jour  - ['Drama'] - Predicted: ['Drama-99.67%', 'Comedy-94.22%', 'Romance-53.31%']
# Ex. 376: Drugstore Cowboy  - ['Crime', 'Drama'] - Predicted: ['Drama-99.91%', 'Comedy-0.29%', 'Documentary-0.00%']
# Ex. 377: Right Stuff, The  - ['Drama'] - Predicted: ['Drama-95.30%', 'Comedy-4.52%', 'Western-0.02%']
# Ex. 378: Filth and the Fury, The  - ['Documentary'] - Predicted: ['Drama-58.87%', 'Musical-0.02%', 'Mystery-0.01%']
# Ex. 379: Get Carter  - ['Action', 'Drama', 'Thriller'] - Predicted: ['Thriller-98.87%', 'Drama-5.71%', 'Action-1.94%']
# Ex. 380: Black Beauty  - ['Adventure', "Children's"] - Predicted: ['Drama-96.98%', 'Action-1.31%', 'Thriller-0.10%']
# Ex. 381: Life of Ãmile Zola, The  - ['Drama'] - Predicted: ['Comedy-62.64%', 'Drama-0.11%', 'Action-0.00%']
# Ex. 382: Green Mile, The  - ['Drama', 'Thriller'] - Predicted: ['Drama-74.64%', 'Thriller-0.50%', 'Comedy-0.20%']
# Ex. 383: Braindead  - ['Comedy', 'Horror'] - Predicted: ['Drama-73.13%', 'Comedy-5.13%', 'Thriller-0.13%']
# Ex. 384: Fled  - ['Action', 'Adventure'] - Predicted: ['Drama-19.78%', 'Comedy-1.56%', 'Romance-0.31%']
# Ex. 385: No Small Affair  - ['Comedy', 'Romance'] - Predicted: ['Thriller-16.04%', 'Comedy-4.20%', 'Action-1.09%']
# Ex. 386: Endurance  - ['Documentary', 'Drama'] - Predicted: ['Drama-82.25%', 'Thriller-0.84%', 'Romance-0.70%']
# Ex. 387: Bed of Roses  - ['Drama', 'Romance'] - Predicted: ['Drama-45.30%', 'Romance-0.65%', 'Comedy-0.09%']
# Ex. 388: Party Girl  - ['Comedy'] - Predicted: ['Comedy-98.37%', 'Western-0.03%', 'Musical-0.01%']
# Ex. 389: Hollow Reed  - ['Drama'] - Predicted: ['Drama-64.32%', 'Comedy-15.13%', 'Crime-0.07%']
# Ex. 390: Skulls, The  - ['Thriller'] - Predicted: ['Thriller-73.64%', 'Action-26.51%', 'Drama-13.28%']
# Ex. 391: Everest  - ['Documentary'] - Predicted: ['Comedy-65.88%', 'Drama-1.05%', "Children's-0.25%"]
# Ex. 392: Flying Saucer, The  - ['Sci-Fi'] - Predicted: ['Drama-62.82%', 'Comedy-0.62%', 'Romance-0.04%']
# Ex. 393: Road to Wellville, The  - ['Comedy'] - Predicted: ['Comedy-99.99%', 'Drama-6.07%', 'Romance-0.00%']
# Ex. 394: Time Regained (Le Temps RetrouvÃ©)  - ['Drama'] - Predicted: ['Drama-93.97%', 'Fantasy-40.37%', 'Romance-17.27%']
# Ex. 395: Santa Claus: The Movie  - ['Adventure', "Children's", 'Fantasy'] - Predicted: ["Children's-99.79%", 'Musical-49.34%', 'Comedy-40.53%']
# Ex. 396: Big  - ['Comedy', 'Fantasy'] - Predicted: ['Comedy-95.27%', 'Drama-56.98%', 'Romance-4.06%']
# Ex. 397: Fatal Attraction  - ['Thriller'] - Predicted: ['Comedy-87.23%', 'Action-52.91%', 'Drama-5.54%']
# Ex. 398: Sleepless in Seattle  - ['Comedy', 'Romance'] - Predicted: ['Comedy-80.82%', 'Drama-66.74%', 'Western-0.01%']
# Ex. 399: Destiny Turns on the Radio  - ['Comedy'] - Predicted: ['Drama-94.51%', 'Comedy-52.12%', 'Western-0.20%']
# Ex. 400: Slumber Party Massacre III, The  - ['Horror'] - Predicted: ['Horror-97.46%', 'Comedy-0.06%', 'Western-0.04%']
# Ex. 401: Hard Target  - ['Action', 'Adventure', 'Crime', 'Thriller'] - Predicted: ['Comedy-98.46%', 'Drama-0.23%', 'Musical-0.19%']
# Ex. 402: Jawbreaker  - ['Comedy'] - Predicted: ['Comedy-74.46%', "Children's-0.18%", 'Crime-0.06%']
# Ex. 403: Max Dugan Returns  - ['Comedy'] - Predicted: ['Drama-19.27%', 'Comedy-2.18%', 'Western-0.91%']
# Ex. 404: Back to the Future Part II  - ['Comedy', 'Sci-Fi'] - Predicted: ['Comedy-99.99%', 'Romance-0.03%', 'Drama-0.00%']
# Ex. 405: Gaslight  - ['Mystery', 'Thriller'] - Predicted: ['Drama-19.63%', 'Comedy-2.15%', 'Western-0.19%']
# Ex. 406: Backdraft  - ['Action', 'Drama'] - Predicted: ['Drama-89.36%', 'Thriller-36.25%', 'Action-0.60%']
# Ex. 407: Sorority House Massacre  - ['Horror'] - Predicted: ['Horror-98.62%', 'Drama-43.11%', 'Sci-Fi-0.04%']
# Ex. 408: Dear Diary (Caro Diario)  - ['Comedy', 'Drama'] - Predicted: ['Comedy-72.76%', 'Drama-2.25%', "Children's-0.15%"]
# Ex. 409: Rear Window  - ['Mystery', 'Thriller'] - Predicted: ['Thriller-28.70%', 'Comedy-4.77%', 'Action-0.04%']
# Ex. 410: Hi-Lo Country, The  - ['Drama', 'Western'] - Predicted: ['Comedy-41.46%', 'Romance-35.41%', 'Drama-2.56%']
# Ex. 411: Crow: Salvation, The  - ['Action', 'Horror'] - Predicted: ['Romance-98.99%', 'Thriller-94.69%', 'Drama-38.48%']
# Ex. 412: Notorious  - ['Film-Noir', 'Romance', 'Thriller'] - Predicted: ['Drama-50.86%', 'Comedy-3.16%', 'Musical-0.19%']
# Ex. 413: Tales from the Darkside: The Movie  - ['Horror'] - Predicted: ['Sci-Fi-99.96%', 'Horror-96.92%', 'Action-2.04%']
# Ex. 414: Meet the Deedles  - ["Children's", 'Comedy'] - Predicted: ['Drama-81.51%', 'Comedy-11.58%', 'Horror-0.05%']
# Ex. 415: ...And Justice for All  - ['Drama', 'Thriller'] - Predicted: ['Drama-99.98%', 'Comedy-1.72%', 'Romance-0.02%']
# Ex. 416: Adventures of Priscilla, Queen of the Desert, The  - ['Comedy', 'Drama'] - Predicted: ['Action-20.66%', 'Sci-Fi-3.98%', 'Adventure-0.55%']
# Ex. 417: Exorcist III, The  - ['Horror'] - Predicted: ['Horror-97.31%', 'Drama-90.25%', 'Western-0.01%']
# Ex. 418: Apartment, The  - ['Comedy', 'Drama'] - Predicted: ['Drama-53.56%', 'Action-1.42%', 'Thriller-0.35%']
# Ex. 419: Ready to Rumble  - ['Comedy'] - Predicted: ['Comedy-95.01%', 'Romance-29.31%', 'Drama-11.49%']
# Ex. 420: One Magic Christmas  - ['Drama', 'Fantasy'] - Predicted: ['Drama-100.00%', 'Comedy-57.51%', "Children's-4.18%"]
# Ex. 421: Mary Reilly  - ['Drama', 'Thriller'] - Predicted: ['Drama-98.94%', 'Comedy-61.48%', 'Romance-0.14%']
# Ex. 422: On Golden Pond  - ['Drama'] - Predicted: ['Drama-100.00%', 'Comedy-48.33%', 'Romance-0.03%']
# Ex. 423: Duel in the Sun  - ['Western'] - Predicted: ['Drama-99.17%', 'Romance-48.07%', 'Comedy-0.63%']
# Ex. 424: Ipcress File, The  - ['Thriller'] - Predicted: ['Comedy-10.91%', 'Drama-2.59%', 'Action-0.03%']
# Ex. 425: Murder, My Sweet  - ['Film-Noir', 'Thriller'] - Predicted: ['Thriller-90.07%', 'Drama-81.79%', 'Western-0.16%']
# Ex. 426: Benji the Hunted  - ['Adventure', "Children's"] - Predicted: ['Drama-97.66%', 'Comedy-3.23%', 'Thriller-0.07%']
# ...
# Ex. 515: Die Hard  - ['Action', 'Thriller'] - Predicted: ['Action-100.00%', 'Thriller-99.94%', 'Crime-0.45%']
# Ex. 516: Cool as Ice  - ['Drama'] - Predicted: ['Comedy-99.87%', 'Crime-4.32%', 'Drama-2.38%']
# Ex. 517: Mephisto  - ['Drama', 'War'] - Predicted: ['Drama-86.38%', 'Action-1.56%', 'Crime-1.17%']
# Ex. 518: Legend  - ['Adventure', 'Fantasy', 'Romance'] - Predicted: ['Drama-99.57%', 'Thriller-0.68%', 'Comedy-0.04%']
# Ex. 519: In Dreams  - ['Thriller'] - Predicted: ['Thriller-2.16%', 'Comedy-0.87%', 'Romance-0.43%']
# Ex. 520: Losing Chase  - ['Drama'] - Predicted: ['Drama-99.99%', 'Comedy-0.02%', 'Crime-0.01%']
# Ex. 521: Castle, The  - ['Comedy'] - Predicted: ['Comedy-5.77%', 'Horror-0.71%', 'Animation-0.13%']
# Ex. 522: Absent Minded Professor, The  - ["Children's", 'Comedy', 'Fantasy'] - Predicted: ['Comedy-40.78%', 'Drama-1.53%', "Children's-0.46%"]
# Ex. 523: Velocity of Gary, The  - ['Comedy', 'Romance'] - Predicted: ['Drama-55.69%', 'Comedy-0.46%', 'Western-0.01%']
# Ex. 524: Breaker Morant  - ['Drama', 'War'] - Predicted: ['Comedy-7.83%', 'Drama-3.08%', 'Mystery-0.07%']
# Ex. 525: Dream for an Insomniac  - ['Drama', 'Romance'] - Predicted: ['Drama-99.85%', 'Comedy-1.15%', 'Musical-0.00%']
# Ex. 526: White Balloon, The (Badkonake Sefid )  - ['Drama'] - Predicted: ['Drama-89.54%', 'Adventure-2.99%', 'Thriller-0.54%']
# Ex. 527: Communion (a.k.a. Alice, Sweet Alice/Holy Terror)  - ['Horror'] - Predicted: ['Drama-96.85%', 'Sci-Fi-93.39%', 'Thriller-49.13%']
# Ex. 528: Sorority House Massacre II  - ['Horror'] - Predicted: ['Horror-91.48%', 'Drama-13.26%', 'Thriller-0.02%']
# Ex. 529: Brothers McMullen, The  - ['Comedy'] - Predicted: ['Drama-91.43%', 'Comedy-6.83%', 'Documentary-0.07%']
# Ex. 530: Little Rascals, The  - ["Children's", 'Comedy'] - Predicted: ['Drama-78.74%', 'Comedy-4.78%', 'Romance-2.87%']
# Ex. 531: From the Hip  - ['Comedy'] - Predicted: ['Drama-19.99%', 'Crime-0.29%', 'Comedy-0.15%']
# Ex. 532: Women on the Verge of a Nervous Breakdown  - ['Comedy', 'Drama'] - Predicted: ['Drama-1.46%', 'Horror-0.02%', 'Film-Noir-0.02%']
# Ex. 533: Ed Wood  - ['Comedy', 'Drama'] - Predicted: ['Drama-74.32%', 'Crime-0.84%', 'Comedy-0.52%']
# Ex. 534: Single Girl, A (La Fille Seule)  - ['Drama'] - Predicted: ['Action-91.89%', 'Comedy-36.09%', 'Sci-Fi-6.30%']
# Ex. 535: Blade  - ['Action', 'Adventure', 'Horror'] - Predicted: ['Drama-64.22%', 'Action-6.77%', 'Thriller-1.09%']
# Ex. 536: Lost Horizon  - ['Drama'] - Predicted: ['Drama-99.52%', 'Thriller-0.58%', 'Crime-0.10%']
# Ex. 537: Killer (Bulletproof Heart)  - ['Thriller'] - Predicted: ['Drama-99.95%', 'Comedy-16.62%', 'Romance-0.41%']
# Ex. 538: Woman on Top  - ['Comedy', 'Romance'] - Predicted: ['Drama-99.88%', 'Mystery-0.03%', 'Thriller-0.03%']
# Ex. 539: My Life in Pink (Ma vie en rose)  - ['Comedy', 'Drama'] - Predicted: ['Comedy-40.56%', 'Drama-30.08%', "Children's-19.23%"]
# Ex. 540: Arthur  - ['Comedy', 'Romance'] - Predicted: ['Drama-80.05%', 'Crime-0.20%', 'Thriller-0.09%']
# Ex. 541: MatchMaker, The  - ['Comedy', 'Romance'] - Predicted: ['Drama-54.36%', 'Comedy-2.27%', 'Mystery-0.18%']
# Ex. 542: Shawshank Redemption, The  - ['Drama'] - Predicted: ['Drama-91.45%', 'Thriller-2.43%', 'Action-0.13%']
# Ex. 543: Unzipped  - ['Documentary'] - Predicted: ['Drama-93.55%', 'Comedy-7.25%', 'Thriller-0.04%']
# Ex. 544: Indiana Jones and the Last Crusade  - ['Action', 'Adventure'] - Predicted: ['Drama-0.13%', 'Action-0.11%', 'Adventure-0.03%']
# Ex. 545: Lawnmower Man, The  - ['Action', 'Sci-Fi', 'Thriller'] - Predicted: ['Thriller-98.32%', 'Drama-74.05%', 'Sci-Fi-50.32%']
# Ex. 546: Nothing to Lose  - ['Drama'] - Predicted: ['Comedy-99.99%', 'Drama-52.78%', 'Action-0.02%']
# Ex. 547: Shooter, The  - ['Action'] - Predicted: ['Drama-42.37%', 'Comedy-1.01%', 'Thriller-0.59%']
# Ex. 548: Apple Dumpling Gang Rides Again, The  - ["Children's", 'Comedy', 'Western'] - Predicted: ['Comedy-100.00%', "Children's-99.53%", 'Western-2.38%']
# Ex. 549: Vacation  - ['Comedy'] - Predicted: ['Comedy-20.83%', 'Drama-2.14%', "Children's-0.11%"]
# Ex. 550: Vagabond (Sans toit ni loi)  - ['Drama'] - Predicted: ['Comedy-34.81%', 'Drama-7.89%', 'Action-0.18%']
# Ex. 551: Don't Look in the Basement!  - ['Horror'] - Predicted: ['Drama-79.78%', 'Comedy-73.18%', 'Western-1.75%']
# Ex. 552: Even Cowgirls Get the Blues  - ['Comedy', 'Romance'] - Predicted: ['Drama-41.16%', 'Comedy-0.74%', 'Action-0.02%']
# Ex. 553: Judge Dredd  - ['Action', 'Adventure', 'Sci-Fi'] - Predicted: ['Drama-4.80%', 'Action-3.94%', 'Crime-0.87%']
# Ex. 554: Dead Man on Campus  - ['Comedy'] - Predicted: ['Comedy-17.82%', 'Drama-1.23%', 'Thriller-0.06%']
# Ex. 555: Inventing the Abbotts  - ['Drama', 'Romance'] - Predicted: ['Drama-44.92%', 'Mystery-0.55%', 'Action-0.55%']
# Ex. 556: Disturbing Behavior  - ['Horror', 'Thriller'] - Predicted: ['Drama-58.31%', 'Action-4.43%', 'Comedy-2.59%']
# Ex. 557: Love & Sex  - ['Comedy', 'Romance'] - Predicted: ['Comedy-45.45%', 'Romance-31.52%', 'Drama-25.87%']
# Ex. 558: Lost in Space  - ['Action', 'Sci-Fi', 'Thriller'] - Predicted: ['Drama-99.98%', 'Comedy-4.72%', 'Romance-0.00%']
# Ex. 559: Sliding Doors  - ['Drama', 'Romance'] - Predicted: ['Comedy-92.31%', 'Drama-19.43%', 'Documentary-0.01%']
# Ex. 560: Man on the Moon  - ['Comedy', 'Drama'] - Predicted: ['Drama-100.00%', 'Thriller-0.21%', 'Romance-0.15%']
# Ex. 561: Primary Colors  - ['Drama'] - Predicted: ['Drama-99.95%', 'Crime-0.32%', 'Horror-0.06%']
# Ex. 562: Gabbeh  - ['Drama'] - Predicted: ['Drama-1.85%', 'Comedy-0.88%', 'Action-0.57%']
# Ex. 563: Killing Fields, The  - ['Drama', 'War'] - Predicted: ['Drama-96.87%', 'Comedy-87.78%', 'Thriller-1.42%']
# Ex. 564: Sesame Street Presents Follow That Bird  - ["Children's", 'Comedy'] - Predicted: ['Comedy-76.49%', "Children's-51.09%", 'Drama-49.29%']
# Ex. 565: Secret Adventures of Tom Thumb, The  - ['Adventure', "Children's"] - Predicted: ['Drama-84.31%', 'Comedy-0.02%', 'Sci-Fi-0.02%']
# Ex. 566: Return of the Pink Panther, The  - ['Comedy'] - Predicted: ['Drama-85.42%', 'Sci-Fi-38.46%', 'Documentary-0.06%']
# Ex. 567: Ed  - ['Comedy'] - Predicted: ['Comedy-18.26%', 'Drama-3.23%', 'Romance-0.16%']
# Ex. 568: Superman  - ['Action', 'Adventure', 'Sci-Fi'] - Predicted: ['Drama-19.15%', 'Action-12.64%', 'Thriller-1.43%']
# Ex. 569: Red Rock West  - ['Thriller'] - Predicted: ['Comedy-45.92%', 'Action-34.12%', 'Thriller-0.02%']
# Ex. 570: No Looking Back  - ['Comedy', 'Drama', 'Romance'] - Predicted: ['Comedy-94.89%', 'Thriller-40.69%', 'Drama-10.76%']
# Ex. 571: Patch Adams  - ['Comedy', 'Drama'] - Predicted: ['Drama-76.31%', 'Romance-5.02%', 'Comedy-3.88%']
# Ex. 572: Bullets Over Broadway  - ['Comedy'] - Predicted: ['Drama-51.51%', 'Comedy-0.21%', 'Action-0.01%']
# Ex. 573: Object of My Affection, The  - ['Comedy', 'Romance'] - Predicted: ['Drama-100.00%', 'Romance-0.20%', 'Comedy-0.17%']
# Ex. 574: Faces  - ['Drama'] - Predicted: ['Drama-90.33%', 'Comedy-47.50%', 'Documentary-0.48%']
# Ex. 575: Rounders  - ['Crime', 'Drama'] - Predicted: ['Drama-80.41%', 'Thriller-2.12%', 'Crime-0.56%']
# Ex. 576: One Fine Day  - ['Drama', 'Romance'] - Predicted: ['Drama-99.95%', 'Comedy-6.65%', 'Western-0.00%']
# Ex. 577: Alan Smithee Film: Burn Hollywood Burn, An  - ['Comedy'] - Predicted: ['Comedy-68.65%', "Children's-26.35%", 'Drama-1.79%']
# Ex. 578: Death Wish 4: The Crackdown  - ['Action', 'Drama'] - Predicted: ['Drama-100.00%', 'Action-89.15%', 'War-0.07%']
# Ex. 579: Shanghai Noon  - ['Action'] - Predicted: ['Western-78.86%', 'Action-3.93%', 'Horror-1.85%']
# Ex. 580: Creature Comforts  - ['Animation', 'Comedy'] - Predicted: ['Drama-18.04%', 'Comedy-2.67%', 'Action-0.45%']
# Ex. 581: Devil and Max Devlin, The  - ['Comedy'] - Predicted: ['Drama-42.58%', 'Comedy-0.94%', 'Romance-0.01%']
# Ex. 582: Small Time Crooks  - ['Comedy'] - Predicted: ['Drama-95.64%', "Children's-74.03%", 'Musical-30.47%']
# Ex. 583: From Dusk Till Dawn  - ['Action', 'Comedy', 'Crime', 'Horror', 'Thriller'] - Predicted: ['Drama-25.04%', 'Comedy-9.87%', 'Action-0.20%']
# Ex. 584: Big Blue, The (Le Grand Bleu)  - ['Adventure', 'Romance'] - Predicted: ['Comedy-99.96%', 'Romance-31.41%', 'Documentary-3.10%']
# Ex. 585: Almost Heroes  - ['Adventure', 'Comedy'] - Predicted: ['Comedy-100.00%', 'Drama-98.20%', 'Crime-0.80%']
# Ex. 586: Cliffhanger  - ['Action', 'Adventure', 'Crime'] - Predicted: ['Drama-82.15%', 'Comedy-12.68%', 'Action-0.27%']
# Ex. 587: Celestial Clockwork  - ['Comedy'] - Predicted: ['Drama-69.89%', 'Comedy-8.25%', 'Crime-0.05%']
# Ex. 588: Bad Seed, The  - ['Drama', 'Thriller'] - Predicted: ['Drama-20.29%', 'Thriller-11.75%', 'Western-1.92%']
# Ex. 589: Career Girls  - ['Drama'] - Predicted: ['Drama-54.26%', 'Western-28.85%', 'War-0.08%']
# Ex. 590: Picture Bride  - ['Drama', 'Romance'] - Predicted: ['Comedy-100.00%', 'Romance-99.97%', 'Thriller-0.23%']
# Ex. 591: Tie Me Up! Tie Me Down!  - ['Drama'] - Predicted: ['Comedy-34.90%', 'Western-7.85%', 'Thriller-0.25%']
# Ex. 592: My Man Godfrey  - ['Comedy'] - Predicted: ['Comedy-100.00%', 'Drama-2.65%', 'Musical-0.01%']
# Ex. 593: Paper Chase, The  - ['Drama'] - Predicted: ['Drama-100.00%', 'Comedy-97.62%', 'Romance-1.43%']
# Ex. 594: Two Women (La Ciociara)  - ['Drama', 'War'] - Predicted: ['Drama-95.58%', 'Mystery-0.17%', 'Romance-0.05%']
# Ex. 595: Coogan's Bluff  - ['Crime'] - Predicted: ['Drama-20.52%', 'Comedy-12.38%', 'Western-0.03%']
# Ex. 596: Isn't She Great?  - ['Comedy'] - Predicted: ['Comedy-31.47%', 'Drama-0.24%', 'Romance-0.00%']
# Ex. 597: Rocky II  - ['Action', 'Drama'] - Predicted: ['Drama-99.13%', 'Thriller-1.36%', 'Action-0.03%']
# Ex. 598: Payback  - ['Action', 'Thriller'] - Predicted: ['Drama-83.23%', 'Thriller-7.28%', 'Comedy-0.43%']
# Ex. 599: Playing God  - ['Crime', 'Thriller'] - Predicted: ['Drama-100.00%', 'Romance-5.21%', 'Mystery-0.03%']
# Ex. 600: Pagemaster, The  - ['Action', 'Adventure', 'Animation', "Children's", 'Fantasy'] - Predicted: ['Comedy-7.71%', 'Drama-0.57%', "Children's-0.05%"]
# Ex. 601: To Die For  - ['Comedy', 'Drama'] - Predicted: ['Drama-87.88%', 'Thriller-23.53%', 'Comedy-6.29%']
# Ex. 602: PokÃ©mon the Movie 2000  - ['Animation', "Children's"] - Predicted: ["Children's-97.87%", 'Animation-94.20%', 'Fantasy-4.10%']
# Ex. 603: My Favorite Year  - ['Comedy'] - Predicted: ['Comedy-1.66%', 'Drama-1.26%', 'Sci-Fi-0.70%']
# Ex. 604: I'm the One That I Want  - ['Comedy'] - Predicted: ['Comedy-96.80%', "Children's-0.00%", 'Drama-0.00%']
# Ex. 605: Urbania  - ['Drama'] - Predicted: ['Drama-42.05%', 'Thriller-3.98%', 'Action-0.82%']
# Ex. 606: Lodger, The  - ['Thriller'] - Predicted: ['Drama-95.03%', 'Thriller-16.03%', 'Action-4.14%']
# Ex. 607: Living Out Loud  - ['Comedy', 'Romance'] - Predicted: ['Comedy-100.00%', 'Drama-35.68%', 'Musical-0.09%']
# Ex. 608: Dirty Dancing  - ['Musical', 'Romance'] - Predicted: ['Drama-95.16%', 'Comedy-42.02%', 'Action-1.61%']
# Ex. 609: Hero  - ['Comedy', 'Drama'] - Predicted: ['Drama-18.34%', 'Romance-1.96%', 'Comedy-1.58%']
# Ex. 610: Final Destination  - ['Drama', 'Thriller'] - Predicted: ['Drama-37.59%', 'Horror-22.56%', 'Thriller-0.26%']
# Ex. 611: Fun and Fancy Free  - ['Animation', "Children's", 'Musical'] - Predicted: ['Comedy-17.37%', 'Musical-6.62%', "Children's-0.18%"]
# Ex. 612: Postman Always Rings Twice, The  - ['Crime', 'Thriller'] - Predicted: ['Drama-100.00%', 'Action-0.00%', 'Comedy-0.00%']
# Ex. 613: Night Falls on Manhattan  - ['Crime', 'Drama'] - Predicted: ['Thriller-17.57%', 'Comedy-12.68%', 'Drama-8.64%']
# Ex. 614: Longest Day, The  - ['Action', 'Drama', 'War'] - Predicted: ['Comedy-7.12%', 'Drama-1.38%', 'Animation-0.09%']
# Ex. 615: Stupids, The  - ['Comedy'] - Predicted: ['Comedy-42.61%', 'Drama-0.63%', 'Romance-0.03%']
# Ex. 616: Philadelphia Story, The  - ['Comedy', 'Romance'] - Predicted: ['Drama-99.10%', 'Comedy-4.51%', 'Western-0.68%']
# Ex. 617: Murder at 1600  - ['Mystery', 'Thriller'] - Predicted: ['Thriller-94.48%', 'Drama-26.72%', 'Mystery-18.25%']
# Ex. 618: Tombstone  - ['Western'] - Predicted: ['Drama-94.79%', 'Comedy-2.77%', 'Western-0.33%']
# Ex. 619: In Too Deep  - ['Action', 'Thriller'] - Predicted: ['Comedy-99.34%', 'Action-0.12%', 'Crime-0.11%']
# Ex. 620: And God Created Woman  - ['Comedy', 'Drama', 'Romance'] - Predicted: ['Drama-100.00%', 'Comedy-17.72%', 'Romance-0.00%']
# Ex. 621: Robocop  - ['Action', 'Crime', 'Sci-Fi'] - Predicted: ['Action-5.94%', 'Drama-2.66%', 'Thriller-1.82%']
# Ex. 622: Edge, The  - ['Adventure', 'Thriller'] - Predicted: ['Drama-99.12%', 'Comedy-87.89%', 'Romance-2.82%']
# Ex. 623: Disclosure  - ['Drama', 'Thriller'] - Predicted: ['Drama-98.24%', 'Comedy-4.60%', 'Thriller-0.91%']
# Ex. 624: Blast from the Past  - ['Comedy', 'Romance'] - Predicted: ['Comedy-1.23%', 'Thriller-0.52%', 'Sci-Fi-0.48%']
# Ex. 625: Malice  - ['Thriller'] - Predicted: ['Thriller-54.89%', 'Drama-29.20%', 'Action-0.34%']
# Ex. 626: End of Days  - ['Action', 'Thriller'] - Predicted: ['Drama-99.88%', 'Thriller-75.03%', 'Crime-0.60%']
# Ex. 627: Children of the Corn II: The Final Sacrifice  - ['Horror'] - Predicted: ['Thriller-86.21%', 'Western-3.65%', 'Mystery-2.37%']
# Ex. 628: Cool Dry Place, A  - ['Drama'] - Predicted: ['Comedy-99.90%', 'Drama-17.54%', 'Fantasy-0.29%']
# Ex. 629: Hush  - ['Thriller'] - Predicted: ['Drama-44.58%', 'Thriller-4.24%', 'Action-1.82%']
# Ex. 630: Mission: Impossible  - ['Action', 'Adventure', 'Mystery'] - Predicted: ['Thriller-100.00%', 'Action-99.45%', 'Drama-0.39%']
# Ex. 631: Sunshine  - ['Drama'] - Predicted: ['Drama-98.32%', 'Comedy-80.64%', 'Romance-8.39%']
# Ex. 632: My Fellow Americans  - ['Comedy'] - Predicted: ['Drama-80.17%', 'Comedy-18.18%', 'Western-0.00%']
# Ex. 633: Glory  - ['Action', 'Drama', 'War'] - Predicted: ['Drama-99.98%', 'Thriller-0.24%', 'Sci-Fi-0.02%']
# Ex. 634: Crumb  - ['Documentary'] - Predicted: ['Western-10.82%', 'Drama-10.71%', 'Action-1.06%']
# Ex. 635: Tango Lesson, The  - ['Romance'] - Predicted: ['Drama-100.00%', 'Western-0.01%', 'Comedy-0.00%']
# Ex. 636: Giant  - ['Drama'] - Predicted: ['Drama-44.60%', 'Thriller-3.33%', 'Sci-Fi-0.64%']
# Ex. 637: Network  - ['Comedy', 'Drama'] - Predicted: ['Drama-85.79%', 'Comedy-1.68%', 'Thriller-0.75%']
# Ex. 638: Getting Even with Dad  - ['Comedy'] - Predicted: ['Drama-85.23%', 'Action-0.79%', 'War-0.09%']
# Ex. 639: Sister Act 2: Back in the Habit  - ['Comedy'] - Predicted: ['Comedy-99.99%', 'Crime-82.25%', 'Drama-26.92%']
# Ex. 560: Man on the Moon  - ['Comedy', 'Drama'] - Predicted: ['Comedy-86.07%', "Children's-14.46%", 'Animation-1.72%']
# Ex. 561: Primary Colors  - ['Drama'] - Predicted: ['Thriller-68.99%', 'Action-11.93%', 'Drama-10.19%']
# Ex. 562: Gabbeh  - ['Drama'] - Predicted: ['Action-72.42%', 'Drama-12.02%', 'Adventure-5.59%']
# Ex. 563: Killing Fields, The  - ['Drama', 'War'] - Predicted: ['Drama-4.90%', "Children's-3.77%", 'Comedy-2.75%']
# Ex. 564: Sesame Street Presents Follow That Bird  - ["Children's", 'Comedy'] - Predicted: ['Comedy-96.21%', 'Drama-85.88%', 'Romance-1.85%']
# Ex. 565: Secret Adventures of Tom Thumb, The  - ['Adventure', "Children's"] - Predicted: ['Horror-100.00%', 'Sci-Fi-39.68%', 'Thriller-0.64%']
# Ex. 566: Return of the Pink Panther, The  - ['Comedy'] - Predicted: ['Comedy-73.42%', 'Animation-0.30%', 'Thriller-0.15%']
# Ex. 567: Ed  - ['Comedy'] - Predicted: ['Horror-100.00%', 'Thriller-0.04%', 'Western-0.00%']
# Ex. 568: Superman  - ['Action', 'Adventure', 'Sci-Fi'] - Predicted: ['Thriller-96.18%', 'Action-24.98%', 'Drama-13.73%']
# Ex. 569: Red Rock West  - ['Thriller'] - Predicted: ['Comedy-97.97%', 'Drama-33.54%', 'Romance-0.30%']
# Ex. 570: No Looking Back  - ['Comedy', 'Drama', 'Romance'] - Predicted: ['Action-86.73%', 'Adventure-61.58%', 'Drama-2.91%']
# Ex. 571: Patch Adams  - ['Comedy', 'Drama'] - Predicted: ['Comedy-14.41%', 'Drama-5.12%', 'Romance-0.01%']
# Ex. 572: Bullets Over Broadway  - ['Comedy'] - Predicted: ['Drama-54.00%', 'Crime-1.43%', 'Comedy-0.41%']
# Ex. 573: Object of My Affection, The  - ['Comedy', 'Romance'] - Predicted: ['Drama-1.00%', 'Comedy-0.32%', 'Romance-0.23%']

# %%
def apk(actual : list | int, predicted: list, k: int):
  """
  Computes the average precision at k.
  This function computes the average prescision at k between two lists of
  items.
  Parameters
  ----------
  actual : list
            A list of elements that are to be predicted (order doesn't matter)
  predicted : list
              A list of predicted elements (order does matter)
  k : int, optional
      The maximum number of predicted elements
  Returns
  -------
  score : double
          The average precision at k over the input lists
  """
  if not actual:
    return 0.0

  if len(predicted)>k:
    predicted = predicted[:k]

  score = 0.0
  num_hits = 0.0
  a = actual if type(actual) is list else [actual]
  for i,p in enumerate(predicted):
    if p in a and p not in predicted[:i]:
      num_hits += 1.0
      score += num_hits / (i+1.0)

  return score / min(len(a), k)

def mapk(actual: list | int, predicted: list, k: int):
  """
  Computes the mean average precision at k.
  This function computes the mean average prescision at k between two lists
  of lists of items.
  Parameters
  ----------
  actual : list
            A list of lists of elements that are to be predicted
            (order doesn't matter in the lists)
  predicted : list
              A list of lists of predicted elements
              (order matters in the lists)
  k : int, optional
      The maximum number of predicted elements
  Returns
  -------
  score : double
          The mean average precision at k over the input lists
  """
  if isinstance(actual, int):
    actual = actual.tolist()
  return np.mean([apk(a,p,k) for a,p in zip(actual, predicted)])

for test_idx, (title_tensor, img_tensor, genre_tensor) in enumerate(test_dataloader):
    titles = testing_set.data['title'].tolist()
    img_paths = testing_set.data['img_path'].tolist()
    genres = testing_set.data['genre'].tolist()
    target_title_tensor = title_tensor
    target_img_tensor = img_tensor
    top_probs, top_classes = percent_classes(model, target_title_tensor, target_img_tensor, topk=topk)
    actuals = [genre_tensor[i].nonzero().squeeze().tolist() for i in range(genre_tensor.size(0))]
    print(f"Batch {test_idx}: {mapk(actuals,top_classes,topk):.4f}")
# Out:
# Batch 0: 0.4479
# Batch 1: 0.5312
# Batch 2: 0.5469
# Batch 3: 0.3906
# Batch 4: 0.5122
# Batch 5: 0.6771
# Batch 6: 0.2986
# Batch 7: 0.3438
# Batch 8: 0.5260
# Batch 9: 0.5035
# Batch 10: 0.3958
# Batch 11: 0.4687
# Batch 12: 0.3854
# Batch 13: 0.4809
# Batch 14: 0.4688
# Batch 15: 0.5417
# Batch 16: 0.4375
# Batch 17: 0.5556
# Batch 18: 0.5677
# Batch 19: 0.4392
# Batch 20: 0.4410
# Batch 21: 0.5226
# Batch 22: 0.4896
# Batch 23: 0.5156
# Batch 24: 0.5365
# Batch 25: 0.4844
# Batch 26: 0.4844
# Batch 27: 0.5226
# Batch 28: 0.4531
# Batch 29: 0.6979
# Batch 30: 0.6562
# Batch 31: 0.4896
# Batch 32: 0.5382
# Batch 33: 0.4271
# Batch 34: 0.4566
# Batch 35: 0.6128
# Batch 36: 0.4844
# Batch 37: 0.6580
# Batch 38: 0.4514
# Batch 39: 0.4844
# Batch 40: 0.6151
